# %%
import numpy as np
import pandas as pd

# %%
# Load the data
df = pd.read_json("nobel_winners_dirty.json")

# %%
# We can identify missing data quickly with the info command...
# Look at gender vs name
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
# born_in           1052 non-null object
# category          1052 non-null object
# country           1052 non-null object
# date_of_birth     1044 non-null object
# date_of_death     1044 non-null object
# gender            1040 non-null object
# link              1052 non-null object
# name              1052 non-null object
# place_of_birth    1044 non-null object
# place_of_death    1044 non-null object
# text              1052 non-null object
# year              1052 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 106.8+ KB

# %%
# Dataframes have a handy shortcut for numerical statistics...
# describe runs on the integer column
# Per the book look at the min value for year
df.describe()
# Out:
#               year
# count  1052.000000
# mean   1968.729087
# std      33.155829
# min    1809.000000
# 25%    1947.000000
# 50%    1975.000000
# 75%    1996.000000
# max    2014.000000

# %%
# But it knows how to describe objects as well...
df.describe(include=['object'])
# Out:
#        born_in                category        country date_of_birth  \
# count     1052                    1052           1052          1044
# unique      40                       7             59           853
# top             Physiology or Medicine  United States    9 May 1947
# freq       910                     250            350             4
#
#        date_of_death gender                                         link  \
# count           1044   1040                                         1052
# unique           563      2                                          893
# top                    male  http://en.wikipedia.org/wiki/Michael_Levitt
# freq             362    982                                            4
#
#                 name place_of_birth place_of_death  \
# count           1052           1044           1044
# unique           998            735            410
# top     Ronald Coase
# freq               2             29            409
#
#                                                      text
# count                                                1052
# unique                                               1043
# top     Robert Aumann ,  born in Germany , Economics, ...
# freq                                                    2

# %%
# The book expounds on data accessors... masks/filters and such.
# We'll move on to clean up data

# %%
# Replace all empty strings with NaN
df.replace('', np.nan, inplace=True)

# %%
# Find names with asterisks
# Contains tries to compile a regex so we have to escape the *
has_asterisk= df.name.str.contains('\*')

# %%
# Use our mask and spot check they do, in fact have asterisks...
df[has_asterisk].head()['name']
# Out:
# 1          Ivo Andric *
# 2     Vladimir Prelog *
# 14      Simon Kuznets *
# 15     Menachem Begin *
# 16       Shimon Peres *
# Name: name, dtype: object

# %%
# Let's replace asterisks but this time we'll pull the series (the column) out
# and just work on it
names = df.name
names = names.str.replace("*", "")

# %%
# If we just replace the "*" we leave the whitespace before it...
# So let's clean up the whitespace
names = names.str.strip()

# %%
names.head()
# Out:
# 0                     César Milstein
# 1                         Ivo Andric
# 2                    Vladimir Prelog
# 3    Institut de Droit International
# 4                  Auguste Beernaert
# Name: name, dtype: object

# %%
# We can use our same mask again- it only has a list of true/false values
# so it is going to show the same names... and we can check they are clean
# Again, the `has_asterisk` mask isn't re-evaluated so it shows the same rows
# it originally detected.
names[has_asterisk].head()
# Out:
# 1          Ivo Andric
# 2     Vladimir Prelog
# 14      Simon Kuznets
# 15     Menachem Begin
# 16       Shimon Peres
# Name: name, dtype: object

# %%
# Just to show how that works...
# rows 1 & 2 are True so they aren't masked
has_asterisk.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# Name: name, dtype: bool

# %%
# Now let's put the series back in to the dataframe...
# Still the old data
df.name.head()
# Out:
# 0                     César Milstein
# 1                       Ivo Andric *
# 2                  Vladimir Prelog *
# 3    Institut de Droit International
# 4                  Auguste Beernaert
# Name: name, dtype: object

# %%
# Reassign the property to our series we changed
df.name = names

# %%
# And now it's clean
df.name.head()
# Out:
# 0                     César Milstein
# 1                         Ivo Andric
# 2                    Vladimir Prelog
# 3    Institut de Droit International
# 4                  Auguste Beernaert
# Name: name, dtype: object

# %%
# Now let's look at our data again
df.head()
# Out:
#                   born_in                category    country   date_of_birth  \
# 0                     NaN  Physiology or Medicine  Argentina  8 October 1927
# 1  Bosnia and Herzegovina              Literature        NaN  9 October 1892
# 2  Bosnia and Herzegovina               Chemistry        NaN   July 23, 1906
# 3                     NaN                   Peace    Belgium            None
# 4                     NaN                   Peace    Belgium    26 July 1829
#
#     date_of_death gender                                               link  \
# 0   24 March 2002   male   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1   13 March 1975   male            http://en.wikipedia.org/wiki/Ivo_Andric
# 2      1998-01-07   male       http://en.wikipedia.org/wiki/Vladimir_Prelog
# 3            None   None  http://en.wikipedia.org/wiki/Institut_de_Droit...
# 4  6 October 1912   male  http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
#
#                               name  \
# 0                   César Milstein
# 1                       Ivo Andric
# 2                  Vladimir Prelog
# 3  Institut de Droit International
# 4                Auguste Beernaert
#
#                                       place_of_birth  \
# 0                          Bahía Blanca ,  Argentina
# 1  Dolac (village near Travnik), Austria-Hungary ...
# 2  Sarajevo ,  Bosnia and Herzegovina , then part...
# 3                                               None
# 4             Ostend ,  Netherlands  (now  Belgium )
#
#                                       place_of_death  \
# 0                                Cambridge , England
# 1  Belgrade, SR Serbia, SFR Yugoslavia (present-d...
# 2                              Zürich ,  Switzerland
# 3                                               None
# 4                             Lucerne ,  Switzerland
#
#                                                 text  year
# 0      César Milstein , Physiology or Medicine, 1984  1984
# 1  Ivo Andric *,  born in then  Austria–Hungary ,...  1961
# 2  Vladimir Prelog *,  born in then  Austria–Hung...  1975
# 3      Institut de Droit International , Peace, 1904  1904
# 4                    Auguste Beernaert , Peace, 1909  1909

# %%
# Let's filter down to all the rows where born_in is null
df = df[df.born_in.isnull()]

# %%
df.head()
# Out:
#   born_in                category    country   date_of_birth   date_of_death  \
# 0     NaN  Physiology or Medicine  Argentina  8 October 1927   24 March 2002
# 3     NaN                   Peace    Belgium            None            None
# 4     NaN                   Peace    Belgium    26 July 1829  6 October 1912
# 5     NaN              Literature    Belgium  29 August 1862      6 May 1949
# 6     NaN                   Peace    Belgium   22 April 1854     14 May 1943
#
#   gender                                               link  \
# 0   male   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 3   None  http://en.wikipedia.org/wiki/Institut_de_Droit...
# 4   male  http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
# 5   male   http://en.wikipedia.org/wiki/Maurice_Maeterlinck
# 6   male     http://en.wikipedia.org/wiki/Henri_La_Fontaine
#
#                               name                          place_of_birth  \
# 0                   César Milstein               Bahía Blanca ,  Argentina
# 3  Institut de Droit International                                    None
# 4                Auguste Beernaert  Ostend ,  Netherlands  (now  Belgium )
# 5              Maurice Maeterlinck                        Ghent ,  Belgium
# 6                Henri La Fontaine                                Brussels
#
#            place_of_death                                           text  year
# 0     Cambridge , England  César Milstein , Physiology or Medicine, 1984  1984
# 3                    None  Institut de Droit International , Peace, 1904  1904
# 4  Lucerne ,  Switzerland                Auguste Beernaert , Peace, 1909  1909
# 5          Nice ,  France         Maurice Maeterlinck , Literature, 1911  1911
# 6                 Belgium                Henri La Fontaine , Peace, 1913  1913

# %%
# Looking above the born_in column isn't useful so we'll remove it
# To drop something we have to specify if it's a column (axis=1)
# or a row (axis=0, which is the default)
df = df.drop('born_in', axis=1)

# %%
df.head()
# Out:
#                  category    country   date_of_birth   date_of_death gender  \
# 0  Physiology or Medicine  Argentina  8 October 1927   24 March 2002   male
# 3                   Peace    Belgium            None            None   None
# 4                   Peace    Belgium    26 July 1829  6 October 1912   male
# 5              Literature    Belgium  29 August 1862      6 May 1949   male
# 6                   Peace    Belgium   22 April 1854     14 May 1943   male
#
#                                                 link  \
# 0   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 3  http://en.wikipedia.org/wiki/Institut_de_Droit...
# 4  http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
# 5   http://en.wikipedia.org/wiki/Maurice_Maeterlinck
# 6     http://en.wikipedia.org/wiki/Henri_La_Fontaine
#
#                               name                          place_of_birth  \
# 0                   César Milstein               Bahía Blanca ,  Argentina
# 3  Institut de Droit International                                    None
# 4                Auguste Beernaert  Ostend ,  Netherlands  (now  Belgium )
# 5              Maurice Maeterlinck                        Ghent ,  Belgium
# 6                Henri La Fontaine                                Brussels
#
#            place_of_death                                           text  year
# 0     Cambridge , England  César Milstein , Physiology or Medicine, 1984  1984
# 3                    None  Institut de Droit International , Peace, 1904  1904
# 4  Lucerne ,  Switzerland                Auguste Beernaert , Peace, 1909  1909
# 5          Nice ,  France         Maurice Maeterlinck , Literature, 1911  1911
# 6                 Belgium                Henri La Fontaine , Peace, 1913  1913

# %%
# Following the operations on p249 we're going to drop the year 1809
df.drop(df[df.year == 1809].index, inplace=True)
# So that code, unrolled:
# df.drop( # Call the drop function
#     df[df.year == 1809].index, # make a dataframe from the mask year == 1809 so we only have that year
                                 # call .index to return the row id's of those rows as a series
#     inplace=True # Alter the dataframe in place
# )
# So that call functions as df.drop(Int64Index([1, 2, 3, ...), inplace=True) after everything is evaluated

# %%
# And confirm it's gone...
df.sort_values('year').head()
# Out:
#                    category      country  date_of_birth     date_of_death  \
# 608                   Peace  Switzerland     8 May 1828   30 October 1910
# 68   Physiology or Medicine      Germany  15 March 1854     31 March 1917
# 909                   Peace       France     8 May 1828   30 October 1910
# 908                   Peace       France   May 20, 1822     June 12, 1912
# 907              Literature       France  16 March 1839  6 September 1907
#
#     gender                                               link  \
# 608   male          http://en.wikipedia.org/wiki/Henry_Dunant
# 68    male  http://en.wikipedia.org/wiki/Emil_Adolf_von_Be...
# 909   male          http://en.wikipedia.org/wiki/Henry_Dunant
# 908   male  http://en.wikipedia.org/wiki/Fr%C3%A9d%C3%A9ri...
# 907   male       http://en.wikipedia.org/wiki/Sully_Prudhomme
#
#                        name        place_of_birth             place_of_death  \
# 608            Henry Dunant  Geneva , Switzerland        Heiden, Switzerland
# 68   Emil Adolf von Behring              Hansdorf    Marburg ,  Hesse-Nassau
# 909            Henry Dunant  Geneva , Switzerland        Heiden, Switzerland
# 908          Frédéric Passy       Paris ,  France            Paris ,  France
# 907         Sully Prudhomme         Paris, France  Châtenay-Malabry , France
#
#                                                   text  year
# 608                         Henry Dunant , Peace, 1901  1901
# 68   Emil Adolf von Behring , Physiology or Medicin...  1901
# 909                         Henry Dunant , Peace, 1901  1901
# 908                       Frédéric Passy , Peace, 1901  1901
# 907                 Sully Prudhomme , Literature, 1901  1901

# %%
# Now let's find duplicates by name
# Note here df.duplicated is just making a mask, a list of True / False...
# So we have to use it to find data in the dataframe
dupes_by_name = df[df.duplicated('name')]

# %%
dupes_by_name.count()
# Out:
# category          45
# country           45
# date_of_birth     44
# date_of_death     23
# gender            44
# link              45
# name              45
# place_of_birth    44
# place_of_death    22
# text              45
# year              45
# dtype: int64

# %%
all_dupes = df[df.name.isin(dupes_by_name.name)]

# %%
all_dupes.count()
# Out:
# category          90
# country           90
# date_of_birth     88
# date_of_death     46
# gender            88
# link              90
# name              90
# place_of_birth    88
# place_of_death    44
# text              90
# year              90
# dtype: int64

# %%
# Now let's sort our data by name
sorted_df = all_dupes.sort_values('name')
# And display name, country, year
sorted_df[['name', 'country', 'year']]
# Out:
#                           name         country  year
# 121                 Aaron Klug    South Africa  1982
# 131                 Aaron Klug  United Kingdom  1982
# 844            Albert Einstein         Germany  1921
# 615            Albert Einstein     Switzerland  1921
# 176              Arieh Warshel   United States  2013
# 798              Arieh Warshel          Israel  2013
# 830              Avram Hershko         Hungary  2004
# 94               Avram Hershko          Israel  2004
# 366           Baruj Benacerraf   United States  1980
# 228           Baruj Benacerraf       Venezuela  1980
# 805             Betty Williams         Ireland  1976
# 573             Betty Williams  United Kingdom  1976
# 162           Brian P. Schmidt   United States  2011
# 1047          Brian P. Schmidt       Australia  2011
# 498             Charles K. Kao   United States  2009
# 831             Charles K. Kao       Hong Kong  2009
# 976             Chen Ning Yang           China  1957
# 295             Chen Ning Yang   United States  1957
# 0               César Milstein       Argentina  1984
# 134             César Milstein  United Kingdom  1984
# 623               Daniel Bovet     Switzerland  1957
# 790               Daniel Bovet           Italy  1957
# 457            Daniel Kahneman   United States  2002
# 93             Daniel Kahneman          Israel  2002
# 630          Edmond H. Fischer     Switzerland  1992
# 407          Edmond H. Fischer   United States  1992
# 505            Ei-ichi Negishi   United States  2010
# 778            Ei-ichi Negishi           Japan  2010
# 524          Ernest Rutherford  United Kingdom  1908
# 985          Ernest Rutherford          Canada  1908
# ...                        ...             ...   ...
# 110              Mother Teresa       Macedonia  1979
# 813              Mother Teresa           India  1979
# 947   Médecins Sans Frontières          France  1999
# 632   Médecins Sans Frontières     Switzerland  1999
# 776            Osamu Shimomura           Japan  2008
# 490            Osamu Shimomura   United States  2008
# 1013            Philipp Lenard         Austria  1905
# 72              Philipp Lenard         Germany  1905
# 1006         Ralph M. Steinman          Canada  2011
# 510          Ralph M. Steinman   United States  2011
# 376       Rita Levi-Montalcini   United States  1986
# 85        Rita Levi-Montalcini           Italy  1986
# 476              Robert Aumann   United States  2005
# 96               Robert Aumann          Israel  2005
# 405               Ronald Coase   United States  1991
# 137               Ronald Coase  United Kingdom  1991
# 515             Shuji Nakamura   United States  2014
# 780             Shuji Nakamura           Japan  2014
# 396              Sidney Altman   United States  1990
# 995              Sidney Altman          Canada  1989
# 451             Sydney Brenner   United States  2002
# 586             Sydney Brenner  United Kingdom  2002
# 172           Thomas C. Südhof   United States  2013
# 905           Thomas C. Südhof         Germany  2013
# 975              Tsung-Dao Lee           China  1957
# 294              Tsung-Dao Lee   United States  1957
# 333           Wassily Leontief   United States  1973
# 684           Wassily Leontief          Russia  1973
# 773             Yoichiro Nambu           Japan  2008
# 489             Yoichiro Nambu   United States  2008
#
# [90 rows x 3 columns]

# %%
# Examine the data above and you will notice some people won
# awards for the same year but listed in different countries.

# Mask our dataframe to those not named Marie Curie
df = df[~(df.name == 'Marie Curie')]

# Reassign the country for Marie Curie's hyphened surname
df.loc[(df.name == u'Marie Skłodowska-Curie') & (df.year == 1911), 'country'] = 'France'

# %%
df.loc[df.name == u'Marie Skłodowska-Curie']
# Out:
#       category country    date_of_birth date_of_death  gender  \
# 706    Physics  Poland  7 November 1867   4 July 1934  female
# 709  Chemistry  France  7 November 1867   4 July 1934  female
#
#                                          link                    name  \
# 706  http://en.wikipedia.org/wiki/Marie_Curie  Marie Skłodowska-Curie
# 709  http://en.wikipedia.org/wiki/Marie_Curie  Marie Skłodowska-Curie
#
#       place_of_birth        place_of_death  \
# 706  Warsaw , Poland  Sancellemoz , France
# 709  Warsaw , Poland  Sancellemoz , France
#
#                                                   text  year
# 706  Marie Skłodowska-Curie ,  born in partitioned ...  1903
# 709  Marie Skłodowska-Curie ,  born in partitioned ...  1911

# %%
df[df.name.str.contains('Marie')].head()
# Out:
#       category country       date_of_birth date_of_death  gender  \
# 706    Physics  Poland     7 November 1867   4 July 1934  female
# 709  Chemistry  France     7 November 1867   4 July 1934  female
# 942  Chemistry  France  September 30, 1939           NaN    male
#
#                                              link                    name  \
# 706      http://en.wikipedia.org/wiki/Marie_Curie  Marie Skłodowska-Curie
# 709      http://en.wikipedia.org/wiki/Marie_Curie  Marie Skłodowska-Curie
# 942  http://en.wikipedia.org/wiki/Jean-Marie_Lehn         Jean-Marie Lehn
#
#         place_of_birth        place_of_death  \
# 706    Warsaw , Poland  Sancellemoz , France
# 709    Warsaw , Poland  Sancellemoz , France
# 942  Rosheim ,  France                   NaN
#
#                                                   text  year
# 706  Marie Skłodowska-Curie ,  born in partitioned ...  1903
# 709  Marie Skłodowska-Curie ,  born in partitioned ...  1911
# 942                  Jean-Marie Lehn , Chemistry, 1987  1987

# %%
# Now following along in the book, p248 & p249 to clean Sidney Altman
