# %%
import requests
import scrapy

# %%
# Setup our URL as a variable for easy reuse if needed

# %%
url = "https://en.wikipedia.org/wiki/List_of_Nobel_laureates"

# %%
# Make a request to the URL with the requests library

# %%
resp = requests.get(url)

# %%
# The content of the response in Python 3 is a byte sequence.
# It looks like a string with a little b in front of it
# 'foo' is a string
# b'foo' is a byte sequence

# %%
body_bytes = resp.content

# %%
# Body is in bytes... turn it in to a string by decoding it to UTF-8
body_str = body_bytes.decode('utf-8')

# %%
# Create a scrapy selector from the string content
# https://doc.scrapy.org/en/latest/topics/selectors.html
sel = scrapy.Selector(text=body_str)

# %%
# Find the table using a CSS selector for the wikitable class
table = sel.css('.wikitable')
table
# Out:
# [<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' wikitable ')]" data='<table class="wikitable sortable">\n<tr>\n'>]

# %%
# In order to get the data from the class we must traverse the content using selectors

# %%
table.css('tr') # Get all the tr elements within the table
table.css('tr')[0] # Get the first tr element within the table using the pythonic index
table.css('tr')[0].css('th') # Get all the th elements from within the first tr
table.css('tr:nth-child(1) th') # Get all the th elements from the first tr element within the table using CSS selector
# !!!! Note the table on the page has a header and a footer and there will be TWO sets of tr's with th's
# Out:
# [<Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th>Year</th>'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="18%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="16%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="18%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="16%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="16%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="15%"><a href="/wiki/List_of_N'>]

# %%
table.css('tr:nth-child(1) th')
# Out:
# [<Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th>Year</th>'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="18%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="16%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="18%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="16%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="16%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::tr[count(preceding-sibling::*) = 0]/descendant-or-self::*/th' data='<th width="15%"><a href="/wiki/List_of_N'>]

# %%
table.css('tr')[0].css('th')
# Out:
# [<Selector xpath='descendant-or-self::th' data='<th>Year</th>'>,
#  <Selector xpath='descendant-or-self::th' data='<th width="18%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::th' data='<th width="16%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::th' data='<th width="18%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::th' data='<th width="16%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::th' data='<th width="16%"><a href="/wiki/List_of_N'>,
#  <Selector xpath='descendant-or-self::th' data='<th width="15%"><a href="/wiki/List_of_N'>]

# %%
# Get the string values of all the th's
# Note they are all Selector objects but the data is just the string content...
table.css('tr')[0].css('th').xpath('string()')
# Out:
# [<Selector xpath='string()' data='Year'>,
#  <Selector xpath='string()' data='Physics'>,
#  <Selector xpath='string()' data='Chemistry'>,
#  <Selector xpath='string()' data='Physiology\nor Medicine'>,
#  <Selector xpath='string()' data='Literature'>,
#  <Selector xpath='string()' data='Peace'>,
#  <Selector xpath='string()' data='Economics'>]

# %%
# We must call extract to pull the data out of the selectors
table.css('tr')[0].css('th').xpath('string()').extract()
# Out:
# ['Year',
#  'Physics',
#  'Chemistry',
#  'Physiology\nor Medicine',
#  'Literature',
#  'Peace',
#  'Economics']

# %%
# Again, the same example using the CSS selector form
# Get all the column names from the first row's table heading (th) elements
# Using CSS selector for nth-child
table.css('tr:nth-child(1) th').xpath('string()').extract()
# Out:
# ['Year',
#  'Physics',
#  'Chemistry',
#  'Physiology\nor Medicine',
#  'Literature',
#  'Peace',
#  'Economics']

# %%
# Save our column names in a variable
col_names = table.css('tr:nth-child(1) th').xpath('string()').extract()

# %%
col_names
# Out:
# ['Year',
#  'Physics',
#  'Chemistry',
#  'Physiology\nor Medicine',
#  'Literature',
#  'Peace',
#  'Economics']

# %%
# Replace newlines with spaces to fix the 4th item
col_names = [x.replace('\n', ' ') for x in col_names]

# %%
col_names
# Out:
# ['Year',
#  'Physics',
#  'Chemistry',
#  'Physiology or Medicine',
#  'Literature',
#  'Peace',
#  'Economics']

# %%
# Now get all the href attributes from the links in the header
col_links = table.css('tr:nth-child(1) th a').xpath('@href').extract()

# %%
col_links
# Out:
# ['/wiki/List_of_Nobel_laureates_in_Physics',
#  '/wiki/List_of_Nobel_laureates_in_Chemistry',
#  '/wiki/List_of_Nobel_laureates_in_Physiology_or_Medicine',
#  '/wiki/List_of_Nobel_laureates_in_Literature',
#  '/wiki/List_of_Nobel_Peace_Prize_laureates',
#  '/wiki/List_of_Nobel_laureates_in_Economics']

# %%
# In python the built-in zip function can combine two lists
# so we can have a single list of tuples with our column names and links

# %%
col_names_links = list(zip(col_names, col_links))

# %%
col_names_links
# Out:
# [('Year', '/wiki/List_of_Nobel_laureates_in_Physics'),
#  ('Physics', '/wiki/List_of_Nobel_laureates_in_Chemistry'),
#  ('Chemistry', '/wiki/List_of_Nobel_laureates_in_Physiology_or_Medicine'),
#  ('Physiology or Medicine', '/wiki/List_of_Nobel_laureates_in_Literature'),
#  ('Literature', '/wiki/List_of_Nobel_Peace_Prize_laureates'),
#  ('Peace', '/wiki/List_of_Nobel_laureates_in_Economics')]

# %%
# Why is it wrong?

# %%
# If the lists do not have the same number of elements they will not line up correctly.
# The first elements from each list will be paired up and then it will continue pairing everything up until
# the shorter list is finished.

# We can fix this by creating a placeholder of None for the year column (which has no link on the page)

# %%
# Add a placeholder of None to the beginning of our links
col_links.insert(0, None)
col_names_links = list(zip(col_names, col_links))

# This could also be a 1-liner if we didn't mutate the col_links list
# col_names_links = list(zip(col_names, [None] + col_links))

# %%
col_names_links
# Out:
# [('Year', None),
#  ('Physics', '/wiki/List_of_Nobel_laureates_in_Physics'),
#  ('Chemistry', '/wiki/List_of_Nobel_laureates_in_Chemistry'),
#  ('Physiology or Medicine',
#   '/wiki/List_of_Nobel_laureates_in_Physiology_or_Medicine'),
#  ('Literature', '/wiki/List_of_Nobel_laureates_in_Literature'),
#  ('Peace', '/wiki/List_of_Nobel_Peace_Prize_laureates'),
#  ('Economics', '/wiki/List_of_Nobel_laureates_in_Economics')]

# %%
# Now we can see all our categories and their correct links
# We can convert that data in to a dictionary to make is more accessible

# %%
col_names_links = [{"name": name, "href": link} for name, link in col_names_links]
col_names_links
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-aeef64223e71> in <module>()
# ----> 1 col_names_links = [{"name": name, "href": link} for name, link in col_names_links]
#       2 col_names_links
#
# NameError: name 'col_names_links' is not defined

# %%
# Once again we go back to the table to get the data from the remaining rows
table
# Out:
# [<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' wikitable ')]" data='<table class="wikitable sortable">\n<tr>\n'>]

# %%
# This time we don't want the header row since we already parsed it so we use
# the :not selector along with the :nth-child in combination to
# select all the tr elements that are not the first one

# %%
other_rows = table.css('tr:not(:nth-child(1))')

# %%
# Now we want to map all our winners by year.
# Our end goal is a structured map:
{
    '1901': [
        {
            'birthday': '1845-03-27',
            'category': 'Physics',
            'href': '/wiki/Wilhelm_R%C3%B6ntgen',
            'name': 'Wilhelm Röntgen'
        }
    ]
}
# Out:
# {'1901': [{'birthday': '1845-03-27',
#    'category': 'Physics',
#    'href': '/wiki/Wilhelm_R%C3%B6ntgen',
#    'name': 'Wilhelm Röntgen'}]}

# %%
# Start by stubbing out our data container...
# Map categories to winners by year
by_year = {}

# %%
# Now build a loop that adds our next piece- an array of winners per year
# Note that 2016 has a footnote and needs to be cleaned

# %%
for row in other_rows:
    try:
        year = row.css('td')[0].xpath('string()').extract()[0]
    except IndexError:
        continue
    # or year = row.css('td')[0].xpath('string()')[0].extract()
    if '[' in year:
        year = year.split('[')[0]

    year_data = []
    by_year[year] = year_data

# %%
by_year
# Out:
# {'1901': [],
#  '1902': [],
#  '1903': [],
#  '1904': [],
#  '1905': [],
#  '1906': [],
#  '1907': [],
#  '1908': [],
#  '1909': [],
#  '1910': [],
#  '1911': [],
#  '1912': [],
#  '1913': [],
#  '1914': [],
#  '1915': [],
#  '1916': [],
#  '1917': [],
#  '1918': [],
#  '1919': [],
#  '1920': [],
#  '1921': [],
#  '1922': [],
#  '1923': [],
#  '1924': [],
#  '1925': [],
#  '1926': [],
#  '1927': [],
#  '1928': [],
#  '1929': [],
#  '1930': [],
#  '1931': [],
#  '1932': [],
#  '1933': [],
#  '1934': [],
#  '1935': [],
#  '1936': [],
#  '1937': [],
#  '1938': [],
#  '1939': [],
#  '1940': [],
#  '1941': [],
#  '1942': [],
#  '1943': [],
#  '1944': [],
#  '1945': [],
#  '1946': [],
#  '1947': [],
#  '1948': [],
#  '1949': [],
#  '1950': [],
#  '1951': [],
#  '1952': [],
#  '1953': [],
#  '1954': [],
#  '1955': [],
#  '1956': [],
#  '1957': [],
#  '1958': [],
#  '1959': [],
#  '1960': [],
#  '1961': [],
#  '1962': [],
#  '1963': [],
#  '1964': [],
#  '1965': [],
#  '1966': [],
#  '1967': [],
#  '1968': [],
#  '1969': [],
#  '1970': [],
#  '1971': [],
#  '1972': [],
#  '1973': [],
#  '1974': [],
#  '1975': [],
#  '1976': [],
#  '1977': [],
#  '1978': [],
#  '1979': [],
#  '1980': [],
#  '1981': [],
#  '1982': [],
#  '1983': [],
#  '1984': [],
#  '1985': [],
#  '1986': [],
#  '1987': [],
#  '1988': [],
#  '1989': [],
#  '1990': [],
#  '1991': [],
#  '1992': [],
#  '1993': [],
#  '1994': [],
#  '1995': [],
#  '1996': [],
#  '1997': [],
#  '1998': [],
#  '1999': [],
#  '2000': [],
#  '2001': [],
#  '2002': [],
#  '2003': [],
#  '2004': [],
#  '2005': [],
#  '2006': [],
#  '2007': [],
#  '2008': [],
#  '2009': [],
#  '2010': [],
#  '2011': [],
#  '2012': [],
#  '2013': [],
#  '2014': [],
#  '2015': [],
#  '2016': [],
#  '2017': []}

# %%
# Now we want to update that loop to print any errors
# Remember the previous warning that the table will have the th's in the footer of the table as well...
# That last row will cause an error because it has th's not td's

# %%
for row in other_rows:
    try:
        year = row.css('td')[0].xpath('string()').extract()[0]
    except IndexError:
        print('error on {}'.format(row))
        continue
    # or year = row.css('td')[0].xpath('string()')[0].extract()
    if '[' in year:
        year = year.split('[')[0]

    year_data = []
    # Loop through each data cell's links
    for name_link in row.css('td:not(:nth-child(1)) a'):
        name = name_link.xpath('string()')[0].extract()
        name_href = name_link.xpath('@href')[0].extract()
        year_data.append({
            "name": name,
            "href": name_href,
        })
    by_year[year] = year_data
by_year
# Out:
# error on <Selector xpath='descendant-or-self::tr[not(count(preceding-sibling::*) = 0)]' data='<tr>\n<th>Year</th>\n<th width="16%"><a hr'>
# {'1901': [{'href': '/wiki/Wilhelm_R%C3%B6ntgen', 'name': 'Wilhelm Röntgen'},
#   {'href': '/wiki/Jacobus_Henricus_van_%27t_Hoff',
#    'name': "Jacobus Henricus van 't Hoff"},
#   {'href': '/wiki/Emil_Adolf_von_Behring', 'name': 'Emil Adolf von Behring'},
#   {'href': '/wiki/Sully_Prudhomme', 'name': 'Sully Prudhomme'},
#   {'href': '/wiki/Henry_Dunant', 'name': 'Henry Dunant'},
#   {'href': '/wiki/Fr%C3%A9d%C3%A9ric_Passy', 'name': 'Frédéric Passy'}],
#  '1902': [{'href': '/wiki/Hendrik_Lorentz', 'name': 'Hendrik Lorentz'},
#   {'href': '/wiki/Pieter_Zeeman', 'name': 'Pieter Zeeman'},
#   {'href': '/wiki/Hermann_Emil_Fischer', 'name': 'Hermann Emil Fischer'},
#   {'href': '/wiki/Ronald_Ross', 'name': 'Ronald Ross'},
#   {'href': '/wiki/Theodor_Mommsen', 'name': 'Theodor Mommsen'},
#   {'href': '/wiki/%C3%89lie_Ducommun', 'name': 'Élie Ducommun'},
#   {'href': '/wiki/Charles_Albert_Gobat', 'name': 'Charles Albert Gobat'}],
#  '1903': [{'href': '/wiki/Henri_Becquerel', 'name': 'Henri Becquerel'},
#   {'href': '/wiki/Pierre_Curie', 'name': 'Pierre Curie'},
#   {'href': '/wiki/Marie_Curie', 'name': 'Marie Curie'},
#   {'href': '/wiki/Svante_Arrhenius', 'name': 'Svante Arrhenius'},
#   {'href': '/wiki/Niels_Ryberg_Finsen', 'name': 'Niels Ryberg Finsen'},
#   {'href': '/wiki/Bj%C3%B8rnstjerne_Bj%C3%B8rnson',
#    'name': 'Bjørnstjerne Bjørnson'},
#   {'href': '/wiki/Randal_Cremer', 'name': 'Randal Cremer'}],
#  '1904': [{'href': '/wiki/John_Strutt,_3rd_Baron_Rayleigh',
#    'name': 'Lord Rayleigh'},
#   {'href': '/wiki/William_Ramsay', 'name': 'William Ramsay'},
#   {'href': '/wiki/Ivan_Pavlov', 'name': 'Ivan Pavlov'},
#   {'href': '/wiki/Fr%C3%A9d%C3%A9ric_Mistral', 'name': 'Frédéric Mistral'},
#   {'href': '/wiki/Jos%C3%A9_Echegaray', 'name': 'José Echegaray'},
#   {'href': '/wiki/Institut_de_Droit_International',
#    'name': 'Institut de Droit International'}],
#  '1905': [{'href': '/wiki/Philipp_Lenard', 'name': 'Philipp Lenard'},
#   {'href': '/wiki/Adolf_von_Baeyer', 'name': 'Adolf von Baeyer'},
#   {'href': '/wiki/Robert_Koch', 'name': 'Robert Koch'},
#   {'href': '/wiki/Henryk_Sienkiewicz', 'name': 'Henryk Sienkiewicz'},
#   {'href': '/wiki/Bertha_von_Suttner', 'name': 'Bertha von Suttner'}],
#  '1906': [{'href': '/wiki/J._J._Thomson', 'name': 'J. J. Thomson'},
#   {'href': '/wiki/Henri_Moissan', 'name': 'Henri Moissan'},
#   {'href': '/wiki/Camillo_Golgi', 'name': 'Camillo Golgi'},
#   {'href': '/wiki/Santiago_Ram%C3%B3n_y_Cajal',
#    'name': 'Santiago Ramón y Cajal'},
#   {'href': '/wiki/Giosu%C3%A8_Carducci', 'name': 'Giosuè Carducci'},
#   {'href': '/wiki/Theodore_Roosevelt', 'name': 'Theodore Roosevelt'}],
#  '1907': [{'href': '/wiki/Albert_Abraham_Michelson',
#    'name': 'Albert Abraham Michelson'},
#   {'href': '/wiki/Eduard_Buchner', 'name': 'Eduard Buchner'},
#   {'href': '/wiki/Charles_Louis_Alphonse_Laveran',
#    'name': 'Charles Louis Alphonse Laveran'},
#   {'href': '/wiki/Rudyard_Kipling', 'name': 'Rudyard Kipling'},
#   {'href': '/wiki/Ernesto_Teodoro_Moneta', 'name': 'Ernesto Teodoro Moneta'},
#   {'href': '/wiki/Louis_Renault_(jurist)', 'name': 'Louis Renault'}],
#  '1908': [{'href': '/wiki/Gabriel_Lippmann', 'name': 'Gabriel Lippmann'},
#   {'href': '/wiki/Ernest_Rutherford', 'name': 'Ernest Rutherford'},
#   {'href': '/wiki/%C3%89lie_Metchnikoff', 'name': 'Élie Metchnikoff'},
#   {'href': '/wiki/Paul_Ehrlich', 'name': 'Paul Ehrlich'},
#   {'href': '/wiki/Rudolf_Christoph_Eucken', 'name': 'Rudolf Christoph Eucken'},
#   {'href': '/wiki/Klas_Pontus_Arnoldson', 'name': 'Klas Pontus Arnoldson'},
#   {'href': '/wiki/Fredrik_Bajer', 'name': 'Fredrik Bajer'}],
#  '1909': [{'href': '/wiki/Karl_Ferdinand_Braun',
#    'name': 'Karl Ferdinand Braun'},
#   {'href': '/wiki/Guglielmo_Marconi', 'name': 'Guglielmo Marconi'},
#   {'href': '/wiki/Wilhelm_Ostwald', 'name': 'Wilhelm Ostwald'},
#   {'href': '/wiki/Emil_Theodor_Kocher', 'name': 'Emil Theodor Kocher'},
#   {'href': '/wiki/Selma_Lagerl%C3%B6f', 'name': 'Selma Lagerlöf'},
#   {'href': '/wiki/Auguste_Marie_Fran%C3%A7ois_Beernaert',
#    'name': 'Auguste Marie François Beernaert'},
#   {'href': '/wiki/Paul-Henri-Benjamin_d%27Estournelles_de_Constant',
#    'name': "Paul-Henri-Benjamin d'Estournelles de Constant"}],
#  '1910': [{'href': '/wiki/Johannes_Diderik_van_der_Waals',
#    'name': 'Johannes Diderik van der Waals'},
#   {'href': '/wiki/Otto_Wallach', 'name': 'Otto Wallach'},
#   {'href': '/wiki/Albrecht_Kossel', 'name': 'Albrecht Kossel'},
#   {'href': '/wiki/Paul_Heyse', 'name': 'Paul Heyse'},
#   {'href': '/wiki/International_Peace_Bureau',
#    'name': 'International Peace Bureau'}],
#  '1911': [{'href': '/wiki/Wilhelm_Wien', 'name': 'Wilhelm Wien'},
#   {'href': '/wiki/Marie_Sk%C5%82odowska-Curie',
#    'name': 'Marie Skłodowska-Curie'},
#   {'href': '/wiki/Allvar_Gullstrand', 'name': 'Allvar Gullstrand'},
#   {'href': '/wiki/Maurice_Maeterlinck', 'name': 'Maurice Maeterlinck'},
#   {'href': '/wiki/Tobias_Asser', 'name': 'Tobias Asser'},
#   {'href': '/wiki/Alfred_Hermann_Fried', 'name': 'Alfred Hermann Fried'}],
#  '1912': [{'href': '/wiki/Gustaf_Dal%C3%A9n', 'name': 'Gustaf Dalén'},
#   {'href': '/wiki/Victor_Grignard', 'name': 'Victor Grignard'},
#   {'href': '/wiki/Paul_Sabatier_(chemist)', 'name': 'Paul Sabatier'},
#   {'href': '/wiki/Alexis_Carrel', 'name': 'Alexis Carrel'},
#   {'href': '/wiki/Gerhart_Hauptmann', 'name': 'Gerhart Hauptmann'},
#   {'href': '/wiki/Elihu_Root', 'name': 'Elihu Root'}],
#  '1913': [{'href': '/wiki/Heike_Kamerlingh_Onnes',
#    'name': 'Heike Kamerlingh Onnes'},
#   {'href': '/wiki/Alfred_Werner', 'name': 'Alfred Werner'},
#   {'href': '/wiki/Charles_Richet', 'name': 'Charles Richet'},
#   {'href': '/wiki/Rabindranath_Tagore', 'name': 'Rabindranath Tagore'},
#   {'href': '/wiki/Henri_La_Fontaine', 'name': 'Henri La Fontaine'}],
#  '1914': [{'href': '/wiki/Max_von_Laue', 'name': 'Max von Laue'},
#   {'href': '/wiki/Theodore_William_Richards',
#    'name': 'Theodore William Richards'},
#   {'href': '/wiki/Robert_B%C3%A1r%C3%A1ny', 'name': 'Robert Bárány'}],
#  '1915': [{'href': '/wiki/William_Henry_Bragg', 'name': 'William Henry Bragg'},
#   {'href': '/wiki/William_Lawrence_Bragg', 'name': 'William Lawrence Bragg'},
#   {'href': '/wiki/Richard_Willst%C3%A4tter', 'name': 'Richard Willstätter'},
#   {'href': '/wiki/Romain_Rolland', 'name': 'Romain Rolland'}],
#  '1916': [{'href': '/wiki/Verner_von_Heidenstam',
#    'name': 'Verner von Heidenstam'}],
#  '1917': [{'href': '/wiki/Charles_Glover_Barkla',
#    'name': 'Charles Glover Barkla'},
#   {'href': '/wiki/Karl_Adolph_Gjellerup', 'name': 'Karl Adolph Gjellerup'},
#   {'href': '/wiki/Henrik_Pontoppidan', 'name': 'Henrik Pontoppidan'},
#   {'href': '/wiki/International_Committee_of_the_Red_Cross',
#    'name': 'International Committee of the Red Cross'}],
#  '1918': [{'href': '/wiki/Max_Planck', 'name': 'Max Planck'},
#   {'href': '/wiki/Fritz_Haber', 'name': 'Fritz Haber'}],
#  '1919': [{'href': '/wiki/Johannes_Stark', 'name': 'Johannes Stark'},
#   {'href': '/wiki/Jules_Bordet', 'name': 'Jules Bordet'},
#   {'href': '/wiki/Carl_Spitteler', 'name': 'Carl Spitteler'},
#   {'href': '/wiki/Woodrow_Wilson', 'name': 'Woodrow Wilson'}],
#  '1920': [{'href': '/wiki/Charles_%C3%89douard_Guillaume',
#    'name': 'Charles Édouard Guillaume'},
#   {'href': '/wiki/Walther_Nernst', 'name': 'Walther Nernst'},
#   {'href': '/wiki/August_Krogh', 'name': 'August Krogh'},
#   {'href': '/wiki/Knut_Hamsun', 'name': 'Knut Hamsun'},
#   {'href': '/wiki/L%C3%A9on_Bourgeois', 'name': 'Léon Bourgeois'}],
#  '1921': [{'href': '/wiki/Albert_Einstein', 'name': 'Albert Einstein'},
#   {'href': '/wiki/Frederick_Soddy', 'name': 'Frederick Soddy'},
#   {'href': '/wiki/Anatole_France', 'name': 'Anatole France'},
#   {'href': '/wiki/Hjalmar_Branting', 'name': 'Hjalmar Branting'},
#   {'href': '/wiki/Christian_Lous_Lange', 'name': 'Christian Lous Lange'}],
#  '1922': [{'href': '/wiki/Niels_Bohr', 'name': 'Niels Bohr'},
#   {'href': '/wiki/Francis_William_Aston', 'name': 'Francis William Aston'},
#   {'href': '/wiki/Archibald_Hill', 'name': 'Archibald Hill'},
#   {'href': '/wiki/Otto_Fritz_Meyerhof', 'name': 'Otto Fritz Meyerhof'},
#   {'href': '/wiki/Jacinto_Benavente', 'name': 'Jacinto Benavente'},
#   {'href': '/wiki/Fridtjof_Nansen', 'name': 'Fridtjof Nansen'}],
#  '1923': [{'href': '/wiki/Robert_Andrews_Millikan',
#    'name': 'Robert Andrews Millikan'},
#   {'href': '/wiki/Fritz_Pregl', 'name': 'Fritz Pregl'},
#   {'href': '/wiki/Frederick_Banting', 'name': 'Frederick Banting'},
#   {'href': '/wiki/John_James_Rickard_Macleod',
#    'name': 'John James Rickard Macleod'},
#   {'href': '/wiki/W._B._Yeats', 'name': 'W. B. Yeats'}],
#  '1924': [{'href': '/wiki/Manne_Siegbahn', 'name': 'Manne Siegbahn'},
#   {'href': '/wiki/Willem_Einthoven', 'name': 'Willem Einthoven'},
#   {'href': '/wiki/W%C5%82adys%C5%82aw_Reymont', 'name': 'Władysław Reymont'}],
#  '1925': [{'href': '/wiki/James_Franck', 'name': 'James Franck'},
#   {'href': '/wiki/Gustav_Ludwig_Hertz', 'name': 'Gustav Ludwig Hertz'},
#   {'href': '/wiki/Richard_Adolf_Zsigmondy', 'name': 'Richard Adolf Zsigmondy'},
#   {'href': '/wiki/George_Bernard_Shaw', 'name': 'George Bernard Shaw'},
#   {'href': '/wiki/Austen_Chamberlain', 'name': 'Austen Chamberlain'},
#   {'href': '/wiki/Charles_G._Dawes', 'name': 'Charles G. Dawes'}],
#  '1926': [{'href': '/wiki/Jean_Baptiste_Perrin',
#    'name': 'Jean Baptiste Perrin'},
#   {'href': '/wiki/Theodor_Svedberg', 'name': 'Theodor Svedberg'},
#   {'href': '/wiki/Johannes_Fibiger', 'name': 'Johannes Fibiger'},
#   {'href': '/wiki/Grazia_Deledda', 'name': 'Grazia Deledda'},
#   {'href': '/wiki/Aristide_Briand', 'name': 'Aristide Briand'},
#   {'href': '/wiki/Gustav_Stresemann', 'name': 'Gustav Stresemann'}],
#  '1927': [{'href': '/wiki/Arthur_Compton', 'name': 'Arthur Compton'},
#   {'href': '/wiki/Charles_Thomson_Rees_Wilson',
#    'name': 'Charles Thomson Rees Wilson'},
#   {'href': '/wiki/Heinrich_Otto_Wieland', 'name': 'Heinrich Otto Wieland'},
#   {'href': '/wiki/Julius_Wagner-Jauregg', 'name': 'Julius Wagner-Jauregg'},
#   {'href': '/wiki/Henri_Bergson', 'name': 'Henri Bergson'},
#   {'href': '/wiki/Ferdinand_Buisson', 'name': 'Ferdinand Buisson'},
#   {'href': '/wiki/Ludwig_Quidde', 'name': 'Ludwig Quidde'}],
#  '1928': [{'href': '/wiki/Owen_Willans_Richardson',
#    'name': 'Owen Willans Richardson'},
#   {'href': '/wiki/Adolf_Otto_Reinhold_Windaus',
#    'name': 'Adolf Otto Reinhold Windaus'},
#   {'href': '/wiki/Charles_Nicolle', 'name': 'Charles Nicolle'},
#   {'href': '/wiki/Sigrid_Undset', 'name': 'Sigrid Undset'}],
#  '1929': [{'href': '/wiki/Louis_de_Broglie', 'name': 'Louis de Broglie'},
#   {'href': '/wiki/Arthur_Harden', 'name': 'Arthur Harden'},
#   {'href': '/wiki/Hans_von_Euler-Chelpin', 'name': 'Hans von Euler-Chelpin'},
#   {'href': '/wiki/Christiaan_Eijkman', 'name': 'Christiaan Eijkman'},
#   {'href': '/wiki/Frederick_Gowland_Hopkins',
#    'name': 'Frederick Gowland Hopkins'},
#   {'href': '/wiki/Thomas_Mann', 'name': 'Thomas Mann'},
#   {'href': '/wiki/Frank_B._Kellogg', 'name': 'Frank B. Kellogg'}],
#  '1930': [{'href': '/wiki/C._V._Raman', 'name': 'C. V. Raman'},
#   {'href': '/wiki/Hans_Fischer', 'name': 'Hans Fischer'},
#   {'href': '/wiki/Karl_Landsteiner', 'name': 'Karl Landsteiner'},
#   {'href': '/wiki/Sinclair_Lewis', 'name': 'Sinclair Lewis'},
#   {'href': '/wiki/Nathan_S%C3%B6derblom', 'name': 'Nathan Söderblom'}],
#  '1931': [{'href': '/wiki/Carl_Bosch', 'name': 'Carl Bosch'},
#   {'href': '/wiki/Friedrich_Bergius', 'name': 'Friedrich Bergius'},
#   {'href': '/wiki/Otto_Heinrich_Warburg', 'name': 'Otto Heinrich Warburg'},
#   {'href': '/wiki/Erik_Axel_Karlfeldt', 'name': 'Erik Axel Karlfeldt'},
#   {'href': '/wiki/Jane_Addams', 'name': 'Jane Addams'},
#   {'href': '/wiki/Nicholas_Murray_Butler', 'name': 'Nicholas Murray Butler'}],
#  '1932': [{'href': '/wiki/Werner_Heisenberg', 'name': 'Werner Heisenberg'},
#   {'href': '/wiki/Irving_Langmuir', 'name': 'Irving Langmuir'},
#   {'href': '/wiki/Charles_Scott_Sherrington',
#    'name': 'Charles Scott Sherrington'},
#   {'href': '/wiki/Edgar_Adrian,_1st_Baron_Adrian', 'name': 'Edgar Adrian'},
#   {'href': '/wiki/John_Galsworthy', 'name': 'John Galsworthy'}],
#  '1933': [{'href': '/wiki/Erwin_Schr%C3%B6dinger',
#    'name': 'Erwin Schrödinger'},
#   {'href': '/wiki/Paul_Dirac', 'name': 'Paul Dirac'},
#   {'href': '/wiki/Thomas_Hunt_Morgan', 'name': 'Thomas Hunt Morgan'},
#   {'href': '/wiki/Ivan_Bunin', 'name': 'Ivan Bunin'},
#   {'href': '/wiki/Norman_Angell', 'name': 'Norman Angell'}],
#  '1934': [{'href': '/wiki/Harold_Urey', 'name': 'Harold Urey'},
#   {'href': '/wiki/George_Whipple', 'name': 'George Whipple'},
#   {'href': '/wiki/George_Minot', 'name': 'George Minot'},
#   {'href': '/wiki/William_P._Murphy', 'name': 'William P. Murphy'},
#   {'href': '/wiki/Luigi_Pirandello', 'name': 'Luigi Pirandello'},
#   {'href': '/wiki/Arthur_Henderson', 'name': 'Arthur Henderson'}],
#  '1935': [{'href': '/wiki/James_Chadwick', 'name': 'James Chadwick'},
#   {'href': '/wiki/Fr%C3%A9d%C3%A9ric_Joliot-Curie',
#    'name': 'Frédéric Joliot-Curie'},
#   {'href': '/wiki/Ir%C3%A8ne_Joliot-Curie', 'name': 'Irène Joliot-Curie'},
#   {'href': '/wiki/Hans_Spemann', 'name': 'Hans Spemann'},
#   {'href': '/wiki/Carl_von_Ossietzky', 'name': 'Carl von Ossietzky'}],
#  '1936': [{'href': '/wiki/Victor_Francis_Hess', 'name': 'Victor Francis Hess'},
#   {'href': '/wiki/Carl_David_Anderson', 'name': 'Carl David Anderson'},
#   {'href': '/wiki/Peter_Debye', 'name': 'Peter Debye'},
#   {'href': '/wiki/Henry_Hallett_Dale', 'name': 'Henry Hallett Dale'},
#   {'href': '/wiki/Otto_Loewi', 'name': 'Otto Loewi'},
#   {'href': '/wiki/Eugene_O%27Neill', 'name': "Eugene O'Neill"},
#   {'href': '/wiki/Carlos_Saavedra_Lamas', 'name': 'Carlos Saavedra Lamas'}],
#  '1937': [{'href': '/wiki/Clinton_Davisson', 'name': 'Clinton Davisson'},
#   {'href': '/wiki/George_Paget_Thomson', 'name': 'George Paget Thomson'},
#   {'href': '/wiki/Norman_Haworth', 'name': 'Norman Haworth'},
#   {'href': '/wiki/Paul_Karrer', 'name': 'Paul Karrer'},
#   {'href': '/wiki/Albert_Szent-Gy%C3%B6rgyi', 'name': 'Albert Szent-Györgyi'},
#   {'href': '/wiki/Roger_Martin_du_Gard', 'name': 'Roger Martin du Gard'},
#   {'href': '/wiki/Robert_Cecil,_1st_Viscount_Cecil_of_Chelwood',
#    'name': 'The Viscount Cecil of Chelwood'}],
#  '1938': [{'href': '/wiki/Enrico_Fermi', 'name': 'Enrico Fermi'},
#   {'href': '/wiki/Richard_Kuhn', 'name': 'Richard Kuhn'},
#   {'href': '#endnote_Note1A', 'name': '[A]'},
#   {'href': '/wiki/Corneille_Heymans', 'name': 'Corneille Heymans'},
#   {'href': '/wiki/Pearl_S._Buck', 'name': 'Pearl S. Buck'},
#   {'href': '/wiki/Office_international_Nansen_pour_les_r%C3%A9fugi%C3%A9s',
#    'name': 'Nansen International Office For Refugees'}],
#  '1939': [{'href': '/wiki/Ernest_Lawrence', 'name': 'Ernest Lawrence'},
#   {'href': '/wiki/Adolf_Butenandt', 'name': 'Adolf Butenandt'},
#   {'href': '#endnote_Note1A', 'name': '[A]'},
#   {'href': '/wiki/Leopold_Ru%C5%BEi%C4%8Dka', 'name': 'Leopold Ružička'},
#   {'href': '/wiki/Gerhard_Domagk', 'name': 'Gerhard Domagk'},
#   {'href': '#endnote_Note1A', 'name': '[A]'},
#   {'href': '/wiki/Frans_Eemil_Sillanp%C3%A4%C3%A4',
#    'name': 'Frans Eemil Sillanpää'}],
#  '1940': [],
#  '1941': [],
#  '1942': [],
#  '1943': [{'href': '/wiki/Otto_Stern', 'name': 'Otto Stern'},
#   {'href': '/wiki/George_de_Hevesy', 'name': 'George de Hevesy'},
#   {'href': '/wiki/Henrik_Dam', 'name': 'Henrik Dam'},
#   {'href': '/wiki/Edward_Adelbert_Doisy', 'name': 'Edward Adelbert Doisy'}],
#  '1944': [{'href': '/wiki/Isidor_Isaac_Rabi', 'name': 'Isidor Isaac Rabi'},
#   {'href': '/wiki/Otto_Hahn', 'name': 'Otto Hahn'},
#   {'href': '/wiki/Joseph_Erlanger', 'name': 'Joseph Erlanger'},
#   {'href': '/wiki/Herbert_Spencer_Gasser', 'name': 'Herbert Spencer Gasser'},
#   {'href': '/wiki/Johannes_Vilhelm_Jensen', 'name': 'Johannes Vilhelm Jensen'},
#   {'href': '/wiki/International_Committee_of_the_Red_Cross',
#    'name': 'International Committee of the Red Cross'}],
#  '1945': [{'href': '/wiki/Wolfgang_Pauli', 'name': 'Wolfgang Pauli'},
#   {'href': '/wiki/Artturi_Ilmari_Virtanen', 'name': 'Artturi Ilmari Virtanen'},
#   {'href': '/wiki/Alexander_Fleming', 'name': 'Alexander Fleming'},
#   {'href': '/wiki/Ernst_Boris_Chain', 'name': 'Ernst Boris Chain'},
#   {'href': '/wiki/Howard_Florey', 'name': 'Howard Florey'},
#   {'href': '/wiki/Gabriela_Mistral', 'name': 'Gabriela Mistral'},
#   {'href': '/wiki/Cordell_Hull', 'name': 'Cordell Hull'}],
#  '1946': [{'href': '/wiki/Percy_Williams_Bridgman',
#    'name': 'Percy Williams Bridgman'},
#   {'href': '/wiki/James_B._Sumner', 'name': 'James B. Sumner'},
#   {'href': '/wiki/John_Howard_Northrop', 'name': 'John Howard Northrop'},
#   {'href': '/wiki/Wendell_Meredith_Stanley',
#    'name': 'Wendell Meredith Stanley'},
#   {'href': '/wiki/Hermann_Joseph_Muller', 'name': 'Hermann Joseph Muller'},
#   {'href': '/wiki/Hermann_Hesse', 'name': 'Hermann Hesse'},
#   {'href': '/wiki/Emily_Greene_Balch', 'name': 'Emily Greene Balch'},
#   {'href': '/wiki/John_Mott', 'name': 'John Mott'}],
#  '1947': [{'href': '/wiki/Edward_Victor_Appleton',
#    'name': 'Edward Victor Appleton'},
#   {'href': '/wiki/Robert_Robinson_(organic_chemist)',
#    'name': 'Robert Robinson'},
#   {'href': '/wiki/Carl_Ferdinand_Cori', 'name': 'Carl Ferdinand Cori'},
#   {'href': '/wiki/Gerty_Cori', 'name': 'Gerty Cori'},
#   {'href': '/wiki/Bernardo_Houssay', 'name': 'Bernardo Houssay'},
#   {'href': '/wiki/Andr%C3%A9_Gide', 'name': 'André Gide'},
#   {'href': '/wiki/Quaker_Peace_and_Social_Witness',
#    'name': 'Friends Service Council'},
#   {'href': '/wiki/American_Friends_Service_Committee',
#    'name': 'American Friends Service Committee'}],
#  '1948': [{'href': '/wiki/Patrick_Blackett,_Baron_Blackett',
#    'name': 'Patrick Blackett'},
#   {'href': '/wiki/Arne_Tiselius', 'name': 'Arne Tiselius'},
#   {'href': '/wiki/Paul_Hermann_M%C3%BCller', 'name': 'Paul Hermann Müller'},
#   {'href': '/wiki/T._S._Eliot', 'name': 'T. S. Eliot'},
#   {'href': '#endnote_Note1B', 'name': '[B]'}],
#  '1949': [{'href': '/wiki/Hideki_Yukawa', 'name': 'Hideki Yukawa'},
#   {'href': '/wiki/William_Giauque', 'name': 'William Giauque'},
#   {'href': '/wiki/Walter_Rudolf_Hess', 'name': 'Walter Rudolf Hess'},
#   {'href': '/wiki/Ant%C3%B3nio_Egas_Moniz', 'name': 'António Egas Moniz'},
#   {'href': '/wiki/William_Faulkner', 'name': 'William Faulkner'},
#   {'href': '/wiki/John_Boyd_Orr,_1st_Baron_Boyd-Orr',
#    'name': 'John Boyd Orr'}],
#  '1950': [{'href': '/wiki/C._F._Powell', 'name': 'C. F. Powell'},
#   {'href': '/wiki/Otto_Diels', 'name': 'Otto Diels'},
#   {'href': '/wiki/Kurt_Alder', 'name': 'Kurt Alder'},
#   {'href': '/wiki/Philip_Showalter_Hench', 'name': 'Philip Showalter Hench'},
#   {'href': '/wiki/Edward_Calvin_Kendall', 'name': 'Edward Calvin Kendall'},
#   {'href': '/wiki/Tadeus_Reichstein', 'name': 'Tadeus Reichstein'},
#   {'href': '/wiki/Bertrand_Russell', 'name': 'Bertrand Russell'},
#   {'href': '/wiki/Ralph_Bunche', 'name': 'Ralph Bunche'}],
#  '1951': [{'href': '/wiki/John_Cockcroft', 'name': 'John Cockcroft'},
#   {'href': '/wiki/Ernest_Walton', 'name': 'Ernest Walton'},
#   {'href': '/wiki/Edwin_McMillan', 'name': 'Edwin McMillan'},
#   {'href': '/wiki/Glenn_T._Seaborg', 'name': 'Glenn T. Seaborg'},
#   {'href': '/wiki/Max_Theiler', 'name': 'Max Theiler'},
#   {'href': '/wiki/P%C3%A4r_Lagerkvist', 'name': 'Pär Lagerkvist'},
#   {'href': '/wiki/L%C3%A9on_Jouhaux', 'name': 'Léon Jouhaux'}],
#  '1952': [{'href': '/wiki/Felix_Bloch', 'name': 'Felix Bloch'},
#   {'href': '/wiki/Edward_Mills_Purcell', 'name': 'Edward Mills Purcell'},
#   {'href': '/wiki/Archer_John_Porter_Martin',
#    'name': 'Archer John Porter Martin'},
#   {'href': '/wiki/Richard_Laurence_Millington_Synge',
#    'name': 'Richard Laurence Millington Synge'},
#   {'href': '/wiki/Selman_Waksman', 'name': 'Selman Waksman'},
#   {'href': '/wiki/Fran%C3%A7ois_Mauriac', 'name': 'François Mauriac'},
#   {'href': '/wiki/Albert_Schweitzer', 'name': 'Albert Schweitzer'}],
#  '1953': [{'href': '/wiki/Frits_Zernike', 'name': 'Frits Zernike'},
#   {'href': '/wiki/Hermann_Staudinger', 'name': 'Hermann Staudinger'},
#   {'href': '/wiki/Hans_Adolf_Krebs', 'name': 'Hans Adolf Krebs'},
#   {'href': '/wiki/Fritz_Albert_Lipmann', 'name': 'Fritz Albert Lipmann'},
#   {'href': '/wiki/Winston_Churchill', 'name': 'Winston Churchill'},
#   {'href': '/wiki/George_Marshall', 'name': 'George Marshall'}],
#  '1954': [{'href': '/wiki/Max_Born', 'name': 'Max Born'},
#   {'href': '/wiki/Walther_Bothe', 'name': 'Walther Bothe'},
#   {'href': '/wiki/Linus_Pauling', 'name': 'Linus Pauling'},
#   {'href': '/wiki/John_Franklin_Enders', 'name': 'John Franklin Enders'},
#   {'href': '/wiki/Frederick_Chapman_Robbins',
#    'name': 'Frederick Chapman Robbins'},
#   {'href': '/wiki/Thomas_Huckle_Weller', 'name': 'Thomas Huckle Weller'},
#   {'href': '/wiki/Ernest_Hemingway', 'name': 'Ernest Hemingway'},
#   {'href': '/wiki/United_Nations_High_Commissioner_for_Refugees',
#    'name': 'United Nations High Commissioner for Refugees'}],
#  '1955': [{'href': '/wiki/Willis_Lamb', 'name': 'Willis Lamb'},
#   {'href': '/wiki/Polykarp_Kusch', 'name': 'Polykarp Kusch'},
#   {'href': '/wiki/Vincent_du_Vigneaud', 'name': 'Vincent du Vigneaud'},
#   {'href': '/wiki/Hugo_Theorell', 'name': 'Hugo Theorell'},
#   {'href': '/wiki/Halld%C3%B3r_Laxness', 'name': 'Halldór Laxness'}],
#  '1956': [{'href': '/wiki/John_Bardeen', 'name': 'John Bardeen'},
#   {'href': '/wiki/Walter_Houser_Brattain', 'name': 'Walter Houser Brattain'},
#   {'href': '/wiki/William_Shockley', 'name': 'William Shockley'},
#   {'href': '/wiki/Cyril_Norman_Hinshelwood',
#    'name': 'Cyril Norman Hinshelwood'},
#   {'href': '/wiki/Nikolay_Semyonov', 'name': 'Nikolay Semyonov'},
#   {'href': '/wiki/Andr%C3%A9_Fr%C3%A9d%C3%A9ric_Cournand',
#    'name': 'André Frédéric Cournand'},
#   {'href': '/wiki/Werner_Forssmann', 'name': 'Werner Forssmann'},
#   {'href': '/wiki/Dickinson_W._Richards', 'name': 'Dickinson W. Richards'},
#   {'href': '/wiki/Juan_Ram%C3%B3n_Jim%C3%A9nez',
#    'name': 'Juan Ramón Jiménez'}],
#  '1957': [{'href': '/wiki/Chen_Ning_Yang', 'name': 'Chen Ning Yang'},
#   {'href': '/wiki/Tsung-Dao_Lee', 'name': 'Tsung-Dao Lee'},
#   {'href': '/wiki/Alexander_R._Todd,_Baron_Todd', 'name': 'The Lord Todd'},
#   {'href': '/wiki/Daniel_Bovet', 'name': 'Daniel Bovet'},
#   {'href': '/wiki/Albert_Camus', 'name': 'Albert Camus'},
#   {'href': '/wiki/Lester_B._Pearson', 'name': 'Lester B. Pearson'}],
#  '1958': [{'href': '/wiki/Pavel_Cherenkov', 'name': 'Pavel Cherenkov'},
#   {'href': '/wiki/Ilya_Frank', 'name': 'Ilya Frank'},
#   {'href': '/wiki/Igor_Tamm', 'name': 'Igor Tamm'},
#   {'href': '/wiki/Frederick_Sanger', 'name': 'Frederick Sanger'},
#   {'href': '/wiki/George_Wells_Beadle', 'name': 'George Wells Beadle'},
#   {'href': '/wiki/Edward_Lawrie_Tatum', 'name': 'Edward Lawrie Tatum'},
#   {'href': '/wiki/Joshua_Lederberg', 'name': 'Joshua Lederberg'},
#   {'href': '/wiki/Boris_Pasternak', 'name': 'Boris Pasternak'},
#   {'href': '#endnote_Note1C', 'name': '[C]'},
#   {'href': '/wiki/Dominique_Pire', 'name': 'Dominique Pire'}],
#  '1959': [{'href': '/wiki/Emilio_G._Segr%C3%A8', 'name': 'Emilio G. Segrè'},
#   {'href': '/wiki/Owen_Chamberlain', 'name': 'Owen Chamberlain'},
#   {'href': '/wiki/Jaroslav_Heyrovsk%C3%BD', 'name': 'Jaroslav Heyrovský'},
#   {'href': '/wiki/Arthur_Kornberg', 'name': 'Arthur Kornberg'},
#   {'href': '/wiki/Severo_Ochoa', 'name': 'Severo Ochoa'},
#   {'href': '/wiki/Salvatore_Quasimodo', 'name': 'Salvatore Quasimodo'},
#   {'href': '/wiki/Philip_Noel-Baker,_Baron_Noel-Baker',
#    'name': 'Philip Noel-Baker'}],
#  '1960': [{'href': '/wiki/Donald_A._Glaser', 'name': 'Donald A. Glaser'},
#   {'href': '/wiki/Willard_Libby', 'name': 'Willard Libby'},
#   {'href': '/wiki/Frank_Macfarlane_Burnet', 'name': 'Frank Macfarlane Burnet'},
#   {'href': '/wiki/Peter_Medawar', 'name': 'Peter Medawar'},
#   {'href': '/wiki/Saint-John_Perse', 'name': 'Saint-John Perse'},
#   {'href': '/wiki/Albert_Lutuli', 'name': 'Albert Lutuli'}],
#  '1961': [{'href': '/wiki/Robert_Hofstadter', 'name': 'Robert Hofstadter'},
#   {'href': '/wiki/Rudolf_M%C3%B6ssbauer', 'name': 'Rudolf Mössbauer'},
#   {'href': '/wiki/Melvin_Calvin', 'name': 'Melvin Calvin'},
#   {'href': '/wiki/Georg_von_B%C3%A9k%C3%A9sy', 'name': 'Georg von Békésy'},
#   {'href': '/wiki/Ivo_Andri%C4%87', 'name': 'Ivo Andrić'},
#   {'href': '/wiki/Dag_Hammarskj%C3%B6ld', 'name': 'Dag Hammarskjöld'}],
#  '1962': [{'href': '/wiki/Lev_Landau', 'name': 'Lev Landau'},
#   {'href': '/wiki/Max_Perutz', 'name': 'Max Perutz'},
#   {'href': '/wiki/John_Kendrew', 'name': 'John Kendrew'},
#   {'href': '/wiki/Francis_Crick', 'name': 'Francis Crick'},
#   {'href': '/wiki/James_D._Watson', 'name': 'James D. Watson'},
#   {'href': '/wiki/Maurice_Wilkins', 'name': 'Maurice Wilkins'},
#   {'href': '/wiki/John_Steinbeck', 'name': 'John Steinbeck'},
#   {'href': '/wiki/Linus_Pauling', 'name': 'Linus Pauling'}],
#  '1963': [{'href': '/wiki/Eugene_Wigner', 'name': 'Eugene Wigner'},
#   {'href': '/wiki/Maria_Goeppert-Mayer', 'name': 'Maria Goeppert-Mayer'},
#   {'href': '/wiki/J._Hans_D._Jensen', 'name': 'J. Hans D. Jensen'},
#   {'href': '/wiki/Karl_Ziegler', 'name': 'Karl Ziegler'},
#   {'href': '/wiki/Giulio_Natta', 'name': 'Giulio Natta'},
#   {'href': '/wiki/John_Eccles_(neurophysiologist)', 'name': 'John Eccles'},
#   {'href': '/wiki/Alan_Lloyd_Hodgkin', 'name': 'Alan Lloyd Hodgkin'},
#   {'href': '/wiki/Andrew_Huxley', 'name': 'Andrew Huxley'},
#   {'href': '/wiki/Giorgos_Seferis', 'name': 'Giorgos Seferis'},
#   {'href': '/wiki/International_Committee_of_the_Red_Cross',
#    'name': 'International Committee of the Red Cross'},
#   {'href': '/wiki/International_Federation_of_Red_Cross_and_Red_Crescent_Societies',
#    'name': 'League of Red Cross societies'}],
#  '1964': [{'href': '/wiki/Charles_Hard_Townes', 'name': 'Charles Hard Townes'},
#   {'href': '/wiki/Nikolay_Basov', 'name': 'Nikolay Basov'},
#   {'href': '/wiki/Alexander_Prokhorov', 'name': 'Alexander Prokhorov'},
#   {'href': '/wiki/Dorothy_Hodgkin', 'name': 'Dorothy Hodgkin'},
#   {'href': '/wiki/Konrad_Emil_Bloch', 'name': 'Konrad Emil Bloch'},
#   {'href': '/wiki/Feodor_Felix_Konrad_Lynen',
#    'name': 'Feodor Felix Konrad Lynen'},
#   {'href': '/wiki/Jean-Paul_Sartre', 'name': 'Jean-Paul Sartre'},
#   {'href': '#endnote_Note1D', 'name': '[D]'},
#   {'href': '/wiki/Martin_Luther_King,_Jr.',
#    'name': 'Martin Luther King, Jr.'}],
#  '1965': [{'href': '/wiki/Sin-Itiro_Tomonaga', 'name': 'Sin-Itiro Tomonaga'},
#   {'href': '/wiki/Julian_Schwinger', 'name': 'Julian Schwinger'},
#   {'href': '/wiki/Richard_Feynman', 'name': 'Richard Feynman'},
#   {'href': '/wiki/Robert_Burns_Woodward', 'name': 'Robert Burns Woodward'},
#   {'href': '/wiki/Fran%C3%A7ois_Jacob', 'name': 'François Jacob'},
#   {'href': '/wiki/Andr%C3%A9_Michel_Lwoff', 'name': 'André Michel Lwoff'},
#   {'href': '/wiki/Jacques_Monod', 'name': 'Jacques Monod'},
#   {'href': '/wiki/Mikhail_Sholokhov', 'name': 'Mikhail Sholokhov'},
#   {'href': '/wiki/UNICEF',
#    'name': "United Nations International Children's Emergency Fund (UNICEF)"}],
#  '1966': [{'href': '/wiki/Alfred_Kastler', 'name': 'Alfred Kastler'},
#   {'href': '/wiki/Robert_S._Mulliken', 'name': 'Robert S. Mulliken'},
#   {'href': '/wiki/Francis_Peyton_Rous', 'name': 'Francis Peyton Rous'},
#   {'href': '/wiki/Charles_Brenton_Huggins', 'name': 'Charles Brenton Huggins'},
#   {'href': '/wiki/Shmuel_Yosef_Agnon', 'name': 'Shmuel Yosef Agnon'},
#   {'href': '/wiki/Nelly_Sachs', 'name': 'Nelly Sachs'}],
#  '1967': [{'href': '/wiki/Hans_Bethe', 'name': 'Hans Bethe'},
#   {'href': '/wiki/Manfred_Eigen', 'name': 'Manfred Eigen'},
#   {'href': '/wiki/Ronald_George_Wreyford_Norrish',
#    'name': 'Ronald George Wreyford Norrish'},
#   {'href': '/wiki/George_Porter', 'name': 'George Porter'},
#   {'href': '/wiki/Ragnar_Granit', 'name': 'Ragnar Granit'},
#   {'href': '/wiki/Haldan_Keffer_Hartline', 'name': 'Haldan Keffer Hartline'},
#   {'href': '/wiki/George_Wald', 'name': 'George Wald'},
#   {'href': '/wiki/Miguel_%C3%81ngel_Asturias',
#    'name': 'Miguel Ángel Asturias'}],
#  '1968': [{'href': '/wiki/Luis_Walter_Alvarez', 'name': 'Luis Walter Alvarez'},
#   {'href': '/wiki/Lars_Onsager', 'name': 'Lars Onsager'},
#   {'href': '/wiki/Robert_W._Holley', 'name': 'Robert W. Holley'},
#   {'href': '/wiki/Har_Gobind_Khorana', 'name': 'Har Gobind Khorana'},
#   {'href': '/wiki/Marshall_Warren_Nirenberg',
#    'name': 'Marshall Warren Nirenberg'},
#   {'href': '/wiki/Yasunari_Kawabata', 'name': 'Yasunari Kawabata'},
#   {'href': '/wiki/Ren%C3%A9_Cassin', 'name': 'René Cassin'}],
#  '1969': [{'href': '/wiki/Murray_Gell-Mann', 'name': 'Murray Gell-Mann'},
#   {'href': '/wiki/Derek_Barton', 'name': 'Derek Barton'},
#   {'href': '/wiki/Odd_Hassel', 'name': 'Odd Hassel'},
#   {'href': '/wiki/Max_Delbr%C3%BCck', 'name': 'Max Delbrück'},
#   {'href': '/wiki/Alfred_Hershey', 'name': 'Alfred Hershey'},
#   {'href': '/wiki/Salvador_Luria', 'name': 'Salvador Luria'},
#   {'href': '/wiki/Samuel_Beckett', 'name': 'Samuel Beckett'},
#   {'href': '/wiki/International_Labour_Organization',
#    'name': 'International Labour Organization'},
#   {'href': '/wiki/Ragnar_Frisch', 'name': 'Ragnar Frisch'},
#   {'href': '/wiki/Jan_Tinbergen', 'name': 'Jan Tinbergen'}],
#  '1970': [{'href': '/wiki/Hannes_Alfv%C3%A9n', 'name': 'Hannes Alfvén'},
#   {'href': '/wiki/Louis_N%C3%A9el', 'name': 'Louis Néel'},
#   {'href': '/wiki/Luis_Federico_Leloir', 'name': 'Luis Federico Leloir'},
#   {'href': '/wiki/Julius_Axelrod', 'name': 'Julius Axelrod'},
#   {'href': '/wiki/Ulf_von_Euler', 'name': 'Ulf von Euler'},
#   {'href': '/wiki/Bernard_Katz', 'name': 'Bernard Katz'},
#   {'href': '/wiki/Aleksandr_Solzhenitsyn', 'name': 'Aleksandr Solzhenitsyn'},
#   {'href': '/wiki/Norman_Borlaug', 'name': 'Norman Borlaug'},
#   {'href': '/wiki/Paul_Samuelson', 'name': 'Paul Samuelson'}],
#  '1971': [{'href': '/wiki/Dennis_Gabor', 'name': 'Dennis Gabor'},
#   {'href': '/wiki/Gerhard_Herzberg', 'name': 'Gerhard Herzberg'},
#   {'href': '/wiki/Earl_Wilbur_Sutherland,_Jr.',
#    'name': 'Earl Wilbur Sutherland, Jr.'},
#   {'href': '/wiki/Pablo_Neruda', 'name': 'Pablo Neruda'},
#   {'href': '/wiki/Willy_Brandt', 'name': 'Willy Brandt'},
#   {'href': '/wiki/Simon_Kuznets', 'name': 'Simon Kuznets'}],
#  '1972': [{'href': '/wiki/John_Bardeen', 'name': 'John Bardeen'},
#   {'href': '/wiki/Leon_Cooper', 'name': 'Leon Cooper'},
#   {'href': '/wiki/John_Robert_Schrieffer', 'name': 'John Robert Schrieffer'},
#   {'href': '/wiki/Christian_B._Anfinsen', 'name': 'Christian B. Anfinsen'},
#   {'href': '/wiki/Stanford_Moore', 'name': 'Stanford Moore'},
#   {'href': '/wiki/William_Howard_Stein', 'name': 'William Howard Stein'},
#   {'href': '/wiki/Gerald_Edelman', 'name': 'Gerald Edelman'},
#   {'href': '/wiki/Rodney_Robert_Porter', 'name': 'Rodney Robert Porter'},
#   {'href': '/wiki/Heinrich_B%C3%B6ll', 'name': 'Heinrich Böll'},
#   {'href': '/wiki/John_Hicks', 'name': 'John Hicks'},
#   {'href': '/wiki/Kenneth_Arrow', 'name': 'Kenneth Arrow'}],
#  '1973': [{'href': '/wiki/Leo_Esaki', 'name': 'Leo Esaki'},
#   {'href': '/wiki/Ivar_Giaever', 'name': 'Ivar Giaever'},
#   {'href': '/wiki/Brian_David_Josephson', 'name': 'Brian David Josephson'},
#   {'href': '/wiki/Ernst_Otto_Fischer', 'name': 'Ernst Otto Fischer'},
#   {'href': '/wiki/Geoffrey_Wilkinson', 'name': 'Geoffrey Wilkinson'},
#   {'href': '/wiki/Karl_von_Frisch', 'name': 'Karl von Frisch'},
#   {'href': '/wiki/Konrad_Lorenz', 'name': 'Konrad Lorenz'},
#   {'href': '/wiki/Nikolaas_Tinbergen', 'name': 'Nikolaas Tinbergen'},
#   {'href': '/wiki/Patrick_White', 'name': 'Patrick White'},
#   {'href': '/wiki/Henry_Kissinger', 'name': 'Henry Kissinger'},
#   {'href': '/wiki/Le_Duc_Tho', 'name': 'Le Duc Tho'},
#   {'href': '#endnote_Note1E', 'name': '[E]'},
#   {'href': '/wiki/Wassily_Leontief', 'name': 'Wassily Leontief'}],
#  '1974': [{'href': '/wiki/Martin_Ryle', 'name': 'Martin Ryle'},
#   {'href': '/wiki/Antony_Hewish', 'name': 'Antony Hewish'},
#   {'href': '/wiki/Paul_Flory', 'name': 'Paul Flory'},
#   {'href': '/wiki/Albert_Claude', 'name': 'Albert Claude'},
#   {'href': '/wiki/Christian_de_Duve', 'name': 'Christian de Duve'},
#   {'href': '/wiki/George_Emil_Palade', 'name': 'George Emil Palade'},
#   {'href': '/wiki/Eyvind_Johnson', 'name': 'Eyvind Johnson'},
#   {'href': '/wiki/Harry_Martinson', 'name': 'Harry Martinson'},
#   {'href': '/wiki/Se%C3%A1n_MacBride', 'name': 'Seán MacBride'},
#   {'href': '/wiki/Eisaku_Sat%C5%8D', 'name': 'Eisaku Satō'},
#   {'href': '/wiki/Gunnar_Myrdal', 'name': 'Gunnar Myrdal'},
#   {'href': '/wiki/Friedrich_Hayek', 'name': 'Friedrich Hayek'}],
#  '1975': [{'href': '/wiki/Aage_Bohr', 'name': 'Aage Bohr'},
#   {'href': '/wiki/Ben_Roy_Mottelson', 'name': 'Ben Roy Mottelson'},
#   {'href': '/wiki/James_Rainwater', 'name': 'James Rainwater'},
#   {'href': '/wiki/John_Cornforth', 'name': 'John Cornforth'},
#   {'href': '/wiki/Vladimir_Prelog', 'name': 'Vladimir Prelog'},
#   {'href': '/wiki/David_Baltimore', 'name': 'David Baltimore'},
#   {'href': '/wiki/Renato_Dulbecco', 'name': 'Renato Dulbecco'},
#   {'href': '/wiki/Howard_Martin_Temin', 'name': 'Howard Martin Temin'},
#   {'href': '/wiki/Eugenio_Montale', 'name': 'Eugenio Montale'},
#   {'href': '/wiki/Andrei_Sakharov', 'name': 'Andrei Sakharov'},
#   {'href': '/wiki/Leonid_Kantorovich', 'name': 'Leonid Kantorovich'},
#   {'href': '/wiki/Tjalling_Koopmans', 'name': 'Tjalling Koopmans'}],
#  '1976': [{'href': '/wiki/Burton_Richter', 'name': 'Burton Richter'},
#   {'href': '/wiki/Samuel_C._C._Ting', 'name': 'Samuel C. C. Ting'},
#   {'href': '/wiki/William_Lipscomb', 'name': 'William Lipscomb'},
#   {'href': '/wiki/Baruch_Samuel_Blumberg', 'name': 'Baruch Samuel Blumberg'},
#   {'href': '/wiki/Daniel_Carleton_Gajdusek',
#    'name': 'Daniel Carleton Gajdusek'},
#   {'href': '/wiki/Saul_Bellow', 'name': 'Saul Bellow'},
#   {'href': '/wiki/Betty_Williams_(Nobel_laureate)', 'name': 'Betty Williams'},
#   {'href': '/wiki/Mairead_Maguire', 'name': 'Mairead Maguire'},
#   {'href': '/wiki/Milton_Friedman', 'name': 'Milton Friedman'}],
#  '1977': [{'href': '/wiki/Philip_Warren_Anderson',
#    'name': 'Philip Warren Anderson'},
#   {'href': '/wiki/Nevill_Francis_Mott', 'name': 'Nevill Francis Mott'},
#   {'href': '/wiki/John_Hasbrouck_Van_Vleck',
#    'name': 'John Hasbrouck Van Vleck'},
#   {'href': '/wiki/Ilya_Prigogine', 'name': 'Ilya Prigogine'},
#   {'href': '/wiki/Roger_Guillemin', 'name': 'Roger Guillemin'},
#   {'href': '/wiki/Andrew_Schally', 'name': 'Andrew Schally'},
#   {'href': '/wiki/Rosalyn_Sussman_Yalow', 'name': 'Rosalyn Sussman Yalow'},
#   {'href': '/wiki/Vicente_Aleixandre', 'name': 'Vicente Aleixandre'},
#   {'href': '/wiki/Amnesty_International', 'name': 'Amnesty International'},
#   {'href': '/wiki/Bertil_Ohlin', 'name': 'Bertil Ohlin'},
#   {'href': '/wiki/James_Meade', 'name': 'James Meade'}],
#  '1978': [{'href': '/wiki/Pyotr_Kapitsa', 'name': 'Pyotr Kapitsa'},
#   {'href': '/wiki/Arno_Allan_Penzias', 'name': 'Arno Allan Penzias'},
#   {'href': '/wiki/Robert_Woodrow_Wilson', 'name': 'Robert Woodrow Wilson'},
#   {'href': '/wiki/Peter_D._Mitchell', 'name': 'Peter D. Mitchell'},
#   {'href': '/wiki/Werner_Arber', 'name': 'Werner Arber'},
#   {'href': '/wiki/Daniel_Nathans', 'name': 'Daniel Nathans'},
#   {'href': '/wiki/Hamilton_O._Smith', 'name': 'Hamilton O. Smith'},
#   {'href': '/wiki/Isaac_Bashevis_Singer', 'name': 'Isaac Bashevis Singer'},
#   {'href': '/wiki/Anwar_Sadat', 'name': 'Anwar Sadat'},
#   {'href': '/wiki/Menachem_Begin', 'name': 'Menachem Begin'},
#   {'href': '/wiki/Herbert_A._Simon', 'name': 'Herbert A. Simon'}],
#  '1979': [{'href': '/wiki/Sheldon_Lee_Glashow', 'name': 'Sheldon Lee Glashow'},
#   {'href': '/wiki/Abdus_Salam', 'name': 'Abdus Salam'},
#   {'href': '/wiki/Steven_Weinberg', 'name': 'Steven Weinberg'},
#   {'href': '/wiki/Herbert_C._Brown', 'name': 'Herbert C. Brown'},
#   {'href': '/wiki/Georg_Wittig', 'name': 'Georg Wittig'},
#   {'href': '/wiki/Allan_McLeod_Cormack', 'name': 'Allan McLeod Cormack'},
#   {'href': '/wiki/Godfrey_Hounsfield', 'name': 'Godfrey Hounsfield'},
#   {'href': '/wiki/Odysseas_Elytis', 'name': 'Odysseas Elytis'},
#   {'href': '/wiki/Mother_Teresa', 'name': 'Mother Teresa'},
#   {'href': '/wiki/Theodore_Schultz', 'name': 'Theodore Schultz'},
#   {'href': '/wiki/Arthur_Lewis_(economist)', 'name': 'Arthur Lewis'}],
#  '1980': [{'href': '/wiki/James_Cronin', 'name': 'James Cronin'},
#   {'href': '/wiki/Val_Logsdon_Fitch', 'name': 'Val Logsdon Fitch'},
#   {'href': '/wiki/Paul_Berg', 'name': 'Paul Berg'},
#   {'href': '/wiki/Walter_Gilbert', 'name': 'Walter Gilbert'},
#   {'href': '/wiki/Frederick_Sanger', 'name': 'Frederick Sanger'},
#   {'href': '/wiki/Baruj_Benacerraf', 'name': 'Baruj Benacerraf'},
#   {'href': '/wiki/Jean_Dausset', 'name': 'Jean Dausset'},
#   {'href': '/wiki/George_Davis_Snell', 'name': 'George Davis Snell'},
#   {'href': '/wiki/Czes%C5%82aw_Mi%C5%82osz', 'name': 'Czesław Miłosz'},
#   {'href': '/wiki/Adolfo_P%C3%A9rez_Esquivel',
#    'name': 'Adolfo Pérez Esquivel'},
#   {'href': '/wiki/Lawrence_Klein', 'name': 'Lawrence Klein'}],
#  '1981': [{'href': '/wiki/Nicolaas_Bloembergen',
#    'name': 'Nicolaas Bloembergen'},
#   {'href': '/wiki/Arthur_Leonard_Schawlow', 'name': 'Arthur Leonard Schawlow'},
#   {'href': '/wiki/Kai_Siegbahn', 'name': 'Kai Siegbahn'},
#   {'href': '/wiki/Kenichi_Fukui', 'name': 'Kenichi Fukui'},
#   {'href': '/wiki/Roald_Hoffmann', 'name': 'Roald Hoffmann'},
#   {'href': '/wiki/Roger_Wolcott_Sperry', 'name': 'Roger Wolcott Sperry'},
#   {'href': '/wiki/David_H._Hubel', 'name': 'David H. Hubel'},
#   {'href': '/wiki/Torsten_Wiesel', 'name': 'Torsten Wiesel'},
#   {'href': '/wiki/Elias_Canetti', 'name': 'Elias Canetti'},
#   {'href': '/wiki/United_Nations_High_Commissioner_for_Refugees',
#    'name': 'United Nations High Commissioner for Refugees'},
#   {'href': '/wiki/James_Tobin', 'name': 'James Tobin'}],
#  '1982': [{'href': '/wiki/Kenneth_G._Wilson', 'name': 'Kenneth G. Wilson'},
#   {'href': '/wiki/Aaron_Klug', 'name': 'Aaron Klug'},
#   {'href': '/wiki/Sune_Bergstr%C3%B6m', 'name': 'Sune Bergström'},
#   {'href': '/wiki/Bengt_I._Samuelsson', 'name': 'Bengt I. Samuelsson'},
#   {'href': '/wiki/John_Vane', 'name': 'John Vane'},
#   {'href': '/wiki/Gabriel_Garc%C3%ADa_M%C3%A1rquez',
#    'name': 'Gabriel García Márquez'},
#   {'href': '/wiki/Alva_Myrdal', 'name': 'Alva Myrdal'},
#   {'href': '/wiki/Alfonso_Garc%C3%ADa_Robles',
#    'name': 'Alfonso García Robles'},
#   {'href': '/wiki/George_Stigler', 'name': 'George Stigler'}],
#  '1983': [{'href': '/wiki/Subrahmanyan_Chandrasekhar',
#    'name': 'Subrahmanyan Chandrasekhar'},
#   {'href': '/wiki/William_Alfred_Fowler', 'name': 'William Alfred Fowler'},
#   {'href': '/wiki/Henry_Taube', 'name': 'Henry Taube'},
#   {'href': '/wiki/Barbara_McClintock', 'name': 'Barbara McClintock'},
#   {'href': '/wiki/William_Golding', 'name': 'William Golding'},
#   {'href': '/wiki/Lech_Wa%C5%82%C4%99sa', 'name': 'Lech Wałęsa'},
#   {'href': '/wiki/G%C3%A9rard_Debreu', 'name': 'Gérard Debreu'}],
#  '1984': [{'href': '/wiki/Carlo_Rubbia', 'name': 'Carlo Rubbia'},
#   {'href': '/wiki/Simon_van_der_Meer', 'name': 'Simon van der Meer'},
#   {'href': '/wiki/Robert_Bruce_Merrifield', 'name': 'Robert Bruce Merrifield'},
#   {'href': '/wiki/Niels_Kaj_Jerne', 'name': 'Niels Kaj Jerne'},
#   {'href': '/wiki/Georges_J._F._K%C3%B6hler', 'name': 'Georges J. F. Köhler'},
#   {'href': '/wiki/C%C3%A9sar_Milstein', 'name': 'César Milstein'},
#   {'href': '/wiki/Jaroslav_Seifert', 'name': 'Jaroslav Seifert'},
#   {'href': '/wiki/Desmond_Tutu', 'name': 'Desmond Tutu'},
#   {'href': '/wiki/Richard_Stone', 'name': 'Richard Stone'}],
#  '1985': [{'href': '/wiki/Klaus_von_Klitzing', 'name': 'Klaus von Klitzing'},
#   {'href': '/wiki/Herbert_A._Hauptman', 'name': 'Herbert A. Hauptman'},
#   {'href': '/wiki/Jerome_Karle', 'name': 'Jerome Karle'},
#   {'href': '/wiki/Michael_Stuart_Brown', 'name': 'Michael Stuart Brown'},
#   {'href': '/wiki/Joseph_L._Goldstein', 'name': 'Joseph L. Goldstein'},
#   {'href': '/wiki/Claude_Simon', 'name': 'Claude Simon'},
#   {'href': '/wiki/International_Physicians_for_the_Prevention_of_Nuclear_War',
#    'name': 'International Physicians for the Prevention of Nuclear War'},
#   {'href': '/wiki/Franco_Modigliani', 'name': 'Franco Modigliani'}],
#  '1986': [{'href': '/wiki/Ernst_Ruska', 'name': 'Ernst Ruska'},
#   {'href': '/wiki/Gerd_Binnig', 'name': 'Gerd Binnig'},
#   {'href': '/wiki/Heinrich_Rohrer', 'name': 'Heinrich Rohrer'},
#   {'href': '/wiki/Dudley_R._Herschbach', 'name': 'Dudley R. Herschbach'},
#   {'href': '/wiki/Yuan_T._Lee', 'name': 'Yuan T. Lee'},
#   {'href': '/wiki/John_Polanyi', 'name': 'John Polanyi'},
#   {'href': '/wiki/Stanley_Cohen_(biochemist)', 'name': 'Stanley Cohen'},
#   {'href': '/wiki/Rita_Levi-Montalcini', 'name': 'Rita Levi-Montalcini'},
#   {'href': '/wiki/Wole_Soyinka', 'name': 'Wole Soyinka'},
#   {'href': '/wiki/Elie_Wiesel', 'name': 'Elie Wiesel'},
#   {'href': '/wiki/James_M._Buchanan', 'name': 'James M. Buchanan'}],
#  '1987': [{'href': '/wiki/Johannes_Georg_Bednorz',
#    'name': 'Johannes Georg Bednorz'},
#   {'href': '/wiki/Karl_Alexander_M%C3%BCller',
#    'name': 'Karl Alexander Müller'},
#   {'href': '/wiki/Donald_J._Cram', 'name': 'Donald J. Cram'},
#   {'href': '/wiki/Jean-Marie_Lehn', 'name': 'Jean-Marie Lehn'},
#   {'href': '/wiki/Charles_J._Pedersen', 'name': 'Charles J. Pedersen'},
#   {'href': '/wiki/Susumu_Tonegawa', 'name': 'Susumu Tonegawa'},
#   {'href': '/wiki/Joseph_Brodsky', 'name': 'Joseph Brodsky'},
#   {'href': '/wiki/%C3%93scar_Arias', 'name': 'Óscar Arias'},
#   {'href': '/wiki/Robert_Solow', 'name': 'Robert Solow'}],
#  '1988': [{'href': '/wiki/Leon_M._Lederman', 'name': 'Leon M. Lederman'},
#   {'href': '/wiki/Melvin_Schwartz', 'name': 'Melvin Schwartz'},
#   {'href': '/wiki/Jack_Steinberger', 'name': 'Jack Steinberger'},
#   {'href': '/wiki/Johann_Deisenhofer', 'name': 'Johann Deisenhofer'},
#   {'href': '/wiki/Robert_Huber', 'name': 'Robert Huber'},
#   {'href': '/wiki/Hartmut_Michel', 'name': 'Hartmut Michel'},
#   {'href': '/wiki/James_W._Black', 'name': 'James W. Black'},
#   {'href': '/wiki/Gertrude_B._Elion', 'name': 'Gertrude B. Elion'},
#   {'href': '/wiki/George_H._Hitchings', 'name': 'George H. Hitchings'},
#   {'href': '/wiki/Naguib_Mahfouz', 'name': 'Naguib Mahfouz'},
#   {'href': '/wiki/United_Nations_peacekeeping',
#    'name': 'United Nations Peace-Keeping Forces'},
#   {'href': '/wiki/Maurice_Allais', 'name': 'Maurice Allais'}],
#  '1989': [{'href': '/wiki/Norman_Foster_Ramsey,_Jr.',
#    'name': 'Norman Foster Ramsey, Jr.'},
#   {'href': '/wiki/Hans_Georg_Dehmelt', 'name': 'Hans Georg Dehmelt'},
#   {'href': '/wiki/Wolfgang_Paul', 'name': 'Wolfgang Paul'},
#   {'href': '/wiki/Sidney_Altman', 'name': 'Sidney Altman'},
#   {'href': '/wiki/Thomas_Cech', 'name': 'Thomas Cech'},
#   {'href': '/wiki/J._Michael_Bishop', 'name': 'J. Michael Bishop'},
#   {'href': '/wiki/Harold_E._Varmus', 'name': 'Harold E. Varmus'},
#   {'href': '/wiki/Camilo_Jos%C3%A9_Cela', 'name': 'Camilo José Cela'},
#   {'href': '/wiki/14th_Dalai_Lama', 'name': 'Tenzin Gyatso (The Dalai Lama)'},
#   {'href': '/wiki/Trygve_Haavelmo', 'name': 'Trygve Haavelmo'}],
#  '1990': [{'href': '/wiki/Jerome_Isaac_Friedman',
#    'name': 'Jerome Isaac Friedman'},
#   {'href': '/wiki/Henry_Way_Kendall', 'name': 'Henry Way Kendall'},
#   {'href': '/wiki/Richard_E._Taylor', 'name': 'Richard E. Taylor'},
#   {'href': '/wiki/Elias_James_Corey', 'name': 'Elias James Corey'},
#   {'href': '/wiki/Joseph_Murray', 'name': 'Joseph Murray'},
#   {'href': '/wiki/E._Donnall_Thomas', 'name': 'E. Donnall Thomas'},
#   {'href': '/wiki/Octavio_Paz', 'name': 'Octavio Paz'},
#   {'href': '/wiki/Mikhail_Gorbachev', 'name': 'Mikhail Gorbachev'},
#   {'href': '/wiki/Harry_Markowitz', 'name': 'Harry Markowitz'},
#   {'href': '/wiki/Merton_Miller', 'name': 'Merton Miller'},
#   {'href': '/wiki/William_F._Sharpe', 'name': 'William F. Sharpe'}],
#  '1991': [{'href': '/wiki/Pierre-Gilles_de_Gennes',
#    'name': 'Pierre-Gilles de Gennes'},
#   {'href': '/wiki/Richard_R._Ernst', 'name': 'Richard R. Ernst'},
#   {'href': '/wiki/Erwin_Neher', 'name': 'Erwin Neher'},
#   {'href': '/wiki/Bert_Sakmann', 'name': 'Bert Sakmann'},
#   {'href': '/wiki/Nadine_Gordimer', 'name': 'Nadine Gordimer'},
#   {'href': '/wiki/Aung_San_Suu_Kyi', 'name': 'Aung San Suu Kyi'},
#   {'href': '/wiki/Ronald_Coase', 'name': 'Ronald Coase'}],
#  '1992': [{'href': '/wiki/Georges_Charpak', 'name': 'Georges Charpak'},
#   {'href': '/wiki/Rudolph_A._Marcus', 'name': 'Rudolph A. Marcus'},
#   {'href': '/wiki/Edmond_H._Fischer', 'name': 'Edmond H. Fischer'},
#   {'href': '/wiki/Edwin_G._Krebs', 'name': 'Edwin G. Krebs'},
#   {'href': '/wiki/Derek_Walcott', 'name': 'Derek Walcott'},
#   {'href': '/wiki/Rigoberta_Mench%C3%BA', 'name': 'Rigoberta Menchú'},
#   {'href': '/wiki/Gary_Becker', 'name': 'Gary Becker'}],
#  '1993': [{'href': '/wiki/Russell_Alan_Hulse', 'name': 'Russell Alan Hulse'},
#   {'href': '/wiki/Joseph_Hooton_Taylor,_Jr.',
#    'name': 'Joseph Hooton Taylor, Jr.'},
#   {'href': '/wiki/Kary_Mullis', 'name': 'Kary Mullis'},
#   {'href': '/wiki/Michael_Smith_(chemist)', 'name': 'Michael Smith'},
#   {'href': '/wiki/Richard_J._Roberts', 'name': 'Richard J. Roberts'},
#   {'href': '/wiki/Phillip_Allen_Sharp', 'name': 'Phillip Allen Sharp'},
#   {'href': '/wiki/Toni_Morrison', 'name': 'Toni Morrison'},
#   {'href': '/wiki/Nelson_Mandela', 'name': 'Nelson Mandela'},
#   {'href': '/wiki/F._W._de_Klerk', 'name': 'F. W. de Klerk'},
#   {'href': '/wiki/Robert_Fogel', 'name': 'Robert Fogel'},
#   {'href': '/wiki/Douglass_North', 'name': 'Douglass North'}],
#  '1994': [{'href': '/wiki/Bertram_Brockhouse', 'name': 'Bertram Brockhouse'},
#   {'href': '/wiki/Clifford_Shull', 'name': 'Clifford Shull'},
#   {'href': '/wiki/George_Andrew_Olah', 'name': 'George Andrew Olah'},
#   {'href': '/wiki/Alfred_G._Gilman', 'name': 'Alfred G. Gilman'},
#   {'href': '/wiki/Martin_Rodbell', 'name': 'Martin Rodbell'},
#   {'href': '/wiki/Kenzabur%C5%8D_%C5%8Ce', 'name': 'Kenzaburō Ōe'},
#   {'href': '/wiki/Yasser_Arafat', 'name': 'Yasser Arafat'},
#   {'href': '/wiki/Shimon_Peres', 'name': 'Shimon Peres'},
#   {'href': '/wiki/Yitzhak_Rabin', 'name': 'Yitzhak Rabin'},
#   {'href': '/wiki/John_Harsanyi', 'name': 'John Harsanyi'},
#   {'href': '/wiki/John_Forbes_Nash,_Jr.', 'name': 'John Forbes Nash, Jr.'},
#   {'href': '/wiki/Reinhard_Selten', 'name': 'Reinhard Selten'}],
#  '1995': [{'href': '/wiki/Martin_Lewis_Perl', 'name': 'Martin Lewis Perl'},
#   {'href': '/wiki/Frederick_Reines', 'name': 'Frederick Reines'},
#   {'href': '/wiki/Paul_J._Crutzen', 'name': 'Paul J. Crutzen'},
#   {'href': '/wiki/Mario_J._Molina', 'name': 'Mario J. Molina'},
#   {'href': '/wiki/Frank_Sherwood_Rowland', 'name': 'Frank Sherwood Rowland'},
#   {'href': '/wiki/Edward_B._Lewis', 'name': 'Edward B. Lewis'},
#   {'href': '/wiki/Christiane_N%C3%BCsslein-Volhard',
#    'name': 'Christiane Nüsslein-Volhard'},
#   {'href': '/wiki/Eric_F._Wieschaus', 'name': 'Eric F. Wieschaus'},
#   {'href': '/wiki/Seamus_Heaney', 'name': 'Seamus Heaney'},
#   {'href': '/wiki/Joseph_Rotblat', 'name': 'Joseph Rotblat'},
#   {'href': '/wiki/Pugwash_Conferences_on_Science_and_World_Affairs',
#    'name': 'Pugwash Conferences on Science and World Affairs'},
#   {'href': '/wiki/Robert_Lucas,_Jr.', 'name': 'Robert Lucas, Jr.'}],
#  '1996': [{'href': '/wiki/David_Lee_(physicist)', 'name': 'David Lee'},
#   {'href': '/wiki/Douglas_Osheroff', 'name': 'Douglas Osheroff'},
#   {'href': '/wiki/Robert_Coleman_Richardson',
#    'name': 'Robert Coleman Richardson'},
#   {'href': '/wiki/Robert_Curl', 'name': 'Robert F. Curl Jr.'},
#   {'href': '/wiki/Harry_Kroto', 'name': 'Harry Kroto'},
#   {'href': '/wiki/Richard_Smalley', 'name': 'Richard Smalley'},
#   {'href': '/wiki/Peter_C._Doherty', 'name': 'Peter C. Doherty'},
#   {'href': '/wiki/Rolf_M._Zinkernagel', 'name': 'Rolf M. Zinkernagel'},
#   {'href': '/wiki/Wis%C5%82awa_Szymborska', 'name': 'Wisława Szymborska'},
#   {'href': '/wiki/Carlos_Filipe_Ximenes_Belo',
#    'name': 'Carlos Filipe Ximenes Belo'},
#   {'href': '/wiki/Jos%C3%A9_Ramos-Horta', 'name': 'José Ramos-Horta'},
#   {'href': '/wiki/James_Mirrlees', 'name': 'James Mirrlees'},
#   {'href': '/wiki/William_Vickrey', 'name': 'William Vickrey'}],
#  '1997': [{'href': '/wiki/Steven_Chu', 'name': 'Steven Chu'},
#   {'href': '/wiki/Claude_Cohen-Tannoudji', 'name': 'Claude Cohen-Tannoudji'},
#   {'href': '/wiki/William_Daniel_Phillips', 'name': 'William Daniel Phillips'},
#   {'href': '/wiki/Paul_D._Boyer', 'name': 'Paul D. Boyer'},
#   {'href': '/wiki/John_E._Walker', 'name': 'John E. Walker'},
#   {'href': '/wiki/Jens_Christian_Skou', 'name': 'Jens Christian Skou'},
#   {'href': '/wiki/Stanley_B._Prusiner', 'name': 'Stanley B. Prusiner'},
#   {'href': '/wiki/Dario_Fo', 'name': 'Dario Fo'},
#   {'href': '/wiki/International_Campaign_to_Ban_Landmines',
#    'name': 'International Campaign to Ban Landmines'},
#   {'href': '/wiki/Jody_Williams', 'name': 'Jody Williams'},
#   {'href': '/wiki/Robert_C._Merton', 'name': 'Robert C. Merton'},
#   {'href': '/wiki/Myron_Scholes', 'name': 'Myron Scholes'}],
#  '1998': [{'href': '/wiki/Robert_B._Laughlin', 'name': 'Robert B. Laughlin'},
#   {'href': '/wiki/Horst_Ludwig_St%C3%B6rmer', 'name': 'Horst Ludwig Störmer'},
#   {'href': '/wiki/Daniel_C._Tsui', 'name': 'Daniel C. Tsui'},
#   {'href': '/wiki/Walter_Kohn', 'name': 'Walter Kohn'},
#   {'href': '/wiki/John_Pople', 'name': 'John Pople'},
#   {'href': '/wiki/Robert_F._Furchgott', 'name': 'Robert F. Furchgott'},
#   {'href': '/wiki/Louis_Ignarro', 'name': 'Louis Ignarro'},
#   {'href': '/wiki/Ferid_Murad', 'name': 'Ferid Murad'},
#   {'href': '/wiki/Jos%C3%A9_Saramago', 'name': 'José Saramago'},
#   {'href': '/wiki/John_Hume', 'name': 'John Hume'},
#   {'href': '/wiki/David_Trimble', 'name': 'David Trimble'},
#   {'href': '/wiki/Amartya_Sen', 'name': 'Amartya Sen'}],
#  '1999': [{'href': '/wiki/Gerard_%27t_Hooft', 'name': "Gerard 't Hooft"},
#   {'href': '/wiki/Martinus_J._G._Veltman', 'name': 'Martinus J. G. Veltman'},
#   {'href': '/wiki/Ahmed_Zewail', 'name': 'Ahmed Zewail'},
#   {'href': '/wiki/G%C3%BCnter_Blobel', 'name': 'Günter Blobel'},
#   {'href': '/wiki/G%C3%BCnter_Grass', 'name': 'Günter Grass'},
#   {'href': '/wiki/M%C3%A9decins_Sans_Fronti%C3%A8res',
#    'name': 'Médecins Sans Frontières'},
#   {'href': '/wiki/Robert_Mundell', 'name': 'Robert Mundell'}],
#  '2000': [{'href': '/wiki/Zhores_Alferov', 'name': 'Zhores Alferov'},
#   {'href': '/wiki/Herbert_Kroemer', 'name': 'Herbert Kroemer'},
#   {'href': '/wiki/Jack_Kilby', 'name': 'Jack Kilby'},
#   {'href': '/wiki/Alan_J._Heeger', 'name': 'Alan J. Heeger'},
#   {'href': '/wiki/Alan_MacDiarmid', 'name': 'Alan MacDiarmid'},
#   {'href': '/wiki/Hideki_Shirakawa', 'name': 'Hideki Shirakawa'},
#   {'href': '/wiki/Arvid_Carlsson', 'name': 'Arvid Carlsson'},
#   {'href': '/wiki/Paul_Greengard', 'name': 'Paul Greengard'},
#   {'href': '/wiki/Eric_Kandel', 'name': 'Eric Kandel'},
#   {'href': '/wiki/Gao_Xingjian', 'name': 'Gao Xingjian'},
#   {'href': '/wiki/Kim_Dae-jung', 'name': 'Kim Dae-jung'},
#   {'href': '/wiki/James_Heckman', 'name': 'James Heckman'},
#   {'href': '/wiki/Daniel_McFadden', 'name': 'Daniel McFadden'}],
#  '2001': [{'href': '/wiki/Eric_Allin_Cornell', 'name': 'Eric Allin Cornell'},
#   {'href': '/wiki/Wolfgang_Ketterle', 'name': 'Wolfgang Ketterle'},
#   {'href': '/wiki/Carl_Wieman', 'name': 'Carl Wieman'},
#   {'href': '/wiki/William_Standish_Knowles',
#    'name': 'William Standish Knowles'},
#   {'href': '/wiki/Ry%C5%8Dji_Noyori', 'name': 'Ryōji Noyori'},
#   {'href': '/wiki/Karl_Barry_Sharpless', 'name': 'Karl Barry Sharpless'},
#   {'href': '/wiki/Leland_H._Hartwell', 'name': 'Leland H. Hartwell'},
#   {'href': '/wiki/Tim_Hunt', 'name': 'Tim Hunt'},
#   {'href': '/wiki/Paul_Nurse', 'name': 'Paul Nurse'},
#   {'href': '/wiki/V._S._Naipaul', 'name': 'V. S. Naipaul'},
#   {'href': '/wiki/United_Nations', 'name': 'United Nations'},
#   {'href': '/wiki/Kofi_Annan', 'name': 'Kofi Annan'},
#   {'href': '/wiki/George_Akerlof', 'name': 'George Akerlof'},
#   {'href': '/wiki/Michael_Spence', 'name': 'Michael Spence'},
#   {'href': '/wiki/Joseph_Stiglitz', 'name': 'Joseph Stiglitz'}],
#  '2002': [{'href': '/wiki/Raymond_Davis,_Jr.', 'name': 'Raymond Davis, Jr.'},
#   {'href': '/wiki/Masatoshi_Koshiba', 'name': 'Masatoshi Koshiba'},
#   {'href': '/wiki/Riccardo_Giacconi', 'name': 'Riccardo Giacconi'},
#   {'href': '/wiki/John_Fenn_(chemist)', 'name': 'John Fenn'},
#   {'href': '/wiki/Koichi_Tanaka', 'name': 'Koichi Tanaka'},
#   {'href': '/wiki/Kurt_W%C3%BCthrich', 'name': 'Kurt Wüthrich'},
#   {'href': '/wiki/Sydney_Brenner', 'name': 'Sydney Brenner'},
#   {'href': '/wiki/H._Robert_Horvitz', 'name': 'H. Robert Horvitz'},
#   {'href': '/wiki/John_Sulston', 'name': 'John Sulston'},
#   {'href': '/wiki/Imre_Kert%C3%A9sz', 'name': 'Imre Kertész'},
#   {'href': '/wiki/Jimmy_Carter', 'name': 'Jimmy Carter'},
#   {'href': '/wiki/Daniel_Kahneman', 'name': 'Daniel Kahneman'},
#   {'href': '/wiki/Vernon_L._Smith', 'name': 'Vernon L. Smith'}],
#  '2003': [{'href': '/wiki/Alexei_Alexeyevich_Abrikosov',
#    'name': 'Alexei Alexeyevich Abrikosov'},
#   {'href': '/wiki/Vitaly_Ginzburg', 'name': 'Vitaly Ginzburg'},
#   {'href': '/wiki/Anthony_James_Leggett', 'name': 'Anthony James Leggett'},
#   {'href': '/wiki/Peter_Agre', 'name': 'Peter Agre'},
#   {'href': '/wiki/Roderick_MacKinnon', 'name': 'Roderick MacKinnon'},
#   {'href': '/wiki/Paul_Lauterbur', 'name': 'Paul Lauterbur'},
#   {'href': '/wiki/Peter_Mansfield', 'name': 'Peter Mansfield'},
#   {'href': '/wiki/J._M._Coetzee', 'name': 'J. M. Coetzee'},
#   {'href': '/wiki/Shirin_Ebadi', 'name': 'Shirin Ebadi'},
#   {'href': '/wiki/Robert_F._Engle', 'name': 'Robert F. Engle'},
#   {'href': '/wiki/Clive_Granger', 'name': 'Clive Granger'}],
#  '2004': [{'href': '/wiki/David_Gross', 'name': 'David Gross'},
#   {'href': '/wiki/Hugh_David_Politzer', 'name': 'Hugh David Politzer'},
#   {'href': '/wiki/Frank_Wilczek', 'name': 'Frank Wilczek'},
#   {'href': '/wiki/Aaron_Ciechanover', 'name': 'Aaron Ciechanover'},
#   {'href': '/wiki/Avram_Hershko', 'name': 'Avram Hershko'},
#   {'href': '/wiki/Irwin_Rose', 'name': 'Irwin Rose'},
#   {'href': '/wiki/Richard_Axel', 'name': 'Richard Axel'},
#   {'href': '/wiki/Linda_B._Buck', 'name': 'Linda B. Buck'},
#   {'href': '/wiki/Elfriede_Jelinek', 'name': 'Elfriede Jelinek'},
#   {'href': '/wiki/Wangari_Maathai', 'name': 'Wangari Maathai'},
#   {'href': '/wiki/Finn_E._Kydland', 'name': 'Finn E. Kydland'},
#   {'href': '/wiki/Edward_C._Prescott', 'name': 'Edward C. Prescott'}],
#  '2005': [{'href': '/wiki/Roy_J._Glauber', 'name': 'Roy J. Glauber'},
#   {'href': '/wiki/John_L._Hall', 'name': 'John L. Hall'},
#   {'href': '/wiki/Theodor_W._H%C3%A4nsch', 'name': 'Theodor W. Hänsch'},
#   {'href': '/wiki/Yves_Chauvin', 'name': 'Yves Chauvin'},
#   {'href': '/wiki/Robert_H._Grubbs', 'name': 'Robert H. Grubbs'},
#   {'href': '/wiki/Richard_R._Schrock', 'name': 'Richard R. Schrock'},
#   {'href': '/wiki/Barry_Marshall', 'name': 'Barry Marshall'},
#   {'href': '/wiki/Robin_Warren', 'name': 'Robin Warren'},
#   {'href': '/wiki/Harold_Pinter', 'name': 'Harold Pinter'},
#   {'href': '/wiki/International_Atomic_Energy_Agency',
#    'name': 'International Atomic Energy Agency'},
#   {'href': '/wiki/Mohamed_ElBaradei', 'name': 'Mohamed ElBaradei'},
#   {'href': '/wiki/Robert_Aumann', 'name': 'Robert Aumann'},
#   {'href': '/wiki/Thomas_Schelling', 'name': 'Thomas Schelling'}],
#  '2006': [{'href': '/wiki/John_C._Mather', 'name': 'John C. Mather'},
#   {'href': '/wiki/George_Smoot', 'name': 'George Smoot'},
#   {'href': '/wiki/Roger_D._Kornberg', 'name': 'Roger D. Kornberg'},
#   {'href': '/wiki/Andrew_Fire', 'name': 'Andrew Fire'},
#   {'href': '/wiki/Craig_Mello', 'name': 'Craig Mello'},
#   {'href': '/wiki/Orhan_Pamuk', 'name': 'Orhan Pamuk'},
#   {'href': '/wiki/Muhammad_Yunus', 'name': 'Muhammad Yunus'},
#   {'href': '/wiki/Grameen_Bank', 'name': 'Grameen Bank'},
#   {'href': '/wiki/Edmund_Phelps', 'name': 'Edmund Phelps'}],
#  '2007': [{'href': '/wiki/Albert_Fert', 'name': 'Albert Fert'},
#   {'href': '/wiki/Peter_Gr%C3%BCnberg', 'name': 'Peter Grünberg'},
#   {'href': '/wiki/Gerhard_Ertl', 'name': 'Gerhard Ertl'},
#   {'href': '/wiki/Mario_Capecchi', 'name': 'Mario Capecchi'},
#   {'href': '/wiki/Martin_Evans', 'name': 'Martin Evans'},
#   {'href': '/wiki/Oliver_Smithies', 'name': 'Oliver Smithies'},
#   {'href': '/wiki/Doris_Lessing', 'name': 'Doris Lessing'},
#   {'href': '/wiki/Intergovernmental_Panel_on_Climate_Change',
#    'name': 'Intergovernmental Panel on Climate Change'},
#   {'href': '/wiki/Al_Gore', 'name': 'Al Gore'},
#   {'href': '/wiki/Leonid_Hurwicz', 'name': 'Leonid Hurwicz'},
#   {'href': '/wiki/Eric_Maskin', 'name': 'Eric Maskin'},
#   {'href': '/wiki/Roger_Myerson', 'name': 'Roger Myerson'}],
#  '2008': [{'href': '/wiki/Yoichiro_Nambu', 'name': 'Yoichiro Nambu'},
#   {'href': '/wiki/Makoto_Kobayashi_(physicist)', 'name': 'Makoto Kobayashi'},
#   {'href': '/wiki/Toshihide_Maskawa', 'name': 'Toshihide Maskawa'},
#   {'href': '/wiki/Osamu_Shimomura', 'name': 'Osamu Shimomura'},
#   {'href': '/wiki/Martin_Chalfie', 'name': 'Martin Chalfie'},
#   {'href': '/wiki/Roger_Y._Tsien', 'name': 'Roger Y. Tsien'},
#   {'href': '/wiki/Harald_zur_Hausen', 'name': 'Harald zur Hausen'},
#   {'href': '/wiki/Fran%C3%A7oise_Barr%C3%A9-Sinoussi',
#    'name': 'Françoise Barré-Sinoussi'},
#   {'href': '/wiki/Luc_Montagnier', 'name': 'Luc Montagnier'},
#   {'href': '/wiki/J._M._G._Le_Cl%C3%A9zio', 'name': 'J. M. G. Le Clézio'},
#   {'href': '/wiki/Martti_Ahtisaari', 'name': 'Martti Ahtisaari'},
#   {'href': '/wiki/Paul_Krugman', 'name': 'Paul Krugman'}],
#  '2009': [{'href': '/wiki/Charles_K._Kao', 'name': 'Charles K. Kao'},
#   {'href': '/wiki/Willard_Boyle', 'name': 'Willard S. Boyle'},
#   {'href': '/wiki/George_E._Smith', 'name': 'George E. Smith'},
#   {'href': '/wiki/Venkatraman_Ramakrishnan',
#    'name': 'Venkatraman Ramakrishnan'},
#   {'href': '/wiki/Thomas_A._Steitz', 'name': 'Thomas A. Steitz'},
#   {'href': '/wiki/Ada_Yonath', 'name': 'Ada Yonath'},
#   {'href': '/wiki/Elizabeth_Blackburn', 'name': 'Elizabeth Blackburn'},
#   {'href': '/wiki/Carol_W._Greider', 'name': 'Carol W. Greider'},
#   {'href': '/wiki/Jack_W._Szostak', 'name': 'Jack W. Szostak'},
#   {'href': '/wiki/Herta_M%C3%BCller', 'name': 'Herta Müller'},
#   {'href': '/wiki/Barack_Obama', 'name': 'Barack Obama'},
#   {'href': '/wiki/Elinor_Ostrom', 'name': 'Elinor Ostrom'},
#   {'href': '/wiki/Oliver_E._Williamson', 'name': 'Oliver E. Williamson'}],
#  '2010': [{'href': '/wiki/Andre_Geim', 'name': 'Andre Geim'},
#   {'href': '/wiki/Konstantin_Novoselov', 'name': 'Konstantin Novoselov'},
#   {'href': '/wiki/Richard_F._Heck', 'name': 'Richard F. Heck'},
#   {'href': '/wiki/Ei-ichi_Negishi', 'name': 'Ei-ichi Negishi'},
#   {'href': '/wiki/Akira_Suzuki_(chemist)', 'name': 'Akira Suzuki'},
#   {'href': '/wiki/Robert_G._Edwards', 'name': 'Robert G. Edwards'},
#   {'href': '/wiki/Mario_Vargas_Llosa', 'name': 'Mario Vargas Llosa'},
#   {'href': '/wiki/Liu_Xiaobo', 'name': 'Liu Xiaobo'},
#   {'href': '#endnote_Note1F', 'name': '[F]'},
#   {'href': '/wiki/Peter_Diamond', 'name': 'Peter A. Diamond'},
#   {'href': '/wiki/Dale_T._Mortensen', 'name': 'Dale T. Mortensen'},
#   {'href': '/wiki/Christopher_A._Pissarides',
#    'name': 'Christopher A. Pissarides'}],
#  '2011': [{'href': '/wiki/Saul_Perlmutter', 'name': 'Saul Perlmutter'},
#   {'href': '/wiki/Adam_Riess', 'name': 'Adam G. Riess'},
#   {'href': '/wiki/Brian_Schmidt', 'name': 'Brian Schmidt'},
#   {'href': '/wiki/Dan_Shechtman', 'name': 'Dan Shechtman'},
#   {'href': '/wiki/Bruce_Beutler', 'name': 'Bruce Beutler'},
#   {'href': '/wiki/Jules_A._Hoffmann', 'name': 'Jules A. Hoffmann'},
#   {'href': '/wiki/Ralph_M._Steinman', 'name': 'Ralph M. Steinman'},
#   {'href': '/wiki/Tomas_Transtr%C3%B6mer', 'name': 'Tomas Tranströmer'},
#   {'href': '/wiki/Ellen_Johnson_Sirleaf', 'name': 'Ellen Johnson Sirleaf'},
#   {'href': '/wiki/Leymah_Gbowee', 'name': 'Leymah Gbowee'},
#   {'href': '/wiki/Tawakel_Karman', 'name': 'Tawakel Karman'},
#   {'href': '/wiki/Thomas_J._Sargent', 'name': 'Thomas J. Sargent'},
#   {'href': '/wiki/Christopher_A._Sims', 'name': 'Christopher A. Sims'}],
#  '2012': [{'href': '/wiki/Serge_Haroche', 'name': 'Serge Haroche'},
#   {'href': '/wiki/David_J._Wineland', 'name': 'David J. Wineland'},
#   {'href': '/wiki/Brian_Kobilka', 'name': 'Brian K. Kobilka'},
#   {'href': '/wiki/Robert_Lefkowitz', 'name': 'Robert J. Lefkowitz'},
#   {'href': '/wiki/John_Gurdon', 'name': 'John B. Gurdon'},
#   {'href': '/wiki/Shinya_Yamanaka', 'name': 'Shinya Yamanaka'},
#   {'href': '/wiki/Mo_Yan', 'name': 'Mo Yan'},
#   {'href': '/wiki/European_Union', 'name': 'European Union'},
#   {'href': '/wiki/Alvin_E._Roth', 'name': 'Alvin E. Roth'},
#   {'href': '/wiki/Lloyd_Shapley', 'name': 'Lloyd S. Shapley'}],
#  '2013': [{'href': '/wiki/Fran%C3%A7ois_Englert', 'name': 'François Englert'},
#   {'href': '/wiki/Peter_Higgs', 'name': 'Peter W. Higgs'},
#   {'href': '/wiki/Martin_Karplus', 'name': 'Martin Karplus'},
#   {'href': '/wiki/Michael_Levitt', 'name': 'Michael Levitt'},
#   {'href': '/wiki/Arieh_Warshel', 'name': 'Arieh Warshel'},
#   {'href': '/wiki/James_Rothman', 'name': 'James E. Rothman'},
#   {'href': '/wiki/Randy_W._Schekman', 'name': 'Randy W. Schekman'},
#   {'href': '/wiki/Thomas_C._S%C3%BCdhof', 'name': 'Thomas C. Südhof'},
#   {'href': '/wiki/Alice_Munro', 'name': 'Alice Munro'},
#   {'href': '/wiki/Organisation_for_the_Prohibition_of_Chemical_Weapons',
#    'name': 'Organisation for the Prohibition of Chemical Weapons'},
#   {'href': '/wiki/Eugene_Fama', 'name': 'Eugene F. Fama'},
#   {'href': '/wiki/Lars_Peter_Hansen', 'name': 'Lars Peter Hansen'},
#   {'href': '/wiki/Robert_Shiller', 'name': 'Robert J. Shiller'}],
#  '2014': [{'href': '/wiki/Isamu_Akasaki', 'name': 'Isamu Akasaki'},
#   {'href': '/wiki/Hiroshi_Amano', 'name': 'Hiroshi Amano'},
#   {'href': '/wiki/Shuji_Nakamura', 'name': 'Shuji Nakamura'},
#   {'href': '/wiki/Eric_Betzig', 'name': 'Eric Betzig'},
#   {'href': '/wiki/Stefan_Hell', 'name': 'Stefan Hell'},
#   {'href': '/wiki/William_Moerner', 'name': 'William Moerner'},
#   {'href': '/wiki/John_O%27Keefe_(neuroscientist)', 'name': "John O'Keefe"},
#   {'href': '/wiki/May-Britt_Moser', 'name': 'May-Britt Moser'},
#   {'href': '/wiki/Edvard_Moser', 'name': 'Edvard Moser'},
#   {'href': '/wiki/Patrick_Modiano', 'name': 'Patrick Modiano'},
#   {'href': '/wiki/Kailash_Satyarthi', 'name': 'Kailash Satyarthi'},
#   {'href': '/wiki/Malala_Yousafzai', 'name': 'Malala Yousafzai'},
#   {'href': '/wiki/Jean_Tirole', 'name': 'Jean Tirole'}],
#  '2015': [{'href': '/wiki/Takaaki_Kajita', 'name': 'Takaaki Kajita'},
#   {'href': '/wiki/Arthur_B._McDonald', 'name': 'Arthur B. McDonald'},
#   {'href': '/wiki/Tomas_Lindahl', 'name': 'Tomas Lindahl'},
#   {'href': '/wiki/Paul_Modrich', 'name': 'Paul L. Modrich'},
#   {'href': '/wiki/Aziz_Sancar', 'name': 'Aziz Sancar'},
#   {'href': '/wiki/William_C._Campbell_(scientist)',
#    'name': 'William C. Campbell'},
#   {'href': '/wiki/Satoshi_%C5%8Cmura', 'name': 'Satoshi Ōmura'},
#   {'href': '/wiki/Tu_Youyou', 'name': 'Tu Youyou'},
#   {'href': '/wiki/Svetlana_Alexievich', 'name': 'Svetlana Alexievich'},
#   {'href': '/wiki/Tunisian_National_Dialogue_Quartet',
#    'name': 'Tunisian National Dialogue Quartet'},
#   {'href': '/wiki/Angus_Deaton', 'name': 'Angus Deaton'}],
#  '2016': [{'href': '/wiki/David_J._Thouless', 'name': 'David J. Thouless'},
#   {'href': '/wiki/Duncan_Haldane', 'name': 'Duncan Haldane'},
#   {'href': '/wiki/John_M._Kosterlitz', 'name': 'John M. Kosterlitz'},
#   {'href': '/wiki/Jean-Pierre_Sauvage', 'name': 'Jean-Pierre Sauvage'},
#   {'href': '/wiki/Fraser_Stoddart', 'name': 'Fraser Stoddart'},
#   {'href': '/wiki/Ben_Feringa', 'name': 'Ben Feringa'},
#   {'href': '/wiki/Yoshinori_Ohsumi', 'name': 'Yoshinori Ohsumi'},
#   {'href': '/wiki/Bob_Dylan', 'name': 'Bob Dylan'},
#   {'href': '/wiki/Juan_Manuel_Santos', 'name': 'Juan Manuel Santos'},
#   {'href': '/wiki/Oliver_Hart_(economist)', 'name': 'Oliver Hart'},
#   {'href': '/wiki/Bengt_R._Holmstr%C3%B6m', 'name': 'Bengt R. Holmström'}],
#  '2017': [{'href': '/wiki/Rainer_Weiss', 'name': 'Rainer Weiss'},
#   {'href': '/wiki/Barry_Barish', 'name': 'Barry Barish'},
#   {'href': '/wiki/Kip_Thorne', 'name': 'Kip Thorne'},
#   {'href': '/wiki/Jacques_Dubochet', 'name': 'Jacques Dubochet'},
#   {'href': '/wiki/Joachim_Frank', 'name': 'Joachim Frank'},
#   {'href': '/wiki/Richard_Henderson_(biologist)', 'name': 'Richard Henderson'},
#   {'href': '/wiki/Jeffrey_C._Hall', 'name': 'Jeffrey C. Hall'},
#   {'href': '/wiki/Michael_Rosbash', 'name': 'Michael Rosbash'},
#   {'href': '/wiki/Michael_W._Young', 'name': 'Michael W. Young'},
#   {'href': '/wiki/Kazuo_Ishiguro', 'name': 'Kazuo Ishiguro'},
#   {'href': '/wiki/International_Campaign_to_Abolish_Nuclear_Weapons',
#    'name': 'International Campaign to Abolish Nuclear Weapons'},
#   {'href': '/wiki/Richard_Thaler', 'name': 'Richard Thaler'}]}

# %%
# Now we have urls and names for each year but we don't have any categories...
# In order to get the categories we'll use the built in enumerate function and
# loop through each cell in our td selector

# We tell the enumerate function to start counting at 1 instead of 0 (the default)
# because in our column / category list the first column, column 0, is "Year".

# Enumerate gives us an index value as we loop over a list of items:
# starting at 0
print(list(enumerate(['a', 'b', 'c'])))

# or starting at 1
print(list(enumerate(['a', 'b', 'c'], 1)))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
by_year = {}
for row in other_rows:
    try:
        year = row.css('td')[0].xpath('string()').extract()[0]
    except IndexError:
        print('error on {}'.format(row))
        continue
    # or year = row.css('td')[0].xpath('string()')[0].extract()
    if '[' in year:
        year = year.split('[')[0]

    year_data = []
    # Loop through each data cell's links
    for i, cell in enumerate(row.css('td:not(:nth-child(1))'), 1):
        # Use the index from the enumberator to lookup the category by col position
        category = col_names_links[i]["name"]
        link = cell.css('a')
        name = link.xpath('string()').extract()
        name_href = link.xpath('@href').extract()
        year_data.append({
            "name": name,
            "href": name_href,
            "category": category,
        })
    by_year[year] = year_data
by_year['1901']
# Out:
# error on <Selector xpath='descendant-or-self::tr[not(count(preceding-sibling::*) = 0)]' data='<tr>\n<th>Year</th>\n<th width="16%"><a hr'>
# [{'category': 'Physics',
#   'href': ['/wiki/Wilhelm_R%C3%B6ntgen'],
#   'name': ['Wilhelm Röntgen']},
#  {'category': 'Chemistry',
#   'href': ['/wiki/Jacobus_Henricus_van_%27t_Hoff'],
#   'name': ["Jacobus Henricus van 't Hoff"]},
#  {'category': 'Physiology or Medicine',
#   'href': ['/wiki/Emil_Adolf_von_Behring'],
#   'name': ['Emil Adolf von Behring']},
#  {'category': 'Literature',
#   'href': ['/wiki/Sully_Prudhomme'],
#   'name': ['Sully Prudhomme']},
#  {'category': 'Peace',
#   'href': ['/wiki/Henry_Dunant', '/wiki/Fr%C3%A9d%C3%A9ric_Passy'],
#   'name': ['Henry Dunant', 'Frédéric Passy']},
#  {'category': 'Economics', 'href': [], 'name': []}]

# %%
# Look closely at the data above. Look at the Peace category... we have multiple winners.
# Now we need to handle multiple people per category

# We do this by nesting another loop to go through each individual anchor element
# and adding a distinct dictionary each time

# %%
by_year = {}
for row in other_rows:
    try:
        year = row.css('td')[0].xpath('string()').extract()[0]
    except IndexError:
        print('error on {}'.format(row))
        continue
    # or year = row.css('td')[0].xpath('string()')[0].extract()
    if '[' in year:
        year = year.split('[')[0]

    year_data = []
    # Loop through each data cell's links
    for i, cell in enumerate(row.css('td:not(:nth-child(1))'), 1):
        category = col_names_links[i]["name"]
        for link in cell.css('a'):
            name = link.xpath('string()').extract()
            name_href = link.xpath('@href').extract()
            year_data.append({
                "name": name,
                "href": name_href,
                "category": category,
            })
    by_year[year] = year_data
by_year['1902']
# Out:
# error on <Selector xpath='descendant-or-self::tr[not(count(preceding-sibling::*) = 0)]' data='<tr>\n<th>Year</th>\n<th width="16%"><a hr'>
# [{'category': 'Physics',
#   'href': ['/wiki/Hendrik_Lorentz'],
#   'name': ['Hendrik Lorentz']},
#  {'category': 'Physics',
#   'href': ['/wiki/Pieter_Zeeman'],
#   'name': ['Pieter Zeeman']},
#  {'category': 'Chemistry',
#   'href': ['/wiki/Hermann_Emil_Fischer'],
#   'name': ['Hermann Emil Fischer']},
#  {'category': 'Physiology or Medicine',
#   'href': ['/wiki/Ronald_Ross'],
#   'name': ['Ronald Ross']},
#  {'category': 'Literature',
#   'href': ['/wiki/Theodor_Mommsen'],
#   'name': ['Theodor Mommsen']},
#  {'category': 'Peace',
#   'href': ['/wiki/%C3%89lie_Ducommun'],
#   'name': ['Élie Ducommun']},
#  {'category': 'Peace',
#   'href': ['/wiki/Charles_Albert_Gobat'],
#   'name': ['Charles Albert Gobat']}]

# %%
# Now we see multiple entries with the Peace category instead of just one

# But we must look closely at the data... each name and href is a list...
# We can fix that by indexing into the list when we assign the values to the dictionary

# %%
by_year = {}
for row in other_rows:
    try:
        year = row.css('td')[0].xpath('string()').extract()[0]
    except IndexError:
        print('error on {}'.format(row))
        continue
    # or year = row.css('td')[0].xpath('string()')[0].extract()
    if '[' in year:
        year = year.split('[')[0]

    year_data = []
    # Loop through each data cell's links
    for i, cell in enumerate(row.css('td:not(:nth-child(1))'), 1):
        category = col_names_links[i]["name"]
        for link in cell.css('a'):
            name = link.xpath('string()').extract()
            name_href = link.xpath('@href').extract()
            year_data.append({
                "name": name[0],
                "href": name_href[0],
                "category": category,
            })
    by_year[year] = year_data
by_year['1902']
# Out:
# error on <Selector xpath='descendant-or-self::tr[not(count(preceding-sibling::*) = 0)]' data='<tr>\n<th>Year</th>\n<th width="16%"><a hr'>
# [{'category': 'Physics',
#   'href': '/wiki/Hendrik_Lorentz',
#   'name': 'Hendrik Lorentz'},
#  {'category': 'Physics',
#   'href': '/wiki/Pieter_Zeeman',
#   'name': 'Pieter Zeeman'},
#  {'category': 'Chemistry',
#   'href': '/wiki/Hermann_Emil_Fischer',
#   'name': 'Hermann Emil Fischer'},
#  {'category': 'Physiology or Medicine',
#   'href': '/wiki/Ronald_Ross',
#   'name': 'Ronald Ross'},
#  {'category': 'Literature',
#   'href': '/wiki/Theodor_Mommsen',
#   'name': 'Theodor Mommsen'},
#  {'category': 'Peace',
#   'href': '/wiki/%C3%89lie_Ducommun',
#   'name': 'Élie Ducommun'},
#  {'category': 'Peace',
#   'href': '/wiki/Charles_Albert_Gobat',
#   'name': 'Charles Albert Gobat'}]

# %%
# Our data looks really good now
by_year
# Out:
# {'1901': [{'category': 'Physics',
#    'href': '/wiki/Wilhelm_R%C3%B6ntgen',
#    'name': 'Wilhelm Röntgen'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Jacobus_Henricus_van_%27t_Hoff',
#    'name': "Jacobus Henricus van 't Hoff"},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Emil_Adolf_von_Behring',
#    'name': 'Emil Adolf von Behring'},
#   {'category': 'Literature',
#    'href': '/wiki/Sully_Prudhomme',
#    'name': 'Sully Prudhomme'},
#   {'category': 'Peace', 'href': '/wiki/Henry_Dunant', 'name': 'Henry Dunant'},
#   {'category': 'Peace',
#    'href': '/wiki/Fr%C3%A9d%C3%A9ric_Passy',
#    'name': 'Frédéric Passy'}],
#  '1902': [{'category': 'Physics',
#    'href': '/wiki/Hendrik_Lorentz',
#    'name': 'Hendrik Lorentz'},
#   {'category': 'Physics',
#    'href': '/wiki/Pieter_Zeeman',
#    'name': 'Pieter Zeeman'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Hermann_Emil_Fischer',
#    'name': 'Hermann Emil Fischer'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Ronald_Ross',
#    'name': 'Ronald Ross'},
#   {'category': 'Literature',
#    'href': '/wiki/Theodor_Mommsen',
#    'name': 'Theodor Mommsen'},
#   {'category': 'Peace',
#    'href': '/wiki/%C3%89lie_Ducommun',
#    'name': 'Élie Ducommun'},
#   {'category': 'Peace',
#    'href': '/wiki/Charles_Albert_Gobat',
#    'name': 'Charles Albert Gobat'}],
#  '1903': [{'category': 'Physics',
#    'href': '/wiki/Henri_Becquerel',
#    'name': 'Henri Becquerel'},
#   {'category': 'Physics',
#    'href': '/wiki/Pierre_Curie',
#    'name': 'Pierre Curie'},
#   {'category': 'Physics', 'href': '/wiki/Marie_Curie', 'name': 'Marie Curie'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Svante_Arrhenius',
#    'name': 'Svante Arrhenius'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Niels_Ryberg_Finsen',
#    'name': 'Niels Ryberg Finsen'},
#   {'category': 'Literature',
#    'href': '/wiki/Bj%C3%B8rnstjerne_Bj%C3%B8rnson',
#    'name': 'Bjørnstjerne Bjørnson'},
#   {'category': 'Peace',
#    'href': '/wiki/Randal_Cremer',
#    'name': 'Randal Cremer'}],
#  '1904': [{'category': 'Physics',
#    'href': '/wiki/John_Strutt,_3rd_Baron_Rayleigh',
#    'name': 'Lord Rayleigh'},
#   {'category': 'Chemistry',
#    'href': '/wiki/William_Ramsay',
#    'name': 'William Ramsay'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Ivan_Pavlov',
#    'name': 'Ivan Pavlov'},
#   {'category': 'Literature',
#    'href': '/wiki/Fr%C3%A9d%C3%A9ric_Mistral',
#    'name': 'Frédéric Mistral'},
#   {'category': 'Literature',
#    'href': '/wiki/Jos%C3%A9_Echegaray',
#    'name': 'José Echegaray'},
#   {'category': 'Peace',
#    'href': '/wiki/Institut_de_Droit_International',
#    'name': 'Institut de Droit International'}],
#  '1905': [{'category': 'Physics',
#    'href': '/wiki/Philipp_Lenard',
#    'name': 'Philipp Lenard'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Adolf_von_Baeyer',
#    'name': 'Adolf von Baeyer'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Robert_Koch',
#    'name': 'Robert Koch'},
#   {'category': 'Literature',
#    'href': '/wiki/Henryk_Sienkiewicz',
#    'name': 'Henryk Sienkiewicz'},
#   {'category': 'Peace',
#    'href': '/wiki/Bertha_von_Suttner',
#    'name': 'Bertha von Suttner'}],
#  '1906': [{'category': 'Physics',
#    'href': '/wiki/J._J._Thomson',
#    'name': 'J. J. Thomson'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Henri_Moissan',
#    'name': 'Henri Moissan'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Camillo_Golgi',
#    'name': 'Camillo Golgi'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Santiago_Ram%C3%B3n_y_Cajal',
#    'name': 'Santiago Ramón y Cajal'},
#   {'category': 'Literature',
#    'href': '/wiki/Giosu%C3%A8_Carducci',
#    'name': 'Giosuè Carducci'},
#   {'category': 'Peace',
#    'href': '/wiki/Theodore_Roosevelt',
#    'name': 'Theodore Roosevelt'}],
#  '1907': [{'category': 'Physics',
#    'href': '/wiki/Albert_Abraham_Michelson',
#    'name': 'Albert Abraham Michelson'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Eduard_Buchner',
#    'name': 'Eduard Buchner'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Charles_Louis_Alphonse_Laveran',
#    'name': 'Charles Louis Alphonse Laveran'},
#   {'category': 'Literature',
#    'href': '/wiki/Rudyard_Kipling',
#    'name': 'Rudyard Kipling'},
#   {'category': 'Peace',
#    'href': '/wiki/Ernesto_Teodoro_Moneta',
#    'name': 'Ernesto Teodoro Moneta'},
#   {'category': 'Peace',
#    'href': '/wiki/Louis_Renault_(jurist)',
#    'name': 'Louis Renault'}],
#  '1908': [{'category': 'Physics',
#    'href': '/wiki/Gabriel_Lippmann',
#    'name': 'Gabriel Lippmann'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Ernest_Rutherford',
#    'name': 'Ernest Rutherford'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/%C3%89lie_Metchnikoff',
#    'name': 'Élie Metchnikoff'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Paul_Ehrlich',
#    'name': 'Paul Ehrlich'},
#   {'category': 'Literature',
#    'href': '/wiki/Rudolf_Christoph_Eucken',
#    'name': 'Rudolf Christoph Eucken'},
#   {'category': 'Peace',
#    'href': '/wiki/Klas_Pontus_Arnoldson',
#    'name': 'Klas Pontus Arnoldson'},
#   {'category': 'Peace',
#    'href': '/wiki/Fredrik_Bajer',
#    'name': 'Fredrik Bajer'}],
#  '1909': [{'category': 'Physics',
#    'href': '/wiki/Karl_Ferdinand_Braun',
#    'name': 'Karl Ferdinand Braun'},
#   {'category': 'Physics',
#    'href': '/wiki/Guglielmo_Marconi',
#    'name': 'Guglielmo Marconi'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Wilhelm_Ostwald',
#    'name': 'Wilhelm Ostwald'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Emil_Theodor_Kocher',
#    'name': 'Emil Theodor Kocher'},
#   {'category': 'Literature',
#    'href': '/wiki/Selma_Lagerl%C3%B6f',
#    'name': 'Selma Lagerlöf'},
#   {'category': 'Peace',
#    'href': '/wiki/Auguste_Marie_Fran%C3%A7ois_Beernaert',
#    'name': 'Auguste Marie François Beernaert'},
#   {'category': 'Peace',
#    'href': '/wiki/Paul-Henri-Benjamin_d%27Estournelles_de_Constant',
#    'name': "Paul-Henri-Benjamin d'Estournelles de Constant"}],
#  '1910': [{'category': 'Physics',
#    'href': '/wiki/Johannes_Diderik_van_der_Waals',
#    'name': 'Johannes Diderik van der Waals'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Otto_Wallach',
#    'name': 'Otto Wallach'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Albrecht_Kossel',
#    'name': 'Albrecht Kossel'},
#   {'category': 'Literature', 'href': '/wiki/Paul_Heyse', 'name': 'Paul Heyse'},
#   {'category': 'Peace',
#    'href': '/wiki/International_Peace_Bureau',
#    'name': 'International Peace Bureau'}],
#  '1911': [{'category': 'Physics',
#    'href': '/wiki/Wilhelm_Wien',
#    'name': 'Wilhelm Wien'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Marie_Sk%C5%82odowska-Curie',
#    'name': 'Marie Skłodowska-Curie'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Allvar_Gullstrand',
#    'name': 'Allvar Gullstrand'},
#   {'category': 'Literature',
#    'href': '/wiki/Maurice_Maeterlinck',
#    'name': 'Maurice Maeterlinck'},
#   {'category': 'Peace', 'href': '/wiki/Tobias_Asser', 'name': 'Tobias Asser'},
#   {'category': 'Peace',
#    'href': '/wiki/Alfred_Hermann_Fried',
#    'name': 'Alfred Hermann Fried'}],
#  '1912': [{'category': 'Physics',
#    'href': '/wiki/Gustaf_Dal%C3%A9n',
#    'name': 'Gustaf Dalén'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Victor_Grignard',
#    'name': 'Victor Grignard'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Paul_Sabatier_(chemist)',
#    'name': 'Paul Sabatier'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Alexis_Carrel',
#    'name': 'Alexis Carrel'},
#   {'category': 'Literature',
#    'href': '/wiki/Gerhart_Hauptmann',
#    'name': 'Gerhart Hauptmann'},
#   {'category': 'Peace', 'href': '/wiki/Elihu_Root', 'name': 'Elihu Root'}],
#  '1913': [{'category': 'Physics',
#    'href': '/wiki/Heike_Kamerlingh_Onnes',
#    'name': 'Heike Kamerlingh Onnes'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Alfred_Werner',
#    'name': 'Alfred Werner'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Charles_Richet',
#    'name': 'Charles Richet'},
#   {'category': 'Literature',
#    'href': '/wiki/Rabindranath_Tagore',
#    'name': 'Rabindranath Tagore'},
#   {'category': 'Peace',
#    'href': '/wiki/Henri_La_Fontaine',
#    'name': 'Henri La Fontaine'}],
#  '1914': [{'category': 'Physics',
#    'href': '/wiki/Max_von_Laue',
#    'name': 'Max von Laue'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Theodore_William_Richards',
#    'name': 'Theodore William Richards'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Robert_B%C3%A1r%C3%A1ny',
#    'name': 'Robert Bárány'}],
#  '1915': [{'category': 'Physics',
#    'href': '/wiki/William_Henry_Bragg',
#    'name': 'William Henry Bragg'},
#   {'category': 'Physics',
#    'href': '/wiki/William_Lawrence_Bragg',
#    'name': 'William Lawrence Bragg'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Richard_Willst%C3%A4tter',
#    'name': 'Richard Willstätter'},
#   {'category': 'Literature',
#    'href': '/wiki/Romain_Rolland',
#    'name': 'Romain Rolland'}],
#  '1916': [{'category': 'Literature',
#    'href': '/wiki/Verner_von_Heidenstam',
#    'name': 'Verner von Heidenstam'}],
#  '1917': [{'category': 'Physics',
#    'href': '/wiki/Charles_Glover_Barkla',
#    'name': 'Charles Glover Barkla'},
#   {'category': 'Literature',
#    'href': '/wiki/Karl_Adolph_Gjellerup',
#    'name': 'Karl Adolph Gjellerup'},
#   {'category': 'Literature',
#    'href': '/wiki/Henrik_Pontoppidan',
#    'name': 'Henrik Pontoppidan'},
#   {'category': 'Peace',
#    'href': '/wiki/International_Committee_of_the_Red_Cross',
#    'name': 'International Committee of the Red Cross'}],
#  '1918': [{'category': 'Physics',
#    'href': '/wiki/Max_Planck',
#    'name': 'Max Planck'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Fritz_Haber',
#    'name': 'Fritz Haber'}],
#  '1919': [{'category': 'Physics',
#    'href': '/wiki/Johannes_Stark',
#    'name': 'Johannes Stark'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Jules_Bordet',
#    'name': 'Jules Bordet'},
#   {'category': 'Literature',
#    'href': '/wiki/Carl_Spitteler',
#    'name': 'Carl Spitteler'},
#   {'category': 'Peace',
#    'href': '/wiki/Woodrow_Wilson',
#    'name': 'Woodrow Wilson'}],
#  '1920': [{'category': 'Physics',
#    'href': '/wiki/Charles_%C3%89douard_Guillaume',
#    'name': 'Charles Édouard Guillaume'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Walther_Nernst',
#    'name': 'Walther Nernst'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/August_Krogh',
#    'name': 'August Krogh'},
#   {'category': 'Literature',
#    'href': '/wiki/Knut_Hamsun',
#    'name': 'Knut Hamsun'},
#   {'category': 'Peace',
#    'href': '/wiki/L%C3%A9on_Bourgeois',
#    'name': 'Léon Bourgeois'}],
#  '1921': [{'category': 'Physics',
#    'href': '/wiki/Albert_Einstein',
#    'name': 'Albert Einstein'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Frederick_Soddy',
#    'name': 'Frederick Soddy'},
#   {'category': 'Literature',
#    'href': '/wiki/Anatole_France',
#    'name': 'Anatole France'},
#   {'category': 'Peace',
#    'href': '/wiki/Hjalmar_Branting',
#    'name': 'Hjalmar Branting'},
#   {'category': 'Peace',
#    'href': '/wiki/Christian_Lous_Lange',
#    'name': 'Christian Lous Lange'}],
#  '1922': [{'category': 'Physics',
#    'href': '/wiki/Niels_Bohr',
#    'name': 'Niels Bohr'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Francis_William_Aston',
#    'name': 'Francis William Aston'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Archibald_Hill',
#    'name': 'Archibald Hill'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Otto_Fritz_Meyerhof',
#    'name': 'Otto Fritz Meyerhof'},
#   {'category': 'Literature',
#    'href': '/wiki/Jacinto_Benavente',
#    'name': 'Jacinto Benavente'},
#   {'category': 'Peace',
#    'href': '/wiki/Fridtjof_Nansen',
#    'name': 'Fridtjof Nansen'}],
#  '1923': [{'category': 'Physics',
#    'href': '/wiki/Robert_Andrews_Millikan',
#    'name': 'Robert Andrews Millikan'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Fritz_Pregl',
#    'name': 'Fritz Pregl'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Frederick_Banting',
#    'name': 'Frederick Banting'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/John_James_Rickard_Macleod',
#    'name': 'John James Rickard Macleod'},
#   {'category': 'Literature',
#    'href': '/wiki/W._B._Yeats',
#    'name': 'W. B. Yeats'}],
#  '1924': [{'category': 'Physics',
#    'href': '/wiki/Manne_Siegbahn',
#    'name': 'Manne Siegbahn'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Willem_Einthoven',
#    'name': 'Willem Einthoven'},
#   {'category': 'Literature',
#    'href': '/wiki/W%C5%82adys%C5%82aw_Reymont',
#    'name': 'Władysław Reymont'}],
#  '1925': [{'category': 'Physics',
#    'href': '/wiki/James_Franck',
#    'name': 'James Franck'},
#   {'category': 'Physics',
#    'href': '/wiki/Gustav_Ludwig_Hertz',
#    'name': 'Gustav Ludwig Hertz'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Richard_Adolf_Zsigmondy',
#    'name': 'Richard Adolf Zsigmondy'},
#   {'category': 'Literature',
#    'href': '/wiki/George_Bernard_Shaw',
#    'name': 'George Bernard Shaw'},
#   {'category': 'Peace',
#    'href': '/wiki/Austen_Chamberlain',
#    'name': 'Austen Chamberlain'},
#   {'category': 'Peace',
#    'href': '/wiki/Charles_G._Dawes',
#    'name': 'Charles G. Dawes'}],
#  '1926': [{'category': 'Physics',
#    'href': '/wiki/Jean_Baptiste_Perrin',
#    'name': 'Jean Baptiste Perrin'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Theodor_Svedberg',
#    'name': 'Theodor Svedberg'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Johannes_Fibiger',
#    'name': 'Johannes Fibiger'},
#   {'category': 'Literature',
#    'href': '/wiki/Grazia_Deledda',
#    'name': 'Grazia Deledda'},
#   {'category': 'Peace',
#    'href': '/wiki/Aristide_Briand',
#    'name': 'Aristide Briand'},
#   {'category': 'Peace',
#    'href': '/wiki/Gustav_Stresemann',
#    'name': 'Gustav Stresemann'}],
#  '1927': [{'category': 'Physics',
#    'href': '/wiki/Arthur_Compton',
#    'name': 'Arthur Compton'},
#   {'category': 'Physics',
#    'href': '/wiki/Charles_Thomson_Rees_Wilson',
#    'name': 'Charles Thomson Rees Wilson'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Heinrich_Otto_Wieland',
#    'name': 'Heinrich Otto Wieland'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Julius_Wagner-Jauregg',
#    'name': 'Julius Wagner-Jauregg'},
#   {'category': 'Literature',
#    'href': '/wiki/Henri_Bergson',
#    'name': 'Henri Bergson'},
#   {'category': 'Peace',
#    'href': '/wiki/Ferdinand_Buisson',
#    'name': 'Ferdinand Buisson'},
#   {'category': 'Peace',
#    'href': '/wiki/Ludwig_Quidde',
#    'name': 'Ludwig Quidde'}],
#  '1928': [{'category': 'Physics',
#    'href': '/wiki/Owen_Willans_Richardson',
#    'name': 'Owen Willans Richardson'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Adolf_Otto_Reinhold_Windaus',
#    'name': 'Adolf Otto Reinhold Windaus'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Charles_Nicolle',
#    'name': 'Charles Nicolle'},
#   {'category': 'Literature',
#    'href': '/wiki/Sigrid_Undset',
#    'name': 'Sigrid Undset'}],
#  '1929': [{'category': 'Physics',
#    'href': '/wiki/Louis_de_Broglie',
#    'name': 'Louis de Broglie'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Arthur_Harden',
#    'name': 'Arthur Harden'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Hans_von_Euler-Chelpin',
#    'name': 'Hans von Euler-Chelpin'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Christiaan_Eijkman',
#    'name': 'Christiaan Eijkman'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Frederick_Gowland_Hopkins',
#    'name': 'Frederick Gowland Hopkins'},
#   {'category': 'Literature',
#    'href': '/wiki/Thomas_Mann',
#    'name': 'Thomas Mann'},
#   {'category': 'Peace',
#    'href': '/wiki/Frank_B._Kellogg',
#    'name': 'Frank B. Kellogg'}],
#  '1930': [{'category': 'Physics',
#    'href': '/wiki/C._V._Raman',
#    'name': 'C. V. Raman'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Hans_Fischer',
#    'name': 'Hans Fischer'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Karl_Landsteiner',
#    'name': 'Karl Landsteiner'},
#   {'category': 'Literature',
#    'href': '/wiki/Sinclair_Lewis',
#    'name': 'Sinclair Lewis'},
#   {'category': 'Peace',
#    'href': '/wiki/Nathan_S%C3%B6derblom',
#    'name': 'Nathan Söderblom'}],
#  '1931': [{'category': 'Chemistry',
#    'href': '/wiki/Carl_Bosch',
#    'name': 'Carl Bosch'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Friedrich_Bergius',
#    'name': 'Friedrich Bergius'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Otto_Heinrich_Warburg',
#    'name': 'Otto Heinrich Warburg'},
#   {'category': 'Literature',
#    'href': '/wiki/Erik_Axel_Karlfeldt',
#    'name': 'Erik Axel Karlfeldt'},
#   {'category': 'Peace', 'href': '/wiki/Jane_Addams', 'name': 'Jane Addams'},
#   {'category': 'Peace',
#    'href': '/wiki/Nicholas_Murray_Butler',
#    'name': 'Nicholas Murray Butler'}],
#  '1932': [{'category': 'Physics',
#    'href': '/wiki/Werner_Heisenberg',
#    'name': 'Werner Heisenberg'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Irving_Langmuir',
#    'name': 'Irving Langmuir'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Charles_Scott_Sherrington',
#    'name': 'Charles Scott Sherrington'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Edgar_Adrian,_1st_Baron_Adrian',
#    'name': 'Edgar Adrian'},
#   {'category': 'Literature',
#    'href': '/wiki/John_Galsworthy',
#    'name': 'John Galsworthy'}],
#  '1933': [{'category': 'Physics',
#    'href': '/wiki/Erwin_Schr%C3%B6dinger',
#    'name': 'Erwin Schrödinger'},
#   {'category': 'Physics', 'href': '/wiki/Paul_Dirac', 'name': 'Paul Dirac'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Thomas_Hunt_Morgan',
#    'name': 'Thomas Hunt Morgan'},
#   {'category': 'Literature', 'href': '/wiki/Ivan_Bunin', 'name': 'Ivan Bunin'},
#   {'category': 'Peace',
#    'href': '/wiki/Norman_Angell',
#    'name': 'Norman Angell'}],
#  '1934': [{'category': 'Chemistry',
#    'href': '/wiki/Harold_Urey',
#    'name': 'Harold Urey'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/George_Whipple',
#    'name': 'George Whipple'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/George_Minot',
#    'name': 'George Minot'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/William_P._Murphy',
#    'name': 'William P. Murphy'},
#   {'category': 'Literature',
#    'href': '/wiki/Luigi_Pirandello',
#    'name': 'Luigi Pirandello'},
#   {'category': 'Peace',
#    'href': '/wiki/Arthur_Henderson',
#    'name': 'Arthur Henderson'}],
#  '1935': [{'category': 'Physics',
#    'href': '/wiki/James_Chadwick',
#    'name': 'James Chadwick'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Fr%C3%A9d%C3%A9ric_Joliot-Curie',
#    'name': 'Frédéric Joliot-Curie'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Ir%C3%A8ne_Joliot-Curie',
#    'name': 'Irène Joliot-Curie'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Hans_Spemann',
#    'name': 'Hans Spemann'},
#   {'category': 'Peace',
#    'href': '/wiki/Carl_von_Ossietzky',
#    'name': 'Carl von Ossietzky'}],
#  '1936': [{'category': 'Physics',
#    'href': '/wiki/Victor_Francis_Hess',
#    'name': 'Victor Francis Hess'},
#   {'category': 'Physics',
#    'href': '/wiki/Carl_David_Anderson',
#    'name': 'Carl David Anderson'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Peter_Debye',
#    'name': 'Peter Debye'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Henry_Hallett_Dale',
#    'name': 'Henry Hallett Dale'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Otto_Loewi',
#    'name': 'Otto Loewi'},
#   {'category': 'Literature',
#    'href': '/wiki/Eugene_O%27Neill',
#    'name': "Eugene O'Neill"},
#   {'category': 'Peace',
#    'href': '/wiki/Carlos_Saavedra_Lamas',
#    'name': 'Carlos Saavedra Lamas'}],
#  '1937': [{'category': 'Physics',
#    'href': '/wiki/Clinton_Davisson',
#    'name': 'Clinton Davisson'},
#   {'category': 'Physics',
#    'href': '/wiki/George_Paget_Thomson',
#    'name': 'George Paget Thomson'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Norman_Haworth',
#    'name': 'Norman Haworth'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Paul_Karrer',
#    'name': 'Paul Karrer'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Albert_Szent-Gy%C3%B6rgyi',
#    'name': 'Albert Szent-Györgyi'},
#   {'category': 'Literature',
#    'href': '/wiki/Roger_Martin_du_Gard',
#    'name': 'Roger Martin du Gard'},
#   {'category': 'Peace',
#    'href': '/wiki/Robert_Cecil,_1st_Viscount_Cecil_of_Chelwood',
#    'name': 'The Viscount Cecil of Chelwood'}],
#  '1938': [{'category': 'Physics',
#    'href': '/wiki/Enrico_Fermi',
#    'name': 'Enrico Fermi'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Richard_Kuhn',
#    'name': 'Richard Kuhn'},
#   {'category': 'Chemistry', 'href': '#endnote_Note1A', 'name': '[A]'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Corneille_Heymans',
#    'name': 'Corneille Heymans'},
#   {'category': 'Literature',
#    'href': '/wiki/Pearl_S._Buck',
#    'name': 'Pearl S. Buck'},
#   {'category': 'Peace',
#    'href': '/wiki/Office_international_Nansen_pour_les_r%C3%A9fugi%C3%A9s',
#    'name': 'Nansen International Office For Refugees'}],
#  '1939': [{'category': 'Physics',
#    'href': '/wiki/Ernest_Lawrence',
#    'name': 'Ernest Lawrence'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Adolf_Butenandt',
#    'name': 'Adolf Butenandt'},
#   {'category': 'Chemistry', 'href': '#endnote_Note1A', 'name': '[A]'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Leopold_Ru%C5%BEi%C4%8Dka',
#    'name': 'Leopold Ružička'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Gerhard_Domagk',
#    'name': 'Gerhard Domagk'},
#   {'category': 'Physiology or Medicine',
#    'href': '#endnote_Note1A',
#    'name': '[A]'},
#   {'category': 'Literature',
#    'href': '/wiki/Frans_Eemil_Sillanp%C3%A4%C3%A4',
#    'name': 'Frans Eemil Sillanpää'}],
#  '1940': [],
#  '1941': [],
#  '1942': [],
#  '1943': [{'category': 'Physics',
#    'href': '/wiki/Otto_Stern',
#    'name': 'Otto Stern'},
#   {'category': 'Chemistry',
#    'href': '/wiki/George_de_Hevesy',
#    'name': 'George de Hevesy'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Henrik_Dam',
#    'name': 'Henrik Dam'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Edward_Adelbert_Doisy',
#    'name': 'Edward Adelbert Doisy'}],
#  '1944': [{'category': 'Physics',
#    'href': '/wiki/Isidor_Isaac_Rabi',
#    'name': 'Isidor Isaac Rabi'},
#   {'category': 'Chemistry', 'href': '/wiki/Otto_Hahn', 'name': 'Otto Hahn'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Joseph_Erlanger',
#    'name': 'Joseph Erlanger'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Herbert_Spencer_Gasser',
#    'name': 'Herbert Spencer Gasser'},
#   {'category': 'Literature',
#    'href': '/wiki/Johannes_Vilhelm_Jensen',
#    'name': 'Johannes Vilhelm Jensen'},
#   {'category': 'Peace',
#    'href': '/wiki/International_Committee_of_the_Red_Cross',
#    'name': 'International Committee of the Red Cross'}],
#  '1945': [{'category': 'Physics',
#    'href': '/wiki/Wolfgang_Pauli',
#    'name': 'Wolfgang Pauli'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Artturi_Ilmari_Virtanen',
#    'name': 'Artturi Ilmari Virtanen'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Alexander_Fleming',
#    'name': 'Alexander Fleming'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Ernst_Boris_Chain',
#    'name': 'Ernst Boris Chain'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Howard_Florey',
#    'name': 'Howard Florey'},
#   {'category': 'Literature',
#    'href': '/wiki/Gabriela_Mistral',
#    'name': 'Gabriela Mistral'},
#   {'category': 'Peace', 'href': '/wiki/Cordell_Hull', 'name': 'Cordell Hull'}],
#  '1946': [{'category': 'Physics',
#    'href': '/wiki/Percy_Williams_Bridgman',
#    'name': 'Percy Williams Bridgman'},
#   {'category': 'Chemistry',
#    'href': '/wiki/James_B._Sumner',
#    'name': 'James B. Sumner'},
#   {'category': 'Chemistry',
#    'href': '/wiki/John_Howard_Northrop',
#    'name': 'John Howard Northrop'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Wendell_Meredith_Stanley',
#    'name': 'Wendell Meredith Stanley'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Hermann_Joseph_Muller',
#    'name': 'Hermann Joseph Muller'},
#   {'category': 'Literature',
#    'href': '/wiki/Hermann_Hesse',
#    'name': 'Hermann Hesse'},
#   {'category': 'Peace',
#    'href': '/wiki/Emily_Greene_Balch',
#    'name': 'Emily Greene Balch'},
#   {'category': 'Peace', 'href': '/wiki/John_Mott', 'name': 'John Mott'}],
#  '1947': [{'category': 'Physics',
#    'href': '/wiki/Edward_Victor_Appleton',
#    'name': 'Edward Victor Appleton'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Robert_Robinson_(organic_chemist)',
#    'name': 'Robert Robinson'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Carl_Ferdinand_Cori',
#    'name': 'Carl Ferdinand Cori'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Gerty_Cori',
#    'name': 'Gerty Cori'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Bernardo_Houssay',
#    'name': 'Bernardo Houssay'},
#   {'category': 'Literature',
#    'href': '/wiki/Andr%C3%A9_Gide',
#    'name': 'André Gide'},
#   {'category': 'Peace',
#    'href': '/wiki/Quaker_Peace_and_Social_Witness',
#    'name': 'Friends Service Council'},
#   {'category': 'Peace',
#    'href': '/wiki/American_Friends_Service_Committee',
#    'name': 'American Friends Service Committee'}],
#  '1948': [{'category': 'Physics',
#    'href': '/wiki/Patrick_Blackett,_Baron_Blackett',
#    'name': 'Patrick Blackett'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Arne_Tiselius',
#    'name': 'Arne Tiselius'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Paul_Hermann_M%C3%BCller',
#    'name': 'Paul Hermann Müller'},
#   {'category': 'Literature',
#    'href': '/wiki/T._S._Eliot',
#    'name': 'T. S. Eliot'},
#   {'category': 'Peace', 'href': '#endnote_Note1B', 'name': '[B]'}],
#  '1949': [{'category': 'Physics',
#    'href': '/wiki/Hideki_Yukawa',
#    'name': 'Hideki Yukawa'},
#   {'category': 'Chemistry',
#    'href': '/wiki/William_Giauque',
#    'name': 'William Giauque'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Walter_Rudolf_Hess',
#    'name': 'Walter Rudolf Hess'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Ant%C3%B3nio_Egas_Moniz',
#    'name': 'António Egas Moniz'},
#   {'category': 'Literature',
#    'href': '/wiki/William_Faulkner',
#    'name': 'William Faulkner'},
#   {'category': 'Peace',
#    'href': '/wiki/John_Boyd_Orr,_1st_Baron_Boyd-Orr',
#    'name': 'John Boyd Orr'}],
#  '1950': [{'category': 'Physics',
#    'href': '/wiki/C._F._Powell',
#    'name': 'C. F. Powell'},
#   {'category': 'Chemistry', 'href': '/wiki/Otto_Diels', 'name': 'Otto Diels'},
#   {'category': 'Chemistry', 'href': '/wiki/Kurt_Alder', 'name': 'Kurt Alder'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Philip_Showalter_Hench',
#    'name': 'Philip Showalter Hench'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Edward_Calvin_Kendall',
#    'name': 'Edward Calvin Kendall'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Tadeus_Reichstein',
#    'name': 'Tadeus Reichstein'},
#   {'category': 'Literature',
#    'href': '/wiki/Bertrand_Russell',
#    'name': 'Bertrand Russell'},
#   {'category': 'Peace', 'href': '/wiki/Ralph_Bunche', 'name': 'Ralph Bunche'}],
#  '1951': [{'category': 'Physics',
#    'href': '/wiki/John_Cockcroft',
#    'name': 'John Cockcroft'},
#   {'category': 'Physics',
#    'href': '/wiki/Ernest_Walton',
#    'name': 'Ernest Walton'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Edwin_McMillan',
#    'name': 'Edwin McMillan'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Glenn_T._Seaborg',
#    'name': 'Glenn T. Seaborg'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Max_Theiler',
#    'name': 'Max Theiler'},
#   {'category': 'Literature',
#    'href': '/wiki/P%C3%A4r_Lagerkvist',
#    'name': 'Pär Lagerkvist'},
#   {'category': 'Peace',
#    'href': '/wiki/L%C3%A9on_Jouhaux',
#    'name': 'Léon Jouhaux'}],
#  '1952': [{'category': 'Physics',
#    'href': '/wiki/Felix_Bloch',
#    'name': 'Felix Bloch'},
#   {'category': 'Physics',
#    'href': '/wiki/Edward_Mills_Purcell',
#    'name': 'Edward Mills Purcell'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Archer_John_Porter_Martin',
#    'name': 'Archer John Porter Martin'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Richard_Laurence_Millington_Synge',
#    'name': 'Richard Laurence Millington Synge'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Selman_Waksman',
#    'name': 'Selman Waksman'},
#   {'category': 'Literature',
#    'href': '/wiki/Fran%C3%A7ois_Mauriac',
#    'name': 'François Mauriac'},
#   {'category': 'Peace',
#    'href': '/wiki/Albert_Schweitzer',
#    'name': 'Albert Schweitzer'}],
#  '1953': [{'category': 'Physics',
#    'href': '/wiki/Frits_Zernike',
#    'name': 'Frits Zernike'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Hermann_Staudinger',
#    'name': 'Hermann Staudinger'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Hans_Adolf_Krebs',
#    'name': 'Hans Adolf Krebs'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Fritz_Albert_Lipmann',
#    'name': 'Fritz Albert Lipmann'},
#   {'category': 'Literature',
#    'href': '/wiki/Winston_Churchill',
#    'name': 'Winston Churchill'},
#   {'category': 'Peace',
#    'href': '/wiki/George_Marshall',
#    'name': 'George Marshall'}],
#  '1954': [{'category': 'Physics',
#    'href': '/wiki/Max_Born',
#    'name': 'Max Born'},
#   {'category': 'Physics',
#    'href': '/wiki/Walther_Bothe',
#    'name': 'Walther Bothe'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Linus_Pauling',
#    'name': 'Linus Pauling'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/John_Franklin_Enders',
#    'name': 'John Franklin Enders'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Frederick_Chapman_Robbins',
#    'name': 'Frederick Chapman Robbins'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Thomas_Huckle_Weller',
#    'name': 'Thomas Huckle Weller'},
#   {'category': 'Literature',
#    'href': '/wiki/Ernest_Hemingway',
#    'name': 'Ernest Hemingway'},
#   {'category': 'Peace',
#    'href': '/wiki/United_Nations_High_Commissioner_for_Refugees',
#    'name': 'United Nations High Commissioner for Refugees'}],
#  '1955': [{'category': 'Physics',
#    'href': '/wiki/Willis_Lamb',
#    'name': 'Willis Lamb'},
#   {'category': 'Physics',
#    'href': '/wiki/Polykarp_Kusch',
#    'name': 'Polykarp Kusch'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Vincent_du_Vigneaud',
#    'name': 'Vincent du Vigneaud'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Hugo_Theorell',
#    'name': 'Hugo Theorell'},
#   {'category': 'Literature',
#    'href': '/wiki/Halld%C3%B3r_Laxness',
#    'name': 'Halldór Laxness'}],
#  '1956': [{'category': 'Physics',
#    'href': '/wiki/John_Bardeen',
#    'name': 'John Bardeen'},
#   {'category': 'Physics',
#    'href': '/wiki/Walter_Houser_Brattain',
#    'name': 'Walter Houser Brattain'},
#   {'category': 'Physics',
#    'href': '/wiki/William_Shockley',
#    'name': 'William Shockley'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Cyril_Norman_Hinshelwood',
#    'name': 'Cyril Norman Hinshelwood'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Nikolay_Semyonov',
#    'name': 'Nikolay Semyonov'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Andr%C3%A9_Fr%C3%A9d%C3%A9ric_Cournand',
#    'name': 'André Frédéric Cournand'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Werner_Forssmann',
#    'name': 'Werner Forssmann'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Dickinson_W._Richards',
#    'name': 'Dickinson W. Richards'},
#   {'category': 'Literature',
#    'href': '/wiki/Juan_Ram%C3%B3n_Jim%C3%A9nez',
#    'name': 'Juan Ramón Jiménez'}],
#  '1957': [{'category': 'Physics',
#    'href': '/wiki/Chen_Ning_Yang',
#    'name': 'Chen Ning Yang'},
#   {'category': 'Physics',
#    'href': '/wiki/Tsung-Dao_Lee',
#    'name': 'Tsung-Dao Lee'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Alexander_R._Todd,_Baron_Todd',
#    'name': 'The Lord Todd'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Daniel_Bovet',
#    'name': 'Daniel Bovet'},
#   {'category': 'Literature',
#    'href': '/wiki/Albert_Camus',
#    'name': 'Albert Camus'},
#   {'category': 'Peace',
#    'href': '/wiki/Lester_B._Pearson',
#    'name': 'Lester B. Pearson'}],
#  '1958': [{'category': 'Physics',
#    'href': '/wiki/Pavel_Cherenkov',
#    'name': 'Pavel Cherenkov'},
#   {'category': 'Physics', 'href': '/wiki/Ilya_Frank', 'name': 'Ilya Frank'},
#   {'category': 'Physics', 'href': '/wiki/Igor_Tamm', 'name': 'Igor Tamm'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Frederick_Sanger',
#    'name': 'Frederick Sanger'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/George_Wells_Beadle',
#    'name': 'George Wells Beadle'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Edward_Lawrie_Tatum',
#    'name': 'Edward Lawrie Tatum'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Joshua_Lederberg',
#    'name': 'Joshua Lederberg'},
#   {'category': 'Literature',
#    'href': '/wiki/Boris_Pasternak',
#    'name': 'Boris Pasternak'},
#   {'category': 'Literature', 'href': '#endnote_Note1C', 'name': '[C]'},
#   {'category': 'Peace',
#    'href': '/wiki/Dominique_Pire',
#    'name': 'Dominique Pire'}],
#  '1959': [{'category': 'Physics',
#    'href': '/wiki/Emilio_G._Segr%C3%A8',
#    'name': 'Emilio G. Segrè'},
#   {'category': 'Physics',
#    'href': '/wiki/Owen_Chamberlain',
#    'name': 'Owen Chamberlain'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Jaroslav_Heyrovsk%C3%BD',
#    'name': 'Jaroslav Heyrovský'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Arthur_Kornberg',
#    'name': 'Arthur Kornberg'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Severo_Ochoa',
#    'name': 'Severo Ochoa'},
#   {'category': 'Literature',
#    'href': '/wiki/Salvatore_Quasimodo',
#    'name': 'Salvatore Quasimodo'},
#   {'category': 'Peace',
#    'href': '/wiki/Philip_Noel-Baker,_Baron_Noel-Baker',
#    'name': 'Philip Noel-Baker'}],
#  '1960': [{'category': 'Physics',
#    'href': '/wiki/Donald_A._Glaser',
#    'name': 'Donald A. Glaser'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Willard_Libby',
#    'name': 'Willard Libby'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Frank_Macfarlane_Burnet',
#    'name': 'Frank Macfarlane Burnet'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Peter_Medawar',
#    'name': 'Peter Medawar'},
#   {'category': 'Literature',
#    'href': '/wiki/Saint-John_Perse',
#    'name': 'Saint-John Perse'},
#   {'category': 'Peace',
#    'href': '/wiki/Albert_Lutuli',
#    'name': 'Albert Lutuli'}],
#  '1961': [{'category': 'Physics',
#    'href': '/wiki/Robert_Hofstadter',
#    'name': 'Robert Hofstadter'},
#   {'category': 'Physics',
#    'href': '/wiki/Rudolf_M%C3%B6ssbauer',
#    'name': 'Rudolf Mössbauer'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Melvin_Calvin',
#    'name': 'Melvin Calvin'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Georg_von_B%C3%A9k%C3%A9sy',
#    'name': 'Georg von Békésy'},
#   {'category': 'Literature',
#    'href': '/wiki/Ivo_Andri%C4%87',
#    'name': 'Ivo Andrić'},
#   {'category': 'Peace',
#    'href': '/wiki/Dag_Hammarskj%C3%B6ld',
#    'name': 'Dag Hammarskjöld'}],
#  '1962': [{'category': 'Physics',
#    'href': '/wiki/Lev_Landau',
#    'name': 'Lev Landau'},
#   {'category': 'Chemistry', 'href': '/wiki/Max_Perutz', 'name': 'Max Perutz'},
#   {'category': 'Chemistry',
#    'href': '/wiki/John_Kendrew',
#    'name': 'John Kendrew'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Francis_Crick',
#    'name': 'Francis Crick'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/James_D._Watson',
#    'name': 'James D. Watson'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Maurice_Wilkins',
#    'name': 'Maurice Wilkins'},
#   {'category': 'Literature',
#    'href': '/wiki/John_Steinbeck',
#    'name': 'John Steinbeck'},
#   {'category': 'Peace',
#    'href': '/wiki/Linus_Pauling',
#    'name': 'Linus Pauling'}],
#  '1963': [{'category': 'Physics',
#    'href': '/wiki/Eugene_Wigner',
#    'name': 'Eugene Wigner'},
#   {'category': 'Physics',
#    'href': '/wiki/Maria_Goeppert-Mayer',
#    'name': 'Maria Goeppert-Mayer'},
#   {'category': 'Physics',
#    'href': '/wiki/J._Hans_D._Jensen',
#    'name': 'J. Hans D. Jensen'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Karl_Ziegler',
#    'name': 'Karl Ziegler'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Giulio_Natta',
#    'name': 'Giulio Natta'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/John_Eccles_(neurophysiologist)',
#    'name': 'John Eccles'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Alan_Lloyd_Hodgkin',
#    'name': 'Alan Lloyd Hodgkin'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Andrew_Huxley',
#    'name': 'Andrew Huxley'},
#   {'category': 'Literature',
#    'href': '/wiki/Giorgos_Seferis',
#    'name': 'Giorgos Seferis'},
#   {'category': 'Peace',
#    'href': '/wiki/International_Committee_of_the_Red_Cross',
#    'name': 'International Committee of the Red Cross'},
#   {'category': 'Peace',
#    'href': '/wiki/International_Federation_of_Red_Cross_and_Red_Crescent_Societies',
#    'name': 'League of Red Cross societies'}],
#  '1964': [{'category': 'Physics',
#    'href': '/wiki/Charles_Hard_Townes',
#    'name': 'Charles Hard Townes'},
#   {'category': 'Physics',
#    'href': '/wiki/Nikolay_Basov',
#    'name': 'Nikolay Basov'},
#   {'category': 'Physics',
#    'href': '/wiki/Alexander_Prokhorov',
#    'name': 'Alexander Prokhorov'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Dorothy_Hodgkin',
#    'name': 'Dorothy Hodgkin'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Konrad_Emil_Bloch',
#    'name': 'Konrad Emil Bloch'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Feodor_Felix_Konrad_Lynen',
#    'name': 'Feodor Felix Konrad Lynen'},
#   {'category': 'Literature',
#    'href': '/wiki/Jean-Paul_Sartre',
#    'name': 'Jean-Paul Sartre'},
#   {'category': 'Literature', 'href': '#endnote_Note1D', 'name': '[D]'},
#   {'category': 'Peace',
#    'href': '/wiki/Martin_Luther_King,_Jr.',
#    'name': 'Martin Luther King, Jr.'}],
#  '1965': [{'category': 'Physics',
#    'href': '/wiki/Sin-Itiro_Tomonaga',
#    'name': 'Sin-Itiro Tomonaga'},
#   {'category': 'Physics',
#    'href': '/wiki/Julian_Schwinger',
#    'name': 'Julian Schwinger'},
#   {'category': 'Physics',
#    'href': '/wiki/Richard_Feynman',
#    'name': 'Richard Feynman'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Robert_Burns_Woodward',
#    'name': 'Robert Burns Woodward'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Fran%C3%A7ois_Jacob',
#    'name': 'François Jacob'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Andr%C3%A9_Michel_Lwoff',
#    'name': 'André Michel Lwoff'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Jacques_Monod',
#    'name': 'Jacques Monod'},
#   {'category': 'Literature',
#    'href': '/wiki/Mikhail_Sholokhov',
#    'name': 'Mikhail Sholokhov'},
#   {'category': 'Peace',
#    'href': '/wiki/UNICEF',
#    'name': "United Nations International Children's Emergency Fund (UNICEF)"}],
#  '1966': [{'category': 'Physics',
#    'href': '/wiki/Alfred_Kastler',
#    'name': 'Alfred Kastler'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Robert_S._Mulliken',
#    'name': 'Robert S. Mulliken'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Francis_Peyton_Rous',
#    'name': 'Francis Peyton Rous'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Charles_Brenton_Huggins',
#    'name': 'Charles Brenton Huggins'},
#   {'category': 'Literature',
#    'href': '/wiki/Shmuel_Yosef_Agnon',
#    'name': 'Shmuel Yosef Agnon'},
#   {'category': 'Literature',
#    'href': '/wiki/Nelly_Sachs',
#    'name': 'Nelly Sachs'}],
#  '1967': [{'category': 'Physics',
#    'href': '/wiki/Hans_Bethe',
#    'name': 'Hans Bethe'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Manfred_Eigen',
#    'name': 'Manfred Eigen'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Ronald_George_Wreyford_Norrish',
#    'name': 'Ronald George Wreyford Norrish'},
#   {'category': 'Chemistry',
#    'href': '/wiki/George_Porter',
#    'name': 'George Porter'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Ragnar_Granit',
#    'name': 'Ragnar Granit'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Haldan_Keffer_Hartline',
#    'name': 'Haldan Keffer Hartline'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/George_Wald',
#    'name': 'George Wald'},
#   {'category': 'Literature',
#    'href': '/wiki/Miguel_%C3%81ngel_Asturias',
#    'name': 'Miguel Ángel Asturias'}],
#  '1968': [{'category': 'Physics',
#    'href': '/wiki/Luis_Walter_Alvarez',
#    'name': 'Luis Walter Alvarez'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Lars_Onsager',
#    'name': 'Lars Onsager'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Robert_W._Holley',
#    'name': 'Robert W. Holley'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Har_Gobind_Khorana',
#    'name': 'Har Gobind Khorana'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Marshall_Warren_Nirenberg',
#    'name': 'Marshall Warren Nirenberg'},
#   {'category': 'Literature',
#    'href': '/wiki/Yasunari_Kawabata',
#    'name': 'Yasunari Kawabata'},
#   {'category': 'Peace',
#    'href': '/wiki/Ren%C3%A9_Cassin',
#    'name': 'René Cassin'}],
#  '1969': [{'category': 'Physics',
#    'href': '/wiki/Murray_Gell-Mann',
#    'name': 'Murray Gell-Mann'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Derek_Barton',
#    'name': 'Derek Barton'},
#   {'category': 'Chemistry', 'href': '/wiki/Odd_Hassel', 'name': 'Odd Hassel'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Max_Delbr%C3%BCck',
#    'name': 'Max Delbrück'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Alfred_Hershey',
#    'name': 'Alfred Hershey'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Salvador_Luria',
#    'name': 'Salvador Luria'},
#   {'category': 'Literature',
#    'href': '/wiki/Samuel_Beckett',
#    'name': 'Samuel Beckett'},
#   {'category': 'Peace',
#    'href': '/wiki/International_Labour_Organization',
#    'name': 'International Labour Organization'},
#   {'category': 'Economics',
#    'href': '/wiki/Ragnar_Frisch',
#    'name': 'Ragnar Frisch'},
#   {'category': 'Economics',
#    'href': '/wiki/Jan_Tinbergen',
#    'name': 'Jan Tinbergen'}],
#  '1970': [{'category': 'Physics',
#    'href': '/wiki/Hannes_Alfv%C3%A9n',
#    'name': 'Hannes Alfvén'},
#   {'category': 'Physics',
#    'href': '/wiki/Louis_N%C3%A9el',
#    'name': 'Louis Néel'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Luis_Federico_Leloir',
#    'name': 'Luis Federico Leloir'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Julius_Axelrod',
#    'name': 'Julius Axelrod'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Ulf_von_Euler',
#    'name': 'Ulf von Euler'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Bernard_Katz',
#    'name': 'Bernard Katz'},
#   {'category': 'Literature',
#    'href': '/wiki/Aleksandr_Solzhenitsyn',
#    'name': 'Aleksandr Solzhenitsyn'},
#   {'category': 'Peace',
#    'href': '/wiki/Norman_Borlaug',
#    'name': 'Norman Borlaug'},
#   {'category': 'Economics',
#    'href': '/wiki/Paul_Samuelson',
#    'name': 'Paul Samuelson'}],
#  '1971': [{'category': 'Physics',
#    'href': '/wiki/Dennis_Gabor',
#    'name': 'Dennis Gabor'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Gerhard_Herzberg',
#    'name': 'Gerhard Herzberg'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Earl_Wilbur_Sutherland,_Jr.',
#    'name': 'Earl Wilbur Sutherland, Jr.'},
#   {'category': 'Literature',
#    'href': '/wiki/Pablo_Neruda',
#    'name': 'Pablo Neruda'},
#   {'category': 'Peace', 'href': '/wiki/Willy_Brandt', 'name': 'Willy Brandt'},
#   {'category': 'Economics',
#    'href': '/wiki/Simon_Kuznets',
#    'name': 'Simon Kuznets'}],
#  '1972': [{'category': 'Physics',
#    'href': '/wiki/John_Bardeen',
#    'name': 'John Bardeen'},
#   {'category': 'Physics', 'href': '/wiki/Leon_Cooper', 'name': 'Leon Cooper'},
#   {'category': 'Physics',
#    'href': '/wiki/John_Robert_Schrieffer',
#    'name': 'John Robert Schrieffer'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Christian_B._Anfinsen',
#    'name': 'Christian B. Anfinsen'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Stanford_Moore',
#    'name': 'Stanford Moore'},
#   {'category': 'Chemistry',
#    'href': '/wiki/William_Howard_Stein',
#    'name': 'William Howard Stein'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Gerald_Edelman',
#    'name': 'Gerald Edelman'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Rodney_Robert_Porter',
#    'name': 'Rodney Robert Porter'},
#   {'category': 'Literature',
#    'href': '/wiki/Heinrich_B%C3%B6ll',
#    'name': 'Heinrich Böll'},
#   {'category': 'Economics', 'href': '/wiki/John_Hicks', 'name': 'John Hicks'},
#   {'category': 'Economics',
#    'href': '/wiki/Kenneth_Arrow',
#    'name': 'Kenneth Arrow'}],
#  '1973': [{'category': 'Physics',
#    'href': '/wiki/Leo_Esaki',
#    'name': 'Leo Esaki'},
#   {'category': 'Physics',
#    'href': '/wiki/Ivar_Giaever',
#    'name': 'Ivar Giaever'},
#   {'category': 'Physics',
#    'href': '/wiki/Brian_David_Josephson',
#    'name': 'Brian David Josephson'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Ernst_Otto_Fischer',
#    'name': 'Ernst Otto Fischer'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Geoffrey_Wilkinson',
#    'name': 'Geoffrey Wilkinson'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Karl_von_Frisch',
#    'name': 'Karl von Frisch'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Konrad_Lorenz',
#    'name': 'Konrad Lorenz'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Nikolaas_Tinbergen',
#    'name': 'Nikolaas Tinbergen'},
#   {'category': 'Literature',
#    'href': '/wiki/Patrick_White',
#    'name': 'Patrick White'},
#   {'category': 'Peace',
#    'href': '/wiki/Henry_Kissinger',
#    'name': 'Henry Kissinger'},
#   {'category': 'Peace', 'href': '/wiki/Le_Duc_Tho', 'name': 'Le Duc Tho'},
#   {'category': 'Peace', 'href': '#endnote_Note1E', 'name': '[E]'},
#   {'category': 'Economics',
#    'href': '/wiki/Wassily_Leontief',
#    'name': 'Wassily Leontief'}],
#  '1974': [{'category': 'Physics',
#    'href': '/wiki/Martin_Ryle',
#    'name': 'Martin Ryle'},
#   {'category': 'Physics',
#    'href': '/wiki/Antony_Hewish',
#    'name': 'Antony Hewish'},
#   {'category': 'Chemistry', 'href': '/wiki/Paul_Flory', 'name': 'Paul Flory'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Albert_Claude',
#    'name': 'Albert Claude'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Christian_de_Duve',
#    'name': 'Christian de Duve'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/George_Emil_Palade',
#    'name': 'George Emil Palade'},
#   {'category': 'Literature',
#    'href': '/wiki/Eyvind_Johnson',
#    'name': 'Eyvind Johnson'},
#   {'category': 'Literature',
#    'href': '/wiki/Harry_Martinson',
#    'name': 'Harry Martinson'},
#   {'category': 'Peace',
#    'href': '/wiki/Se%C3%A1n_MacBride',
#    'name': 'Seán MacBride'},
#   {'category': 'Peace',
#    'href': '/wiki/Eisaku_Sat%C5%8D',
#    'name': 'Eisaku Satō'},
#   {'category': 'Economics',
#    'href': '/wiki/Gunnar_Myrdal',
#    'name': 'Gunnar Myrdal'},
#   {'category': 'Economics',
#    'href': '/wiki/Friedrich_Hayek',
#    'name': 'Friedrich Hayek'}],
#  '1975': [{'category': 'Physics',
#    'href': '/wiki/Aage_Bohr',
#    'name': 'Aage Bohr'},
#   {'category': 'Physics',
#    'href': '/wiki/Ben_Roy_Mottelson',
#    'name': 'Ben Roy Mottelson'},
#   {'category': 'Physics',
#    'href': '/wiki/James_Rainwater',
#    'name': 'James Rainwater'},
#   {'category': 'Chemistry',
#    'href': '/wiki/John_Cornforth',
#    'name': 'John Cornforth'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Vladimir_Prelog',
#    'name': 'Vladimir Prelog'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/David_Baltimore',
#    'name': 'David Baltimore'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Renato_Dulbecco',
#    'name': 'Renato Dulbecco'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Howard_Martin_Temin',
#    'name': 'Howard Martin Temin'},
#   {'category': 'Literature',
#    'href': '/wiki/Eugenio_Montale',
#    'name': 'Eugenio Montale'},
#   {'category': 'Peace',
#    'href': '/wiki/Andrei_Sakharov',
#    'name': 'Andrei Sakharov'},
#   {'category': 'Economics',
#    'href': '/wiki/Leonid_Kantorovich',
#    'name': 'Leonid Kantorovich'},
#   {'category': 'Economics',
# ...
#    'name': 'Aaron Ciechanover'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Avram_Hershko',
#    'name': 'Avram Hershko'},
#   {'category': 'Chemistry', 'href': '/wiki/Irwin_Rose', 'name': 'Irwin Rose'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Richard_Axel',
#    'name': 'Richard Axel'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Linda_B._Buck',
#    'name': 'Linda B. Buck'},
#   {'category': 'Literature',
#    'href': '/wiki/Elfriede_Jelinek',
#    'name': 'Elfriede Jelinek'},
#   {'category': 'Peace',
#    'href': '/wiki/Wangari_Maathai',
#    'name': 'Wangari Maathai'},
#   {'category': 'Economics',
#    'href': '/wiki/Finn_E._Kydland',
#    'name': 'Finn E. Kydland'},
#   {'category': 'Economics',
#    'href': '/wiki/Edward_C._Prescott',
#    'name': 'Edward C. Prescott'}],
#  '2005': [{'category': 'Physics',
#    'href': '/wiki/Roy_J._Glauber',
#    'name': 'Roy J. Glauber'},
#   {'category': 'Physics',
#    'href': '/wiki/John_L._Hall',
#    'name': 'John L. Hall'},
#   {'category': 'Physics',
#    'href': '/wiki/Theodor_W._H%C3%A4nsch',
#    'name': 'Theodor W. Hänsch'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Yves_Chauvin',
#    'name': 'Yves Chauvin'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Robert_H._Grubbs',
#    'name': 'Robert H. Grubbs'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Richard_R._Schrock',
#    'name': 'Richard R. Schrock'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Barry_Marshall',
#    'name': 'Barry Marshall'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Robin_Warren',
#    'name': 'Robin Warren'},
#   {'category': 'Literature',
#    'href': '/wiki/Harold_Pinter',
#    'name': 'Harold Pinter'},
#   {'category': 'Peace',
#    'href': '/wiki/International_Atomic_Energy_Agency',
#    'name': 'International Atomic Energy Agency'},
#   {'category': 'Peace',
#    'href': '/wiki/Mohamed_ElBaradei',
#    'name': 'Mohamed ElBaradei'},
#   {'category': 'Economics',
#    'href': '/wiki/Robert_Aumann',
#    'name': 'Robert Aumann'},
#   {'category': 'Economics',
#    'href': '/wiki/Thomas_Schelling',
#    'name': 'Thomas Schelling'}],
#  '2006': [{'category': 'Physics',
#    'href': '/wiki/John_C._Mather',
#    'name': 'John C. Mather'},
#   {'category': 'Physics',
#    'href': '/wiki/George_Smoot',
#    'name': 'George Smoot'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Roger_D._Kornberg',
#    'name': 'Roger D. Kornberg'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Andrew_Fire',
#    'name': 'Andrew Fire'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Craig_Mello',
#    'name': 'Craig Mello'},
#   {'category': 'Literature',
#    'href': '/wiki/Orhan_Pamuk',
#    'name': 'Orhan Pamuk'},
#   {'category': 'Peace',
#    'href': '/wiki/Muhammad_Yunus',
#    'name': 'Muhammad Yunus'},
#   {'category': 'Peace', 'href': '/wiki/Grameen_Bank', 'name': 'Grameen Bank'},
#   {'category': 'Economics',
#    'href': '/wiki/Edmund_Phelps',
#    'name': 'Edmund Phelps'}],
#  '2007': [{'category': 'Physics',
#    'href': '/wiki/Albert_Fert',
#    'name': 'Albert Fert'},
#   {'category': 'Physics',
#    'href': '/wiki/Peter_Gr%C3%BCnberg',
#    'name': 'Peter Grünberg'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Gerhard_Ertl',
#    'name': 'Gerhard Ertl'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Mario_Capecchi',
#    'name': 'Mario Capecchi'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Martin_Evans',
#    'name': 'Martin Evans'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Oliver_Smithies',
#    'name': 'Oliver Smithies'},
#   {'category': 'Literature',
#    'href': '/wiki/Doris_Lessing',
#    'name': 'Doris Lessing'},
#   {'category': 'Peace',
#    'href': '/wiki/Intergovernmental_Panel_on_Climate_Change',
#    'name': 'Intergovernmental Panel on Climate Change'},
#   {'category': 'Peace', 'href': '/wiki/Al_Gore', 'name': 'Al Gore'},
#   {'category': 'Economics',
#    'href': '/wiki/Leonid_Hurwicz',
#    'name': 'Leonid Hurwicz'},
#   {'category': 'Economics',
#    'href': '/wiki/Eric_Maskin',
#    'name': 'Eric Maskin'},
#   {'category': 'Economics',
#    'href': '/wiki/Roger_Myerson',
#    'name': 'Roger Myerson'}],
#  '2008': [{'category': 'Physics',
#    'href': '/wiki/Yoichiro_Nambu',
#    'name': 'Yoichiro Nambu'},
#   {'category': 'Physics',
#    'href': '/wiki/Makoto_Kobayashi_(physicist)',
#    'name': 'Makoto Kobayashi'},
#   {'category': 'Physics',
#    'href': '/wiki/Toshihide_Maskawa',
#    'name': 'Toshihide Maskawa'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Osamu_Shimomura',
#    'name': 'Osamu Shimomura'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Martin_Chalfie',
#    'name': 'Martin Chalfie'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Roger_Y._Tsien',
#    'name': 'Roger Y. Tsien'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Harald_zur_Hausen',
#    'name': 'Harald zur Hausen'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Fran%C3%A7oise_Barr%C3%A9-Sinoussi',
#    'name': 'Françoise Barré-Sinoussi'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Luc_Montagnier',
#    'name': 'Luc Montagnier'},
#   {'category': 'Literature',
#    'href': '/wiki/J._M._G._Le_Cl%C3%A9zio',
#    'name': 'J. M. G. Le Clézio'},
#   {'category': 'Peace',
#    'href': '/wiki/Martti_Ahtisaari',
#    'name': 'Martti Ahtisaari'},
#   {'category': 'Economics',
#    'href': '/wiki/Paul_Krugman',
#    'name': 'Paul Krugman'}],
#  '2009': [{'category': 'Physics',
#    'href': '/wiki/Charles_K._Kao',
#    'name': 'Charles K. Kao'},
#   {'category': 'Physics',
#    'href': '/wiki/Willard_Boyle',
#    'name': 'Willard S. Boyle'},
#   {'category': 'Physics',
#    'href': '/wiki/George_E._Smith',
#    'name': 'George E. Smith'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Venkatraman_Ramakrishnan',
#    'name': 'Venkatraman Ramakrishnan'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Thomas_A._Steitz',
#    'name': 'Thomas A. Steitz'},
#   {'category': 'Chemistry', 'href': '/wiki/Ada_Yonath', 'name': 'Ada Yonath'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Elizabeth_Blackburn',
#    'name': 'Elizabeth Blackburn'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Carol_W._Greider',
#    'name': 'Carol W. Greider'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Jack_W._Szostak',
#    'name': 'Jack W. Szostak'},
#   {'category': 'Literature',
#    'href': '/wiki/Herta_M%C3%BCller',
#    'name': 'Herta Müller'},
#   {'category': 'Peace', 'href': '/wiki/Barack_Obama', 'name': 'Barack Obama'},
#   {'category': 'Economics',
#    'href': '/wiki/Elinor_Ostrom',
#    'name': 'Elinor Ostrom'},
#   {'category': 'Economics',
#    'href': '/wiki/Oliver_E._Williamson',
#    'name': 'Oliver E. Williamson'}],
#  '2010': [{'category': 'Physics',
#    'href': '/wiki/Andre_Geim',
#    'name': 'Andre Geim'},
#   {'category': 'Physics',
#    'href': '/wiki/Konstantin_Novoselov',
#    'name': 'Konstantin Novoselov'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Richard_F._Heck',
#    'name': 'Richard F. Heck'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Ei-ichi_Negishi',
#    'name': 'Ei-ichi Negishi'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Akira_Suzuki_(chemist)',
#    'name': 'Akira Suzuki'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Robert_G._Edwards',
#    'name': 'Robert G. Edwards'},
#   {'category': 'Literature',
#    'href': '/wiki/Mario_Vargas_Llosa',
#    'name': 'Mario Vargas Llosa'},
#   {'category': 'Peace', 'href': '/wiki/Liu_Xiaobo', 'name': 'Liu Xiaobo'},
#   {'category': 'Peace', 'href': '#endnote_Note1F', 'name': '[F]'},
#   {'category': 'Economics',
#    'href': '/wiki/Peter_Diamond',
#    'name': 'Peter A. Diamond'},
#   {'category': 'Economics',
#    'href': '/wiki/Dale_T._Mortensen',
#    'name': 'Dale T. Mortensen'},
#   {'category': 'Economics',
#    'href': '/wiki/Christopher_A._Pissarides',
#    'name': 'Christopher A. Pissarides'}],
#  '2011': [{'category': 'Physics',
#    'href': '/wiki/Saul_Perlmutter',
#    'name': 'Saul Perlmutter'},
#   {'category': 'Physics', 'href': '/wiki/Adam_Riess', 'name': 'Adam G. Riess'},
#   {'category': 'Physics',
#    'href': '/wiki/Brian_Schmidt',
#    'name': 'Brian Schmidt'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Dan_Shechtman',
#    'name': 'Dan Shechtman'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Bruce_Beutler',
#    'name': 'Bruce Beutler'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Jules_A._Hoffmann',
#    'name': 'Jules A. Hoffmann'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Ralph_M._Steinman',
#    'name': 'Ralph M. Steinman'},
#   {'category': 'Literature',
#    'href': '/wiki/Tomas_Transtr%C3%B6mer',
#    'name': 'Tomas Tranströmer'},
#   {'category': 'Peace',
#    'href': '/wiki/Ellen_Johnson_Sirleaf',
#    'name': 'Ellen Johnson Sirleaf'},
#   {'category': 'Peace',
#    'href': '/wiki/Leymah_Gbowee',
#    'name': 'Leymah Gbowee'},
#   {'category': 'Peace',
#    'href': '/wiki/Tawakel_Karman',
#    'name': 'Tawakel Karman'},
#   {'category': 'Economics',
#    'href': '/wiki/Thomas_J._Sargent',
#    'name': 'Thomas J. Sargent'},
#   {'category': 'Economics',
#    'href': '/wiki/Christopher_A._Sims',
#    'name': 'Christopher A. Sims'}],
#  '2012': [{'category': 'Physics',
#    'href': '/wiki/Serge_Haroche',
#    'name': 'Serge Haroche'},
#   {'category': 'Physics',
#    'href': '/wiki/David_J._Wineland',
#    'name': 'David J. Wineland'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Brian_Kobilka',
#    'name': 'Brian K. Kobilka'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Robert_Lefkowitz',
#    'name': 'Robert J. Lefkowitz'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/John_Gurdon',
#    'name': 'John B. Gurdon'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Shinya_Yamanaka',
#    'name': 'Shinya Yamanaka'},
#   {'category': 'Literature', 'href': '/wiki/Mo_Yan', 'name': 'Mo Yan'},
#   {'category': 'Peace',
#    'href': '/wiki/European_Union',
#    'name': 'European Union'},
#   {'category': 'Economics',
#    'href': '/wiki/Alvin_E._Roth',
#    'name': 'Alvin E. Roth'},
#   {'category': 'Economics',
#    'href': '/wiki/Lloyd_Shapley',
#    'name': 'Lloyd S. Shapley'}],
#  '2013': [{'category': 'Physics',
#    'href': '/wiki/Fran%C3%A7ois_Englert',
#    'name': 'François Englert'},
#   {'category': 'Physics',
#    'href': '/wiki/Peter_Higgs',
#    'name': 'Peter W. Higgs'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Martin_Karplus',
#    'name': 'Martin Karplus'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Michael_Levitt',
#    'name': 'Michael Levitt'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Arieh_Warshel',
#    'name': 'Arieh Warshel'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/James_Rothman',
#    'name': 'James E. Rothman'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Randy_W._Schekman',
#    'name': 'Randy W. Schekman'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Thomas_C._S%C3%BCdhof',
#    'name': 'Thomas C. Südhof'},
#   {'category': 'Literature',
#    'href': '/wiki/Alice_Munro',
#    'name': 'Alice Munro'},
#   {'category': 'Peace',
#    'href': '/wiki/Organisation_for_the_Prohibition_of_Chemical_Weapons',
#    'name': 'Organisation for the Prohibition of Chemical Weapons'},
#   {'category': 'Economics',
#    'href': '/wiki/Eugene_Fama',
#    'name': 'Eugene F. Fama'},
#   {'category': 'Economics',
#    'href': '/wiki/Lars_Peter_Hansen',
#    'name': 'Lars Peter Hansen'},
#   {'category': 'Economics',
#    'href': '/wiki/Robert_Shiller',
#    'name': 'Robert J. Shiller'}],
#  '2014': [{'category': 'Physics',
#    'href': '/wiki/Isamu_Akasaki',
#    'name': 'Isamu Akasaki'},
#   {'category': 'Physics',
#    'href': '/wiki/Hiroshi_Amano',
#    'name': 'Hiroshi Amano'},
#   {'category': 'Physics',
#    'href': '/wiki/Shuji_Nakamura',
#    'name': 'Shuji Nakamura'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Eric_Betzig',
#    'name': 'Eric Betzig'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Stefan_Hell',
#    'name': 'Stefan Hell'},
#   {'category': 'Chemistry',
#    'href': '/wiki/William_Moerner',
#    'name': 'William Moerner'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/John_O%27Keefe_(neuroscientist)',
#    'name': "John O'Keefe"},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/May-Britt_Moser',
#    'name': 'May-Britt Moser'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Edvard_Moser',
#    'name': 'Edvard Moser'},
#   {'category': 'Literature',
#    'href': '/wiki/Patrick_Modiano',
#    'name': 'Patrick Modiano'},
#   {'category': 'Peace',
#    'href': '/wiki/Kailash_Satyarthi',
#    'name': 'Kailash Satyarthi'},
#   {'category': 'Peace',
#    'href': '/wiki/Malala_Yousafzai',
#    'name': 'Malala Yousafzai'},
#   {'category': 'Economics',
#    'href': '/wiki/Jean_Tirole',
#    'name': 'Jean Tirole'}],
#  '2015': [{'category': 'Physics',
#    'href': '/wiki/Takaaki_Kajita',
#    'name': 'Takaaki Kajita'},
#   {'category': 'Physics',
#    'href': '/wiki/Arthur_B._McDonald',
#    'name': 'Arthur B. McDonald'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Tomas_Lindahl',
#    'name': 'Tomas Lindahl'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Paul_Modrich',
#    'name': 'Paul L. Modrich'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Aziz_Sancar',
#    'name': 'Aziz Sancar'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/William_C._Campbell_(scientist)',
#    'name': 'William C. Campbell'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Satoshi_%C5%8Cmura',
#    'name': 'Satoshi Ōmura'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Tu_Youyou',
#    'name': 'Tu Youyou'},
#   {'category': 'Literature',
#    'href': '/wiki/Svetlana_Alexievich',
#    'name': 'Svetlana Alexievich'},
#   {'category': 'Peace',
#    'href': '/wiki/Tunisian_National_Dialogue_Quartet',
#    'name': 'Tunisian National Dialogue Quartet'},
#   {'category': 'Economics',
#    'href': '/wiki/Angus_Deaton',
#    'name': 'Angus Deaton'}],
#  '2016': [{'category': 'Physics',
#    'href': '/wiki/David_J._Thouless',
#    'name': 'David J. Thouless'},
#   {'category': 'Physics',
#    'href': '/wiki/Duncan_Haldane',
#    'name': 'Duncan Haldane'},
#   {'category': 'Physics',
#    'href': '/wiki/John_M._Kosterlitz',
#    'name': 'John M. Kosterlitz'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Jean-Pierre_Sauvage',
#    'name': 'Jean-Pierre Sauvage'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Fraser_Stoddart',
#    'name': 'Fraser Stoddart'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Ben_Feringa',
#    'name': 'Ben Feringa'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Yoshinori_Ohsumi',
#    'name': 'Yoshinori Ohsumi'},
#   {'category': 'Literature', 'href': '/wiki/Bob_Dylan', 'name': 'Bob Dylan'},
#   {'category': 'Peace',
#    'href': '/wiki/Juan_Manuel_Santos',
#    'name': 'Juan Manuel Santos'},
#   {'category': 'Economics',
#    'href': '/wiki/Oliver_Hart_(economist)',
#    'name': 'Oliver Hart'},
#   {'category': 'Economics',
#    'href': '/wiki/Bengt_R._Holmstr%C3%B6m',
#    'name': 'Bengt R. Holmström'}],
#  '2017': [{'category': 'Physics',
#    'href': '/wiki/Rainer_Weiss',
#    'name': 'Rainer Weiss'},
#   {'category': 'Physics',
#    'href': '/wiki/Barry_Barish',
#    'name': 'Barry Barish'},
#   {'category': 'Physics', 'href': '/wiki/Kip_Thorne', 'name': 'Kip Thorne'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Jacques_Dubochet',
#    'name': 'Jacques Dubochet'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Joachim_Frank',
#    'name': 'Joachim Frank'},
#   {'category': 'Chemistry',
#    'href': '/wiki/Richard_Henderson_(biologist)',
#    'name': 'Richard Henderson'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Jeffrey_C._Hall',
#    'name': 'Jeffrey C. Hall'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Michael_Rosbash',
#    'name': 'Michael Rosbash'},
#   {'category': 'Physiology or Medicine',
#    'href': '/wiki/Michael_W._Young',
#    'name': 'Michael W. Young'},
#   {'category': 'Literature',
#    'href': '/wiki/Kazuo_Ishiguro',
#    'name': 'Kazuo Ishiguro'},
#   {'category': 'Peace',
#    'href': '/wiki/International_Campaign_to_Abolish_Nuclear_Weapons',
#    'name': 'International Campaign to Abolish Nuclear Weapons'},
#   {'category': 'Economics',
#    'href': '/wiki/Richard_Thaler',
#    'name': 'Richard Thaler'}]}

# %%
# In order to get the birthday for each winner we will have to build
# a new url and request the data. We'll create a list of the first
# item in the by_year dictionary values by using the slice syntax:
# <list variable>[:n] means everything leading up to the nth item
# x[:!0] would be the first 10 items
# x[-10:] would mean the last 10 items
# x[5:10] would mean the items in the 5th-10th positions

# If we didn't slice by_year.values() down it would take a long time
# to run because it would call out to wikipedia for every page

# %%
for winner_list in list(by_year.values())[:1]:
    for winner in winner_list:
        new_url = 'https://en.wikipedia.org' + winner["href"]
        response = requests.get(new_url)
        content = response.content.decode('utf-8')
        sel = scrapy.Selector(text=content)

# %%
# We can see that our selector hold's the detail page's contents

# %%
sel
# Out:
# <Selector xpath=None data='<html class="client-nojs" lang="en" dir='>

# %%
# We can also see that the biography table rows contain the information we need
# to discover the winners birthday

# %%
sel.css('.vcard tr').xpath("string()").extract()
# Out:
# ['\nFrédéric Passy\n',
#  '\n\n',
#  '\nBorn\nFrédéric Passy\n(1822-05-20)May 20, 1822\nParis, France\n',
#  '\nDied\nJune 12, 1912(1912-06-12) (aged\xa090)\nNeuilly-sur-Seine, France\n',
#  '\nNationality\nFrench\n',
#  '\nEducation\nUniversity of Paris\n',
#  '\nOccupation\nEconomist\n',
#  '\nAwards\nNobel Peace Prize (1901)\n']

# %%
# Revisiting the page and inspecting the data with chrome
# reveals there is a hidden span with a class of "bday"

# %%
sel.css('.vcard span.bday').xpath("string()").extract()
# Out:
# ['1822-05-20']

# %%
# We can create a function that takes a winner's dictionary
# and mutates it (edits it in place) and adds the birthday info
# This is important to note in python... dictionaries are mutable
# and editing them within a function causes them to retain the changes.

# We don't have to have our function return a new dictionary or alter the
# list we're looping over. The changes to the dictionary stick.
# Your can't do this with some datatypes in Python, such as strings.

# We'll print the variable before and after we update it to demonstrate

# %%
def update_with_bday(winner):
    print("updating {}".format(winner["name"]))
    print(winner)
    new_url = 'https://en.wikipedia.org' + winner["href"]
    response = requests.get(new_url)
    content = response.content.decode('utf-8')
    sel = scrapy.Selector(text=content)
    bday = sel.css('.vcard span.bday').xpath("string()").extract()[0]
    winner["birthday"] = bday
    print(winner)

# %%
print(winner_list[0])
for winner_list in list(by_year.values())[:1]:
    for winner in winner_list:
        update_with_bday(winner)
print(winner_list[0])
# Out:
# {'name': 'Wilhelm Röntgen', 'href': '/wiki/Wilhelm_R%C3%B6ntgen', 'category': 'Physics', 'birthday': '1845-03-27'}
# updating Wilhelm Röntgen
# {'name': 'Wilhelm Röntgen', 'href': '/wiki/Wilhelm_R%C3%B6ntgen', 'category': 'Physics', 'birthday': '1845-03-27'}
# {'name': 'Wilhelm Röntgen', 'href': '/wiki/Wilhelm_R%C3%B6ntgen', 'category': 'Physics', 'birthday': '1845-03-27'}
# updating Jacobus Henricus van 't Hoff
# {'name': "Jacobus Henricus van 't Hoff", 'href': '/wiki/Jacobus_Henricus_van_%27t_Hoff', 'category': 'Chemistry', 'birthday': '1852-08-30'}
# {'name': "Jacobus Henricus van 't Hoff", 'href': '/wiki/Jacobus_Henricus_van_%27t_Hoff', 'category': 'Chemistry', 'birthday': '1852-08-30'}
# updating Emil Adolf von Behring
# {'name': 'Emil Adolf von Behring', 'href': '/wiki/Emil_Adolf_von_Behring', 'category': 'Physiology or Medicine', 'birthday': '1854-03-15'}
# {'name': 'Emil Adolf von Behring', 'href': '/wiki/Emil_Adolf_von_Behring', 'category': 'Physiology or Medicine', 'birthday': '1854-03-15'}
# updating Sully Prudhomme
# {'name': 'Sully Prudhomme', 'href': '/wiki/Sully_Prudhomme', 'category': 'Literature', 'birthday': '1839-03-16'}
# {'name': 'Sully Prudhomme', 'href': '/wiki/Sully_Prudhomme', 'category': 'Literature', 'birthday': '1839-03-16'}
# updating Henry Dunant
# {'name': 'Henry Dunant', 'href': '/wiki/Henry_Dunant', 'category': 'Peace', 'birthday': '1828-05-08'}
# {'name': 'Henry Dunant', 'href': '/wiki/Henry_Dunant', 'category': 'Peace', 'birthday': '1828-05-08'}
# updating Frédéric Passy
# {'name': 'Frédéric Passy', 'href': '/wiki/Fr%C3%A9d%C3%A9ric_Passy', 'category': 'Peace', 'birthday': '1822-05-20'}
# {'name': 'Frédéric Passy', 'href': '/wiki/Fr%C3%A9d%C3%A9ric_Passy', 'category': 'Peace', 'birthday': '1822-05-20'}
# {'name': 'Wilhelm Röntgen', 'href': '/wiki/Wilhelm_R%C3%B6ntgen', 'category': 'Physics', 'birthday': '1845-03-27'}

# %%
def update_with_bday(winner):
    print("updating {}".format(winner["name"]))
    print(winner)
    new_url = 'https://en.wikipedia.org' + winner["href"]
    print("Calling wikipedia: {}".format(new_url))
    response = requests.get(new_url)
    content = response.content.decode('utf-8')
    sel = scrapy.Selector(text=content)
    bday = sel.css('.vcard span.bday').xpath("string()").extract()
    birthday = None
    if bday:
        birthday = bday[0]
    winner["birthday"] = birthday
    print(winner)

print(winner_list[0])
for winner_list in list(by_year.values())[:1]:
    for winner in winner_list:
        if 'birthday' not in winner:
            update_with_bday(winner)
print(winner_list[0])
# Out:
# {'name': 'Wilhelm Röntgen', 'href': '/wiki/Wilhelm_R%C3%B6ntgen', 'category': 'Physics'}
# updating Wilhelm Röntgen
# {'name': 'Wilhelm Röntgen', 'href': '/wiki/Wilhelm_R%C3%B6ntgen', 'category': 'Physics'}
# Calling wikipedia: https://en.wikipedia.org/wiki/Wilhelm_R%C3%B6ntgen
# {'name': 'Wilhelm Röntgen', 'href': '/wiki/Wilhelm_R%C3%B6ntgen', 'category': 'Physics', 'birthday': '1845-03-27'}
# updating Jacobus Henricus van 't Hoff
# {'name': "Jacobus Henricus van 't Hoff", 'href': '/wiki/Jacobus_Henricus_van_%27t_Hoff', 'category': 'Chemistry'}
# Calling wikipedia: https://en.wikipedia.org/wiki/Jacobus_Henricus_van_%27t_Hoff
# {'name': "Jacobus Henricus van 't Hoff", 'href': '/wiki/Jacobus_Henricus_van_%27t_Hoff', 'category': 'Chemistry', 'birthday': '1852-08-30'}
# updating Emil Adolf von Behring
# {'name': 'Emil Adolf von Behring', 'href': '/wiki/Emil_Adolf_von_Behring', 'category': 'Physiology or Medicine'}
# Calling wikipedia: https://en.wikipedia.org/wiki/Emil_Adolf_von_Behring
# {'name': 'Emil Adolf von Behring', 'href': '/wiki/Emil_Adolf_von_Behring', 'category': 'Physiology or Medicine', 'birthday': '1854-03-15'}
# updating Sully Prudhomme
# {'name': 'Sully Prudhomme', 'href': '/wiki/Sully_Prudhomme', 'category': 'Literature'}
# Calling wikipedia: https://en.wikipedia.org/wiki/Sully_Prudhomme
# {'name': 'Sully Prudhomme', 'href': '/wiki/Sully_Prudhomme', 'category': 'Literature', 'birthday': '1839-03-16'}
# updating Henry Dunant
# {'name': 'Henry Dunant', 'href': '/wiki/Henry_Dunant', 'category': 'Peace'}
# Calling wikipedia: https://en.wikipedia.org/wiki/Henry_Dunant
# {'name': 'Henry Dunant', 'href': '/wiki/Henry_Dunant', 'category': 'Peace', 'birthday': '1828-05-08'}
# updating Frédéric Passy
# {'name': 'Frédéric Passy', 'href': '/wiki/Fr%C3%A9d%C3%A9ric_Passy', 'category': 'Peace'}
# Calling wikipedia: https://en.wikipedia.org/wiki/Fr%C3%A9d%C3%A9ric_Passy
# {'name': 'Frédéric Passy', 'href': '/wiki/Fr%C3%A9d%C3%A9ric_Passy', 'category': 'Peace', 'birthday': '1822-05-20'}
# {'name': 'Wilhelm Röntgen', 'href': '/wiki/Wilhelm_R%C3%B6ntgen', 'category': 'Physics', 'birthday': '1845-03-27'}

# %%
import pprint
pprint.pprint(winner_list[0])
# Out:
# {'birthday': '1845-03-27',
#  'category': 'Physics',
#  'href': '/wiki/Wilhelm_R%C3%B6ntgen',
#  'name': 'Wilhelm Röntgen'}
